# %%
#!/usr/bin/env python3
"""
ORCID 女性姓名变化检测程序 - 修复版本
添加了对难以处理的XML文件的错误处理和复制功能
解决了多进程返回结果时的 Pickling RecursionError 问题
"""

import os
import csv
import logging
import multiprocessing as mp
from multiprocessing import Pool, Manager, Lock
from concurrent.futures import ProcessPoolExecutor, as_completed
import time
from pathlib import Path
from typing import Dict, List, Optional, Tuple
import signal
import sys
from functools import partial
import shutil
import traceback

from bs4 import BeautifulSoup
import gender_guesser.detector as gender
import Levenshtein
from datetime import datetime


# 增加递归限制
sys.setrecursionlimit(15000)

# 全局配置
CONFIG = {
    'base_path': '/hy-tmp/orcid/ORCID_2024_10_summaries',
    'output_file': '/hy-tmp/female_name_changes.csv',
    'log_file': '/hy-tmp/orcid_processing.log',
    'problem_files_dir': '/hy-tmp/problem_xml_files',  # 问题文件存储目录
    'max_workers': 2,  
    'chunk_size': 10000,  # 每个进程处理的文件数量
    'batch_size': 10,  # 批量写入CSV的记录数
    'max_file_size': 10 * 1024 * 1024,  # 10MB 文件大小限制
}

def setup_problem_files_dir():
    """创建问题文件存储目录"""
    problem_dir = Path(CONFIG['problem_files_dir'])
    problem_dir.mkdir(parents=True, exist_ok=True)
    
    # 创建子目录
    (problem_dir / 'recursion_error').mkdir(exist_ok=True)
    (problem_dir / 'parse_error').mkdir(exist_ok=True)
    (problem_dir / 'large_files').mkdir(exist_ok=True)
    (problem_dir / 'other_errors').mkdir(exist_ok=True)
    
    return problem_dir

def copy_problem_file(file_path: Path, error_type: str, error_msg: str = ""):
    """复制问题文件到指定目录"""
    try:
        problem_dir = Path(CONFIG['problem_files_dir'])
        error_dir = problem_dir / error_type
        
        # 创建唯一的文件名（避免重名）
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")
        new_filename = f"{file_path.stem}_{timestamp}{file_path.suffix}"
        dest_path = error_dir / new_filename
        
        shutil.copy2(file_path, dest_path)
        
        # 记录错误信息
        log_file = error_dir / "error_log.txt"
        with open(log_file, 'a', encoding='utf-8') as f:
            f.write(f"{datetime.now().isoformat()}\t{file_path}\t{new_filename}\t{error_msg}\n")
            
        return True
    except Exception as e:
        print(f"无法复制问题文件 {file_path}: {e}")
        return False

def safe_parse_xml(file_path: Path) -> Optional[BeautifulSoup]:
    """安全的XML解析函数，包含各种错误处理"""
    try:
        # 检查文件大小
        file_size = file_path.stat().st_size
        if file_size > CONFIG['max_file_size']:
            copy_problem_file(file_path, 'large_files', f"File size: {file_size} bytes")
            return None
        
        # 尝试解析XML
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
            
            # 检查内容长度
            if len(content) > 10_000_000:  # 10MB文本内容限制
                copy_problem_file(file_path, 'large_files', f"Content length: {len(content)} chars")
                return None
            
            soup = BeautifulSoup(content, 'lxml-xml')
            return soup
            
    except RecursionError as e:
        copy_problem_file(file_path, 'recursion_error', f"RecursionError: {str(e)}")
        return None
    except Exception as e:
        error_msg = f"{type(e).__name__}: {str(e)}"
        if "recursion" in str(e).lower():
            copy_problem_file(file_path, 'recursion_error', error_msg)
        elif any(keyword in str(e).lower() for keyword in ['parse', 'xml', 'malformed']):
            copy_problem_file(file_path, 'parse_error', error_msg)
        else:
            copy_problem_file(file_path, 'other_errors', error_msg)
        return None

def extract_name_info(soup: BeautifulSoup, gender_detector) -> Optional[Dict]:
    """从BeautifulSoup对象中提取姓名信息和性别"""
    try:
        person_name_tag = soup.find("person:name")
        if not person_name_tag:
            return None

        # 提取person:name基本信息
        person_created_date_tag = person_name_tag.find("common:created-date")
        given_names_tag = person_name_tag.find("personal-details:given-names")
        family_name_tag = person_name_tag.find("personal-details:family-name")

        # <-- FIX: Convert all extracted text to plain Python strings
        person_created_date = person_created_date_tag.get_text(strip=True) if person_created_date_tag else None
        given_name = given_names_tag.get_text(strip=True) if given_names_tag else None
        family_name = family_name_tag.get_text(strip=True) if family_name_tag else None

        # 性别识别 - 只处理女性
        if not given_name:
            return None
        
        gender_result = gender_detector.get_gender(given_name.split()[0])
        if gender_result not in ['female', 'mostly_female']:
            return None 

        # 构建基准姓名 (given_name + family_name)
        if not family_name:
            return None
        base_name = f"{given_name} {family_name}".strip()

        # 提取other-name信息 - 可能有多个
        other_names_data = []
        other_name_tags = soup.find_all("other-name:other-name")
        
        for other_name_tag in other_name_tags:
            other_created_date_tag = other_name_tag.find("common:created-date")
            other_name_content_tag = other_name_tag.find("other-name:content")
            
            # <-- FIX: Convert all extracted text to plain Python strings
            other_created_date = other_created_date_tag.get_text(strip=True) if other_created_date_tag else None
            other_name_content = other_name_content_tag.get_text(strip=True) if other_name_content_tag else None
            
            if other_created_date and other_name_content:
                other_names_data.append({
                    'other_name_content': other_name_content,
                    'other_created_date': other_created_date
                })

        if not other_names_data:
            return None

        return {
            'person_created_date': person_created_date,
            'given_name': given_name,
            'family_name': family_name,
            'base_name': base_name,
            'other_names_data': other_names_data,
            'gender': gender_result
        }

    except RecursionError:
        raise  # 让上层处理
    except Exception as e:
        return None

def process_single_file(file_path: Path, port_name: str, gender_detector) -> Optional[Dict]:
    """处理单个XML文件 - 增强错误处理"""
    try:
        # 使用安全的XML解析
        soup = safe_parse_xml(file_path)
        if not soup:
            return None
            
        name_info = extract_name_info(soup, gender_detector)
        if not name_info:
            return None

        is_change, change_data = is_name_change_candidate(name_info)
        if is_change and change_data:
            path_tag = soup.find("common:path")
            # <-- FIX: Convert the ORCID ID to a plain Python string
            orcid_id = path_tag.get_text(strip=True) if path_tag else "unknown"
            
            return {
                'port_name': port_name,
                'id': orcid_id,
                'person_name': change_data[0],
                'person_date': change_data[1],
                'other_name': change_data[2],
                'other_date': change_data[3],
                'gender': name_info['gender']
            }
        return None

    except RecursionError as e:
        copy_problem_file(file_path, 'recursion_error', f"RecursionError in process_single_file: {str(e)}")
        return None
    except Exception as e:
        # 对于其他异常，不复制文件（因为safe_parse_xml已经处理了）
        return None

def _extract_name_parts(full_name: str) -> Dict[str, str]:
    """从全名中提取姓、名、中间名"""
    parts = full_name.strip().split()
    if not parts:
        return {'given': '', 'middle': '', 'family': ''}
    
    given = parts[0]
    if len(parts) == 1:
        return {'given': given, 'middle': '', 'family': ''}
    
    family = parts[-1]
    middle = ' '.join(parts[1:-1])
    return {'given': given, 'middle': middle, 'family': family}

def is_name_change_candidate(name_info: Dict) -> Tuple[bool, Optional[List]]:
    """
    判断是否为姓名变化候选者
    """
    try:
        # --- 1. 数据提取 ---
        base_name = name_info['base_name']
        person_created_date = name_info['person_created_date']
        other_names_data = name_info['other_names_data']
        family_name = name_info['family_name']
        given_name = name_info['given_name']

        if not all([base_name, person_created_date, other_names_data, family_name, given_name]):
            return False, None

        # 解析person:name的创建日期 
        try:
            person_date = datetime.fromisoformat(person_created_date.replace('Z', '+00:00'))
        except ValueError:
            return False, None

        # --- 2. 遍历 other-names，进行筛选和判断 ---
        for other_data in other_names_data:
            other_name_content = other_data.get('other_name_content')
            other_created_date = other_data.get('other_created_date')
            
            if not other_name_content or not other_created_date:
                continue

            try:
                other_date = datetime.fromisoformat(other_created_date.replace('Z', '+00:00'))
            except ValueError:
                continue

            # 时间差过滤
            if abs((person_date - other_date).days) < 30:
                continue

            # --- 3. 姓名标准化与结构化 ---
            cleaned_base = ' '.join(str(base_name).lower().strip().replace('.', '').replace(',', '').replace('-', ' ').split())
            cleaned_other = ' '.join(str(other_name_content).lower().strip().replace('.', '').replace(',', '').replace('-', ' ').split())
            
            # Levenshtein 距离
            if Levenshtein.distance(cleaned_base, cleaned_other) < 2:
                continue

            base_parts = _extract_name_parts(cleaned_base)
            other_parts = _extract_name_parts(cleaned_other)

            if not all([base_parts['given'], other_parts['given'], base_parts['family'], other_parts['family']]):
                continue

            # --- 4. 核心逻辑判断 ---
            
            # a) 验证是否为同一个人 (名字部分容错判断)
            if Levenshtein.distance(base_parts['given'], other_parts['given']) >= 2:
                continue
            
            # b) 获取并比较完整的姓氏部分
            base_full_surname = f"{base_parts['middle']} {base_parts['family']}".strip()
            other_full_surname = f"{other_parts['middle']} {other_parts['family']}".strip()

            if Levenshtein.distance(base_full_surname, other_full_surname) < 2:
                continue

            # c) 排除只增加/减少中间名的情况
            is_subset_change = (base_full_surname in other_full_surname or other_full_surname in base_full_surname)
            if is_subset_change and Levenshtein.distance(base_parts['family'], other_parts['family']) <= 1:
                continue

            # d) 排除缩写情况
            if (len(base_parts['family']) == 1 and len(other_parts['family']) > 1 and base_parts['family'] == other_parts['family'][0]) or \
               (len(other_parts['family']) == 1 and len(base_parts['family']) > 1 and other_parts['family'] == base_parts['family'][0]):
                continue

            # --- 5. 确认是候选者 ---
            
            if person_date < other_date:
                older_name, newer_name = cleaned_base, cleaned_other
                older_date_str, newer_date_str = person_created_date, other_created_date
            else:
                older_name, newer_name = cleaned_other, cleaned_base
                older_date_str, newer_date_str = other_created_date, person_created_date

            return True, [older_name, older_date_str, newer_name, newer_date_str]

        return False, None

    except RecursionError:
        raise  # 让上层处理
    except Exception as e:
        return False, None

def process_file_chunk(args):
    """处理文件块的工作函数 - 增强错误处理"""
    file_paths, port_name, process_id = args
    
    # 在子进程中初始化 gender detector
    try:
        local_gender_detector = gender.Detector()
    except Exception as e:
        print(f"Process {process_id}: Failed to initialize gender detector: {e}")
        return [], 0, 0, 0  # 增加错误文件计数
    
    results = []
    processed = 0
    error_count = 0
    
    for file_path in file_paths:
        try:
            # 检查文件大小
            file_size = file_path.stat().st_size
            if file_size > CONFIG['max_file_size']:
                copy_problem_file(file_path, 'large_files', f"File size: {file_size} bytes")
                error_count += 1
                processed += 1
                continue
            
            result = process_single_file(file_path, port_name, local_gender_detector)
            if result:
                results.append(result)
            processed += 1
            
            # 每处理100000个文件报告一次进度
            if processed % 100000 == 0:
                print(f"Process {process_id}: Processed {processed}/{len(file_paths)} files in {port_name}, errors: {error_count}")
                
        except RecursionError as e:
            copy_problem_file(file_path, 'recursion_error', f"RecursionError: {str(e)}")
            error_count += 1
            processed += 1
        except MemoryError as e:
            copy_problem_file(file_path, 'large_files', f"MemoryError: {str(e)}")
            error_count += 1
            processed += 1
        except Exception as e:
            error_msg = f"{type(e).__name__}: {str(e)}"
            if "recursion" in str(e).lower():
                copy_problem_file(file_path, 'recursion_error', error_msg)
            elif any(keyword in str(e).lower() for keyword in ['parse', 'xml', 'malformed']):
                copy_problem_file(file_path, 'parse_error', error_msg)
            else:
                copy_problem_file(file_path, 'other_errors', error_msg)
            error_count += 1
            processed += 1
    
    print(f"Process {process_id} completed: {processed} files, {len(results)} results, {error_count} errors")
    return results, processed, len(results), error_count

def get_file_chunks(base_path: str, chunk_size: int = 1000) -> List[Tuple]:
    """获取文件分块信息"""
    base_path = Path(base_path)
    chunks = []
    chunk_id = 0
    
    for portfolio_folder in base_path.iterdir():
        if not portfolio_folder.is_dir():
            continue
            
        # 获取文件夹中的所有XML文件
        xml_files = list(portfolio_folder.glob("*.xml"))
        if not xml_files:
            xml_files = [f for f in portfolio_folder.iterdir() if f.is_file()]  # 如果没有.xml扩展名
            
        # 将文件分块
        for i in range(0, len(xml_files), chunk_size):
            file_chunk = xml_files[i:i + chunk_size]
            chunks.append((file_chunk, portfolio_folder.name, chunk_id))
            chunk_id += 1
    
    return chunks
    
def write_results_batch(results_batch: List[Dict], output_file: str, write_header: bool = False):
    """批量写入结果到CSV文件"""
    mode = 'w' if write_header else 'a'
    with open(output_file, mode, newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['port_name', 'id', 'person_name', 'person_date', 
                                             'other_name', 'other_date', 'gender'])
        if write_header:
            writer.writeheader()
        writer.writerows(results_batch)

def signal_handler(signum, frame):
    """信号处理器"""
    print("\n收到中断信号，正在安全退出...")
    sys.exit(0)

def write_summary_report(total_processed: int, total_results: int, total_errors: int, duration: float):
    """写入处理总结报告"""
    summary_file = Path(CONFIG['problem_files_dir']) / 'processing_summary.txt'
    with open(summary_file, 'w', encoding='utf-8') as f:
        f.write(f"ORCID 姓名变化检测处理总结\n")
        f.write(f"处理时间: {datetime.now().isoformat()}\n")
        f.write(f"="*50 + "\n")
        f.write(f"总处理文件数: {total_processed:,}\n")
        f.write(f"发现姓名变化: {total_results:,}\n")
        f.write(f"错误文件数: {total_errors:,}\n")
        f.write(f"成功率: {((total_processed - total_errors) / total_processed * 100):.2f}%\n")
        f.write(f"处理时间: {duration/3600:.2f} 小时\n")
        f.write(f"平均速度: {total_processed/duration:.0f} 文件/秒\n")
        f.write(f"\n错误文件分类:\n")
        
        # 统计各类错误文件数量
        problem_dir = Path(CONFIG['problem_files_dir'])
        for error_type in ['recursion_error', 'parse_error', 'large_files', 'other_errors']:
            error_dir = problem_dir / error_type
            if error_dir.exists():
                error_files = list(error_dir.glob("*.xml"))
                f.write(f"  {error_type}: {len(error_files)} 个文件\n")

def main():
    """主函数"""
    # 注册信号处理器
    signal.signal(signal.SIGINT, signal_handler)
    signal.signal(signal.SIGTERM, signal_handler)
    
    start_time = time.time()
    
    # 设置问题文件目录
    print("设置问题文件存储目录...")
    setup_problem_files_dir()
    
    # 获取文件分块
    print("正在分析文件结构...")
    chunks = get_file_chunks(CONFIG['base_path'], CONFIG['chunk_size'])
    total_chunks = len(chunks)
    
    print(f"发现 {total_chunks} 个文件块")
    if total_chunks == 0:
        print("没有找到需要处理的文件")
        return
    
    # 初始化输出文件
    write_results_batch([], CONFIG['output_file'], write_header=True)
    
    # 统计变量
    total_processed = 0
    total_results = 0
    total_errors = 0
    results_buffer = []
    
    try:
        # 使用进程池处理
        with ProcessPoolExecutor(max_workers=CONFIG['max_workers']) as executor:
            print(f"启动 {CONFIG['max_workers']} 个工作进程...")
            print(f"问题文件将保存到: {CONFIG['problem_files_dir']}")
            
            # 提交所有任务
            future_to_chunk = {executor.submit(process_file_chunk, chunk): i 
                              for i, chunk in enumerate(chunks)}
            
            # 处理完成的任务
            for future in as_completed(future_to_chunk):
                chunk_idx = future_to_chunk[future]
                try:
                    chunk_results, chunk_processed, chunk_found, chunk_errors = future.result()
                    
                    total_processed += chunk_processed
                    total_results += chunk_found
                    total_errors += chunk_errors
                    results_buffer.extend(chunk_results)
                    
                    # 批量写入结果
                    if len(results_buffer) >= CONFIG['batch_size']:
                        write_results_batch(results_buffer, CONFIG['output_file'])
                        results_buffer = []
                    
                    # 进度报告
                    progress = (chunk_idx + 1) / total_chunks * 100
                    print(f"进度: {progress:.1f}% ({chunk_idx + 1}/{total_chunks}), "
                          f"已处理: {total_processed:,}, 发现变化: {total_results:,}, 错误: {total_errors:,}")
                    
                except Exception as e:
                    print(f"处理块 {chunk_idx} 时出错: {e}")
                    print(f"错误详情: {traceback.format_exc()}")
    
    except KeyboardInterrupt:
        print("\n用户中断程序执行")
        return
    except Exception as e:
        print(f"程序执行出错: {e}")
        print(f"错误详情: {traceback.format_exc()}")
        return
    finally:
        # 写入剩余结果
        if results_buffer:
            write_results_batch(results_buffer, CONFIG['output_file'])
    
    # 最终统计
    end_time = time.time()
    duration = end_time - start_time
    
    print("\n" + "="*60)
    print("处理完成!")
    print(f"总处理文件数: {total_processed:,}")
    print(f"发现姓名变化: {total_results:,}")
    print(f"错误文件数: {total_errors:,}")
    print(f"成功率: {((total_processed - total_errors) / total_processed * 100):.2f}%" if total_processed > 0 else "N/A")
    print(f"处理时间: {duration/3600:.1f} 小时 ({duration/60:.1f} 分钟)")
    print(f"平均速度: {total_processed/duration:.0f} 文件/秒" if duration > 0 else "N/A")
    print(f"结果已保存至: {CONFIG['output_file']}")
    print(f"问题文件已保存至: {CONFIG['problem_files_dir']}")
    print("="*60)
    
    # 写入处理总结报告
    write_summary_report(total_processed, total_results, total_errors, duration)

if __name__ == "__main__":   
    main()
# Out:
# 设置问题文件存储目录...
# 正在分析文件结构...
# 发现 2431 个文件块
# 启动 2 个工作进程...
# 问题文件将保存到: /hy-tmp/problem_xml_files
# Process 1 completed: 9980 files, 7 results, 0 errors
# 进度: 0.1% (2/2431), 已处理: 9,980, 发现变化: 7, 错误: 0
# Process 0 completed: 10000 files, 24 results, 0 errors
# 进度: 0.0% (1/2431), 已处理: 19,980, 发现变化: 31, 错误: 0
# Process 2 completed: 10000 files, 28 results, 0 errors
# 进度: 0.1% (3/2431), 已处理: 29,980, 发现变化: 59, 错误: 0
# Process 3 completed: 9856 files, 6 results, 0 errors
# 进度: 0.2% (4/2431), 已处理: 39,836, 发现变化: 65, 错误: 0
# Process 5 completed: 9863 files, 11 results, 0 errors
# 进度: 0.2% (6/2431), 已处理: 49,699, 发现变化: 76, 错误: 0
# Process 4 completed: 10000 files, 20 results, 0 errors
# 进度: 0.2% (5/2431), 已处理: 59,699, 发现变化: 96, 错误: 0
# Process 6 completed: 10000 files, 29 results, 0 errors
# 进度: 0.3% (7/2431), 已处理: 69,699, 发现变化: 125, 错误: 0
# Process 7 completed: 9992 files, 7 results, 0 errors
# 进度: 0.3% (8/2431), 已处理: 79,691, 发现变化: 132, 错误: 0
# Process 9 completed: 10000 files, 10 results, 0 errors
# 进度: 0.4% (10/2431), 已处理: 89,691, 发现变化: 142, 错误: 0
# Process 10 completed: 7 files, 0 results, 0 errors
# 进度: 0.5% (11/2431), 已处理: 89,698, 发现变化: 142, 错误: 0
# Process 8 completed: 10000 files, 28 results, 0 errors
# 进度: 0.4% (9/2431), 已处理: 99,698, 发现变化: 170, 错误: 0
# Process 11 completed: 10000 files, 22 results, 0 errors
# 进度: 0.5% (12/2431), 已处理: 109,698, 发现变化: 192, 错误: 0
# Process 13 completed: 60 files, 0 results, 0 errors
# 进度: 0.6% (14/2431), 已处理: 109,758, 发现变化: 192, 错误: 0
# Process 12 completed: 10000 files, 14 results, 0 errors
# 进度: 0.5% (13/2431), 已处理: 119,758, 发现变化: 206, 错误: 0
# Process 15 completed: 9782 files, 10 results, 0 errors
# 进度: 0.7% (16/2431), 已处理: 129,540, 发现变化: 216, 错误: 0
# Process 14 completed: 10000 files, 30 results, 0 errors
# 进度: 0.6% (15/2431), 已处理: 139,540, 发现变化: 246, 错误: 0
# Process 16 completed: 10000 files, 22 results, 0 errors
# 进度: 0.7% (17/2431), 已处理: 149,540, 发现变化: 268, 错误: 0
# Process 17 completed: 9843 files, 9 results, 0 errors
# 进度: 0.7% (18/2431), 已处理: 159,383, 发现变化: 277, 错误: 0
# Process 19 completed: 10000 files, 17 results, 0 errors
# 进度: 0.8% (20/2431), 已处理: 169,383, 发现变化: 294, 错误: 0
# Process 20 completed: 63 files, 0 results, 0 errors
# 进度: 0.9% (21/2431), 已处理: 169,446, 发现变化: 294, 错误: 0
# Process 18 completed: 10000 files, 25 results, 0 errors
# 进度: 0.8% (19/2431), 已处理: 179,446, 发现变化: 319, 错误: 0
# Process 21 completed: 10000 files, 24 results, 0 errors
# 进度: 0.9% (22/2431), 已处理: 189,446, 发现变化: 343, 错误: 0
# Process 22 completed: 9910 files, 12 results, 0 errors
# 进度: 0.9% (23/2431), 已处理: 199,356, 发现变化: 355, 错误: 0
# Process 24 completed: 10000 files, 11 results, 0 errors
# 进度: 1.0% (25/2431), 已处理: 209,356, 发现变化: 366, 错误: 0
# Process 25 completed: 2 files, 0 results, 0 errors
# 进度: 1.1% (26/2431), 已处理: 209,358, 发现变化: 366, 错误: 0
# Process 23 completed: 10000 files, 28 results, 0 errors
# 进度: 1.0% (24/2431), 已处理: 219,358, 发现变化: 394, 错误: 0
# Process 27 completed: 9997 files, 13 results, 0 errors
# 进度: 1.2% (28/2431), 已处理: 229,355, 发现变化: 407, 错误: 0
# Process 26 completed: 10000 files, 30 results, 0 errors
# 进度: 1.1% (27/2431), 已处理: 239,355, 发现变化: 437, 错误: 0
# Process 29 completed: 9917 files, 14 results, 0 errors
# 进度: 1.2% (30/2431), 已处理: 249,272, 发现变化: 451, 错误: 0
# Process 28 completed: 10000 files, 27 results, 0 errors
# 进度: 1.2% (29/2431), 已处理: 259,272, 发现变化: 478, 错误: 0
# Process 31 completed: 9931 files, 16 results, 0 errors
# 进度: 1.3% (32/2431), 已处理: 269,203, 发现变化: 494, 错误: 0
# Process 30 completed: 10000 files, 29 results, 0 errors
# 进度: 1.3% (31/2431), 已处理: 279,203, 发现变化: 523, 错误: 0
# Process 33 completed: 9862 files, 17 results, 0 errors
# 进度: 1.4% (34/2431), 已处理: 289,065, 发现变化: 540, 错误: 0
# Process 32 completed: 10000 files, 21 results, 0 errors
# 进度: 1.4% (33/2431), 已处理: 299,065, 发现变化: 561, 错误: 0
# Process 35 completed: 10000 files, 12 results, 0 errors
# 进度: 1.5% (36/2431), 已处理: 309,065, 发现变化: 573, 错误: 0
# Process 36 completed: 49 files, 0 results, 0 errors
# 进度: 1.5% (37/2431), 已处理: 309,114, 发现变化: 573, 错误: 0
# Process 34 completed: 10000 files, 23 results, 0 errors
# 进度: 1.4% (35/2431), 已处理: 319,114, 发现变化: 596, 错误: 0
# Process 38 completed: 9917 files, 21 results, 0 errors
# 进度: 1.6% (39/2431), 已处理: 329,031, 发现变化: 617, 错误: 0
# Process 37 completed: 10000 files, 30 results, 0 errors
# 进度: 1.6% (38/2431), 已处理: 339,031, 发现变化: 647, 错误: 0
# Process 40 completed: 10000 files, 9 results, 0 errors
# 进度: 1.7% (41/2431), 已处理: 349,031, 发现变化: 656, 错误: 0
# Process 41 completed: 3 files, 0 results, 0 errors
# 进度: 1.7% (42/2431), 已处理: 349,034, 发现变化: 656, 错误: 0
# Process 39 completed: 10000 files, 19 results, 0 errors
# 进度: 1.6% (40/2431), 已处理: 359,034, 发现变化: 675, 错误: 0
# Process 43 completed: 9896 files, 18 results, 0 errors
# 进度: 1.8% (44/2431), 已处理: 368,930, 发现变化: 693, 错误: 0
# Process 42 completed: 10000 files, 24 results, 0 errors
# 进度: 1.8% (43/2431), 已处理: 378,930, 发现变化: 717, 错误: 0
# Process 45 completed: 10000 files, 9 results, 0 errors
# 进度: 1.9% (46/2431), 已处理: 388,930, 发现变化: 726, 错误: 0
# Process 46 completed: 7 files, 0 results, 0 errors
# 进度: 1.9% (47/2431), 已处理: 388,937, 发现变化: 726, 错误: 0
# Process 44 completed: 10000 files, 18 results, 1 errors
# 进度: 1.9% (45/2431), 已处理: 398,937, 发现变化: 744, 错误: 1
# Process 48 completed: 10000 files, 15 results, 0 errors
# 进度: 2.0% (49/2431), 已处理: 408,937, 发现变化: 759, 错误: 1
# Process 49 completed: 3 files, 0 results, 0 errors
# 进度: 2.1% (50/2431), 已处理: 408,940, 发现变化: 759, 错误: 1
# Process 47 completed: 10000 files, 21 results, 1 errors
# 进度: 2.0% (48/2431), 已处理: 418,940, 发现变化: 780, 错误: 2
# Process 51 completed: 9904 files, 8 results, 0 errors
# 进度: 2.1% (52/2431), 已处理: 428,844, 发现变化: 788, 错误: 2
# Process 50 completed: 10000 files, 22 results, 0 errors
# 进度: 2.1% (51/2431), 已处理: 438,844, 发现变化: 810, 错误: 2
# Process 52 completed: 10000 files, 28 results, 0 errors
# 进度: 2.2% (53/2431), 已处理: 448,844, 发现变化: 838, 错误: 2
# Process 53 completed: 9970 files, 13 results, 0 errors
# 进度: 2.2% (54/2431), 已处理: 458,814, 发现变化: 851, 错误: 2
# Process 55 completed: 9939 files, 8 results, 0 errors
# 进度: 2.3% (56/2431), 已处理: 468,753, 发现变化: 859, 错误: 2
# Process 54 completed: 10000 files, 22 results, 0 errors
# 进度: 2.3% (55/2431), 已处理: 478,753, 发现变化: 881, 错误: 2
# Process 57 completed: 9883 files, 7 results, 0 errors
# 进度: 2.4% (58/2431), 已处理: 488,636, 发现变化: 888, 错误: 2
# Process 56 completed: 10000 files, 32 results, 0 errors
# 进度: 2.3% (57/2431), 已处理: 498,636, 发现变化: 920, 错误: 2
# Process 59 completed: 9910 files, 15 results, 0 errors
# 进度: 2.5% (60/2431), 已处理: 508,546, 发现变化: 935, 错误: 2
# Process 58 completed: 10000 files, 22 results, 0 errors
# 进度: 2.4% (59/2431), 已处理: 518,546, 发现变化: 957, 错误: 2
# Process 61 completed: 9904 files, 15 results, 2 errors
# 进度: 2.6% (62/2431), 已处理: 528,450, 发现变化: 972, 错误: 4
# Process 60 completed: 10000 files, 29 results, 0 errors
# 进度: 2.5% (61/2431), 已处理: 538,450, 发现变化: 1,001, 错误: 4
# Process 63 completed: 9803 files, 18 results, 0 errors
# 进度: 2.6% (64/2431), 已处理: 548,253, 发现变化: 1,019, 错误: 4
# Process 62 completed: 10000 files, 21 results, 0 errors
# 进度: 2.6% (63/2431), 已处理: 558,253, 发现变化: 1,040, 错误: 4
# Process 65 completed: 9874 files, 9 results, 0 errors
# 进度: 2.7% (66/2431), 已处理: 568,127, 发现变化: 1,049, 错误: 4
# Process 64 completed: 10000 files, 23 results, 0 errors
# 进度: 2.7% (65/2431), 已处理: 578,127, 发现变化: 1,072, 错误: 4
# Process 67 completed: 9943 files, 9 results, 0 errors
# 进度: 2.8% (68/2431), 已处理: 588,070, 发现变化: 1,081, 错误: 4
# Process 66 completed: 10000 files, 19 results, 0 errors
# 进度: 2.8% (67/2431), 已处理: 598,070, 发现变化: 1,100, 错误: 4
# Process 69 completed: 10000 files, 13 results, 0 errors
# 进度: 2.9% (70/2431), 已处理: 608,070, 发现变化: 1,113, 错误: 4
# Process 70 completed: 11 files, 0 results, 0 errors
# 进度: 2.9% (71/2431), 已处理: 608,081, 发现变化: 1,113, 错误: 4
# Process 68 completed: 10000 files, 28 results, 0 errors
# 进度: 2.8% (69/2431), 已处理: 618,081, 发现变化: 1,141, 错误: 4
# Process 72 completed: 9941 files, 6 results, 0 errors
# 进度: 3.0% (73/2431), 已处理: 628,022, 发现变化: 1,147, 错误: 4
# Process 71 completed: 10000 files, 24 results, 0 errors
# 进度: 3.0% (72/2431), 已处理: 638,022, 发现变化: 1,171, 错误: 4
# Process 74 completed: 9988 files, 21 results, 1 errors
# 进度: 3.1% (75/2431), 已处理: 648,010, 发现变化: 1,192, 错误: 5
# Process 73 completed: 10000 files, 20 results, 1 errors
# 进度: 3.0% (74/2431), 已处理: 658,010, 发现变化: 1,212, 错误: 6
# Process 76 completed: 9880 files, 8 results, 0 errors
# 进度: 3.2% (77/2431), 已处理: 667,890, 发现变化: 1,220, 错误: 6
# Process 75 completed: 10000 files, 25 results, 0 errors
# 进度: 3.1% (76/2431), 已处理: 677,890, 发现变化: 1,245, 错误: 6
# Process 78 completed: 10000 files, 14 results, 0 errors
# 进度: 3.2% (79/2431), 已处理: 687,890, 发现变化: 1,259, 错误: 6
# Process 79 completed: 23 files, 0 results, 0 errors
# 进度: 3.3% (80/2431), 已处理: 687,913, 发现变化: 1,259, 错误: 6
# Process 77 completed: 10000 files, 27 results, 0 errors
# 进度: 3.2% (78/2431), 已处理: 697,913, 发现变化: 1,286, 错误: 6
# Process 80 completed: 10000 files, 17 results, 0 errors
# 进度: 3.3% (81/2431), 已处理: 707,913, 发现变化: 1,303, 错误: 6
# Process 81 completed: 9890 files, 12 results, 0 errors
# 进度: 3.4% (82/2431), 已处理: 717,803, 发现变化: 1,315, 错误: 6
# Process 83 completed: 9881 files, 13 results, 0 errors
# 进度: 3.5% (84/2431), 已处理: 727,684, 发现变化: 1,328, 错误: 6
# Process 82 completed: 10000 files, 29 results, 0 errors
# 进度: 3.4% (83/2431), 已处理: 737,684, 发现变化: 1,357, 错误: 6
# Process 85 completed: 9865 files, 17 results, 0 errors
# 进度: 3.5% (86/2431), 已处理: 747,549, 发现变化: 1,374, 错误: 6
# Process 84 completed: 10000 files, 18 results, 0 errors
# 进度: 3.5% (85/2431), 已处理: 757,549, 发现变化: 1,392, 错误: 6
# Process 87 completed: 9812 files, 11 results, 0 errors
# 进度: 3.6% (88/2431), 已处理: 767,361, 发现变化: 1,403, 错误: 6
# Process 86 completed: 10000 files, 27 results, 1 errors
# 进度: 3.6% (87/2431), 已处理: 777,361, 发现变化: 1,430, 错误: 7
# Process 89 completed: 9746 files, 10 results, 0 errors
# 进度: 3.7% (90/2431), 已处理: 787,107, 发现变化: 1,440, 错误: 7
# Process 88 completed: 10000 files, 28 results, 0 errors
# 进度: 3.7% (89/2431), 已处理: 797,107, 发现变化: 1,468, 错误: 7
# Process 91 completed: 9895 files, 12 results, 0 errors
# 进度: 3.8% (92/2431), 已处理: 807,002, 发现变化: 1,480, 错误: 7
# Process 90 completed: 10000 files, 30 results, 0 errors
# 进度: 3.7% (91/2431), 已处理: 817,002, 发现变化: 1,510, 错误: 7
# Process 93 completed: 9967 files, 16 results, 0 errors
# 进度: 3.9% (94/2431), 已处理: 826,969, 发现变化: 1,526, 错误: 7
# Process 92 completed: 10000 files, 30 results, 0 errors
# 进度: 3.8% (93/2431), 已处理: 836,969, 发现变化: 1,556, 错误: 7
# Process 95 completed: 9990 files, 18 results, 0 errors
# 进度: 3.9% (96/2431), 已处理: 846,959, 发现变化: 1,574, 错误: 7
# Process 94 completed: 10000 files, 23 results, 1 errors
# 进度: 3.9% (95/2431), 已处理: 856,959, 发现变化: 1,597, 错误: 8
# Process 97 completed: 10000 files, 13 results, 0 errors
# 进度: 4.0% (98/2431), 已处理: 866,959, 发现变化: 1,610, 错误: 8
# Process 98 completed: 25 files, 0 results, 0 errors
# 进度: 4.1% (99/2431), 已处理: 866,984, 发现变化: 1,610, 错误: 8
# Process 96 completed: 10000 files, 18 results, 0 errors
# 进度: 4.0% (97/2431), 已处理: 876,984, 发现变化: 1,628, 错误: 8
# Process 100 completed: 10000 files, 16 results, 1 errors
# 进度: 4.2% (101/2431), 已处理: 886,984, 发现变化: 1,644, 错误: 9
# Process 101 completed: 71 files, 0 results, 0 errors
# 进度: 4.2% (102/2431), 已处理: 887,055, 发现变化: 1,644, 错误: 9
# Process 99 completed: 10000 files, 26 results, 0 errors
# 进度: 4.1% (100/2431), 已处理: 897,055, 发现变化: 1,670, 错误: 9
# Process 103 completed: 9860 files, 10 results, 0 errors
# 进度: 4.3% (104/2431), 已处理: 906,915, 发现变化: 1,680, 错误: 9
# Process 102 completed: 10000 files, 21 results, 1 errors
# 进度: 4.2% (103/2431), 已处理: 916,915, 发现变化: 1,701, 错误: 10
# Process 105 completed: 9896 files, 11 results, 0 errors
# 进度: 4.4% (106/2431), 已处理: 926,811, 发现变化: 1,712, 错误: 10
# Process 104 completed: 10000 files, 17 results, 0 errors
# 进度: 4.3% (105/2431), 已处理: 936,811, 发现变化: 1,729, 错误: 10
# Process 107 completed: 9832 files, 17 results, 1 errors
# 进度: 4.4% (108/2431), 已处理: 946,643, 发现变化: 1,746, 错误: 11
# Process 106 completed: 10000 files, 20 results, 1 errors
# 进度: 4.4% (107/2431), 已处理: 956,643, 发现变化: 1,766, 错误: 12
# Process 108 completed: 10000 files, 19 results, 0 errors
# 进度: 4.5% (109/2431), 已处理: 966,643, 发现变化: 1,785, 错误: 12
# Process 109 completed: 9961 files, 14 results, 0 errors
# 进度: 4.5% (110/2431), 已处理: 976,604, 发现变化: 1,799, 错误: 12
# Process 111 completed: 9927 files, 15 results, 0 errors
# 进度: 4.6% (112/2431), 已处理: 986,531, 发现变化: 1,814, 错误: 12
# Process 110 completed: 10000 files, 17 results, 0 errors
# 进度: 4.6% (111/2431), 已处理: 996,531, 发现变化: 1,831, 错误: 12
# Process 113 completed: 10000 files, 17 results, 0 errors
# 进度: 4.7% (114/2431), 已处理: 1,006,531, 发现变化: 1,848, 错误: 12
# Process 114 completed: 13 files, 0 results, 0 errors
# 进度: 4.7% (115/2431), 已处理: 1,006,544, 发现变化: 1,848, 错误: 12
# Process 112 completed: 10000 files, 21 results, 0 errors
# 进度: 4.6% (113/2431), 已处理: 1,016,544, 发现变化: 1,869, 错误: 12
# Process 116 completed: 9857 files, 14 results, 1 errors
# 进度: 4.8% (117/2431), 已处理: 1,026,401, 发现变化: 1,883, 错误: 13
# Process 115 completed: 10000 files, 28 results, 1 errors
# 进度: 4.8% (116/2431), 已处理: 1,036,401, 发现变化: 1,911, 错误: 14
# Process 118 completed: 10000 files, 15 results, 0 errors
# 进度: 4.9% (119/2431), 已处理: 1,046,401, 发现变化: 1,926, 错误: 14
# Process 119 completed: 37 files, 0 results, 0 errors
# 进度: 4.9% (120/2431), 已处理: 1,046,438, 发现变化: 1,926, 错误: 14
# Process 117 completed: 10000 files, 25 results, 0 errors
# 进度: 4.9% (118/2431), 已处理: 1,056,438, 发现变化: 1,951, 错误: 14
# Process 120 completed: 10000 files, 22 results, 0 errors
# Process 121 completed: 9941 files, 16 results, 0 errors
# 进度: 5.0% (121/2431), 已处理: 1,066,438, 发现变化: 1,973, 错误: 14
# 进度: 5.0% (122/2431), 已处理: 1,076,379, 发现变化: 1,989, 错误: 14
# Process 123 completed: 9830 files, 10 results, 0 errors
# 进度: 5.1% (124/2431), 已处理: 1,086,209, 发现变化: 1,999, 错误: 14
# Process 122 completed: 10000 files, 28 results, 0 errors
# 进度: 5.1% (123/2431), 已处理: 1,096,209, 发现变化: 2,027, 错误: 14
# Process 124 completed: 10000 files, 20 results, 0 errors
# 进度: 5.1% (125/2431), 已处理: 1,106,209, 发现变化: 2,047, 错误: 14
# Process 125 completed: 9952 files, 9 results, 0 errors
# 进度: 5.2% (126/2431), 已处理: 1,116,161, 发现变化: 2,056, 错误: 14
# Process 127 completed: 9930 files, 23 results, 0 errors
# 进度: 5.3% (128/2431), 已处理: 1,126,091, 发现变化: 2,079, 错误: 14
# Process 126 completed: 10000 files, 25 results, 1 errors
# 进度: 5.2% (127/2431), 已处理: 1,136,091, 发现变化: 2,104, 错误: 15
# Process 128 completed: 10000 files, 20 results, 0 errors
# 进度: 5.3% (129/2431), 已处理: 1,146,091, 发现变化: 2,124, 错误: 15
# Process 130 completed: 15 files, 0 results, 0 errors
# 进度: 5.4% (131/2431), 已处理: 1,146,106, 发现变化: 2,124, 错误: 15
# Process 129 completed: 10000 files, 24 results, 0 errors
# 进度: 5.3% (130/2431), 已处理: 1,156,106, 发现变化: 2,148, 错误: 15
# Process 132 completed: 9775 files, 15 results, 0 errors
# 进度: 5.5% (133/2431), 已处理: 1,165,881, 发现变化: 2,163, 错误: 15
# Process 131 completed: 10000 files, 28 results, 0 errors
# 进度: 5.4% (132/2431), 已处理: 1,175,881, 发现变化: 2,191, 错误: 15
# Process 134 completed: 10000 files, 10 results, 1 errors
# 进度: 5.6% (135/2431), 已处理: 1,185,881, 发现变化: 2,201, 错误: 16
# Process 135 completed: 45 files, 0 results, 0 errors
# 进度: 5.6% (136/2431), 已处理: 1,185,926, 发现变化: 2,201, 错误: 16
# Process 133 completed: 10000 files, 24 results, 0 errors
# 进度: 5.5% (134/2431), 已处理: 1,195,926, 发现变化: 2,225, 错误: 16
# Process 137 completed: 9934 files, 16 results, 0 errors
# 进度: 5.7% (138/2431), 已处理: 1,205,860, 发现变化: 2,241, 错误: 16
# Process 136 completed: 10000 files, 30 results, 0 errors
# 进度: 5.6% (137/2431), 已处理: 1,215,860, 发现变化: 2,271, 错误: 16
# Process 139 completed: 9949 files, 14 results, 0 errors
# 进度: 5.8% (140/2431), 已处理: 1,225,809, 发现变化: 2,285, 错误: 16
# Process 138 completed: 10000 files, 14 results, 0 errors
# 进度: 5.7% (139/2431), 已处理: 1,235,809, 发现变化: 2,299, 错误: 16
# Process 141 completed: 9932 files, 13 results, 0 errors
# 进度: 5.8% (142/2431), 已处理: 1,245,741, 发现变化: 2,312, 错误: 16
# Process 140 completed: 10000 files, 34 results, 0 errors
# 进度: 5.8% (141/2431), 已处理: 1,255,741, 发现变化: 2,346, 错误: 16
# Process 143 completed: 10000 files, 21 results, 0 errors
# 进度: 5.9% (144/2431), 已处理: 1,265,741, 发现变化: 2,367, 错误: 16
# Process 142 completed: 10000 files, 25 results, 0 errors
# 进度: 5.9% (143/2431), 已处理: 1,275,741, 发现变化: 2,392, 错误: 16
# Process 145 completed: 10000 files, 15 results, 1 errors
# 进度: 6.0% (146/2431), 已处理: 1,285,741, 发现变化: 2,407, 错误: 17
# Process 146 completed: 71 files, 0 results, 0 errors
# 进度: 6.0% (147/2431), 已处理: 1,285,812, 发现变化: 2,407, 错误: 17
# Process 144 completed: 10000 files, 24 results, 0 errors
# 进度: 6.0% (145/2431), 已处理: 1,295,812, 发现变化: 2,431, 错误: 17
# Process 148 completed: 9832 files, 16 results, 0 errors
# 进度: 6.1% (149/2431), 已处理: 1,305,644, 发现变化: 2,447, 错误: 17
# Process 147 completed: 10000 files, 22 results, 0 errors
# 进度: 6.1% (148/2431), 已处理: 1,315,644, 发现变化: 2,469, 错误: 17
# Process 150 completed: 9959 files, 20 results, 0 errors
# 进度: 6.2% (151/2431), 已处理: 1,325,603, 发现变化: 2,489, 错误: 17
# Process 149 completed: 10000 files, 34 results, 0 errors
# 进度: 6.2% (150/2431), 已处理: 1,335,603, 发现变化: 2,523, 错误: 17
# Process 152 completed: 9955 files, 20 results, 0 errors
# 进度: 6.3% (153/2431), 已处理: 1,345,558, 发现变化: 2,543, 错误: 17
# Process 151 completed: 10000 files, 26 results, 0 errors
# 进度: 6.3% (152/2431), 已处理: 1,355,558, 发现变化: 2,569, 错误: 17
# Process 154 completed: 9906 files, 9 results, 0 errors
# 进度: 6.4% (155/2431), 已处理: 1,365,464, 发现变化: 2,578, 错误: 17
# Process 153 completed: 10000 files, 26 results, 0 errors
# 进度: 6.3% (154/2431), 已处理: 1,375,464, 发现变化: 2,604, 错误: 17
# Process 156 completed: 9875 files, 15 results, 1 errors
# 进度: 6.5% (157/2431), 已处理: 1,385,339, 发现变化: 2,619, 错误: 18
# Process 155 completed: 10000 files, 21 results, 1 errors
# 进度: 6.4% (156/2431), 已处理: 1,395,339, 发现变化: 2,640, 错误: 19
# Process 158 completed: 10000 files, 15 results, 0 errors
# 进度: 6.5% (159/2431), 已处理: 1,405,339, 发现变化: 2,655, 错误: 19
# Process 159 completed: 51 files, 0 results, 0 errors
# 进度: 6.6% (160/2431), 已处理: 1,405,390, 发现变化: 2,655, 错误: 19
# Process 157 completed: 10000 files, 27 results, 0 errors
# 进度: 6.5% (158/2431), 已处理: 1,415,390, 发现变化: 2,682, 错误: 19
# Process 161 completed: 9844 files, 11 results, 0 errors
# 进度: 6.7% (162/2431), 已处理: 1,425,234, 发现变化: 2,693, 错误: 19
# Process 160 completed: 10000 files, 24 results, 1 errors
# 进度: 6.6% (161/2431), 已处理: 1,435,234, 发现变化: 2,717, 错误: 20
# Process 163 completed: 10000 files, 16 results, 0 errors
# 进度: 6.7% (164/2431), 已处理: 1,445,234, 发现变化: 2,733, 错误: 20
# Process 164 completed: 9 files, 0 results, 0 errors
# 进度: 6.8% (165/2431), 已处理: 1,445,243, 发现变化: 2,733, 错误: 20
# Process 162 completed: 10000 files, 27 results, 0 errors
# 进度: 6.7% (163/2431), 已处理: 1,455,243, 发现变化: 2,760, 错误: 20
# Process 166 completed: 9931 files, 11 results, 1 errors
# 进度: 6.9% (167/2431), 已处理: 1,465,174, 发现变化: 2,771, 错误: 21
# Process 165 completed: 10000 files, 24 results, 1 errors
# 进度: 6.8% (166/2431), 已处理: 1,475,174, 发现变化: 2,795, 错误: 22
# Process 168 completed: 9936 files, 11 results, 0 errors
# 进度: 7.0% (169/2431), 已处理: 1,485,110, 发现变化: 2,806, 错误: 22
# Process 167 completed: 10000 files, 22 results, 0 errors
# 进度: 6.9% (168/2431), 已处理: 1,495,110, 发现变化: 2,828, 错误: 22
# Process 170 completed: 9895 files, 19 results, 0 errors
# 进度: 7.0% (171/2431), 已处理: 1,505,005, 发现变化: 2,847, 错误: 22
# Process 169 completed: 10000 files, 26 results, 0 errors
# 进度: 7.0% (170/2431), 已处理: 1,515,005, 发现变化: 2,873, 错误: 22
# Process 172 completed: 9897 files, 6 results, 0 errors
# 进度: 7.1% (173/2431), 已处理: 1,524,902, 发现变化: 2,879, 错误: 22
# Process 171 completed: 10000 files, 21 results, 0 errors
# 进度: 7.1% (172/2431), 已处理: 1,534,902, 发现变化: 2,900, 错误: 22
# Process 174 completed: 9951 files, 10 results, 0 errors
# 进度: 7.2% (175/2431), 已处理: 1,544,853, 发现变化: 2,910, 错误: 22
# Process 173 completed: 10000 files, 27 results, 1 errors
# 进度: 7.2% (174/2431), 已处理: 1,554,853, 发现变化: 2,937, 错误: 23
# Process 175 completed: 10000 files, 29 results, 0 errors
# 进度: 7.2% (176/2431), 已处理: 1,564,853, 发现变化: 2,966, 错误: 23
# Process 176 completed: 9885 files, 12 results, 0 errors
# 进度: 7.3% (177/2431), 已处理: 1,574,738, 发现变化: 2,978, 错误: 23
# Process 178 completed: 10000 files, 10 results, 0 errors
# 进度: 7.4% (179/2431), 已处理: 1,584,738, 发现变化: 2,988, 错误: 23
# Process 179 completed: 34 files, 0 results, 0 errors
# 进度: 7.4% (180/2431), 已处理: 1,584,772, 发现变化: 2,988, 错误: 23
# Process 177 completed: 10000 files, 23 results, 0 errors
# 进度: 7.3% (178/2431), 已处理: 1,594,772, 发现变化: 3,011, 错误: 23
# Process 181 completed: 9893 files, 11 results, 0 errors
# 进度: 7.5% (182/2431), 已处理: 1,604,665, 发现变化: 3,022, 错误: 23
# Process 180 completed: 10000 files, 23 results, 0 errors
# 进度: 7.4% (181/2431), 已处理: 1,614,665, 发现变化: 3,045, 错误: 23
# Process 183 completed: 9907 files, 13 results, 1 errors
# 进度: 7.6% (184/2431), 已处理: 1,624,572, 发现变化: 3,058, 错误: 24
# Process 182 completed: 10000 files, 28 results, 0 errors
# 进度: 7.5% (183/2431), 已处理: 1,634,572, 发现变化: 3,086, 错误: 24
# Process 185 completed: 9937 files, 16 results, 0 errors
# 进度: 7.7% (186/2431), 已处理: 1,644,509, 发现变化: 3,102, 错误: 24
# Process 184 completed: 10000 files, 27 results, 0 errors
# 进度: 7.6% (185/2431), 已处理: 1,654,509, 发现变化: 3,129, 错误: 24
# Process 187 completed: 9919 files, 14 results, 0 errors
# 进度: 7.7% (188/2431), 已处理: 1,664,428, 发现变化: 3,143, 错误: 24
# Process 186 completed: 10000 files, 32 results, 0 errors
# 进度: 7.7% (187/2431), 已处理: 1,674,428, 发现变化: 3,175, 错误: 24
# Process 189 completed: 9954 files, 6 results, 0 errors
# 进度: 7.8% (190/2431), 已处理: 1,684,382, 发现变化: 3,181, 错误: 24
# Process 188 completed: 10000 files, 22 results, 0 errors
# 进度: 7.8% (189/2431), 已处理: 1,694,382, 发现变化: 3,203, 错误: 24
# Process 191 completed: 10000 files, 12 results, 0 errors
# 进度: 7.9% (192/2431), 已处理: 1,704,382, 发现变化: 3,215, 错误: 24
# Process 192 completed: 1 files, 0 results, 0 errors
# 进度: 7.9% (193/2431), 已处理: 1,704,383, 发现变化: 3,215, 错误: 24
# Process 190 completed: 10000 files, 28 results, 0 errors
# 进度: 7.9% (191/2431), 已处理: 1,714,383, 发现变化: 3,243, 错误: 24
# Process 194 completed: 9986 files, 10 results, 0 errors
# 进度: 8.0% (195/2431), 已处理: 1,724,369, 发现变化: 3,253, 错误: 24
# Process 193 completed: 10000 files, 34 results, 0 errors
# 进度: 8.0% (194/2431), 已处理: 1,734,369, 发现变化: 3,287, 错误: 24
# Process 196 completed: 9849 files, 5 results, 0 errors
# 进度: 8.1% (197/2431), 已处理: 1,744,218, 发现变化: 3,292, 错误: 24
# Process 195 completed: 10000 files, 28 results, 0 errors
# 进度: 8.1% (196/2431), 已处理: 1,754,218, 发现变化: 3,320, 错误: 24
# Process 198 completed: 9938 files, 9 results, 0 errors
# 进度: 8.2% (199/2431), 已处理: 1,764,156, 发现变化: 3,329, 错误: 24
# Process 197 completed: 10000 files, 28 results, 0 errors
# 进度: 8.1% (198/2431), 已处理: 1,774,156, 发现变化: 3,357, 错误: 24
# Process 200 completed: 9899 files, 16 results, 0 errors
# 进度: 8.3% (201/2431), 已处理: 1,784,055, 发现变化: 3,373, 错误: 24
# Process 199 completed: 10000 files, 40 results, 0 errors
# 进度: 8.2% (200/2431), 已处理: 1,794,055, 发现变化: 3,413, 错误: 24
# Process 202 completed: 9964 files, 8 results, 0 errors
# 进度: 8.4% (203/2431), 已处理: 1,804,019, 发现变化: 3,421, 错误: 24
# Process 201 completed: 10000 files, 22 results, 0 errors
# 进度: 8.3% (202/2431), 已处理: 1,814,019, 发现变化: 3,443, 错误: 24
# Process 204 completed: 9929 files, 15 results, 1 errors
# 进度: 8.4% (205/2431), 已处理: 1,823,948, 发现变化: 3,458, 错误: 25
# Process 203 completed: 10000 files, 30 results, 0 errors
# 进度: 8.4% (204/2431), 已处理: 1,833,948, 发现变化: 3,488, 错误: 25
# Process 206 completed: 10000 files, 13 results, 0 errors
# 进度: 8.5% (207/2431), 已处理: 1,843,948, 发现变化: 3,501, 错误: 25
# Process 207 completed: 11 files, 0 results, 0 errors
# 进度: 8.6% (208/2431), 已处理: 1,843,959, 发现变化: 3,501, 错误: 25
# Process 205 completed: 10000 files, 25 results, 0 errors
# 进度: 8.5% (206/2431), 已处理: 1,853,959, 发现变化: 3,526, 错误: 25
# Process 208 completed: 10000 files, 19 results, 0 errors
# 进度: 8.6% (209/2431), 已处理: 1,863,959, 发现变化: 3,545, 错误: 25
# Process 209 completed: 9966 files, 15 results, 0 errors
# 进度: 8.6% (210/2431), 已处理: 1,873,925, 发现变化: 3,560, 错误: 25
# Process 211 completed: 9917 files, 16 results, 0 errors
# 进度: 8.7% (212/2431), 已处理: 1,883,842, 发现变化: 3,576, 错误: 25
# Process 210 completed: 10000 files, 25 results, 0 errors
# 进度: 8.7% (211/2431), 已处理: 1,893,842, 发现变化: 3,601, 错误: 25
# Process 212 completed: 10000 files, 35 results, 0 errors
# 进度: 8.8% (213/2431), 已处理: 1,903,842, 发现变化: 3,636, 错误: 25
# Process 213 completed: 9821 files, 15 results, 0 errors
# 进度: 8.8% (214/2431), 已处理: 1,913,663, 发现变化: 3,651, 错误: 25
# Process 215 completed: 9947 files, 15 results, 0 errors
# 进度: 8.9% (216/2431), 已处理: 1,923,610, 发现变化: 3,666, 错误: 25
# Process 214 completed: 10000 files, 29 results, 0 errors
# 进度: 8.8% (215/2431), 已处理: 1,933,610, 发现变化: 3,695, 错误: 25
# Process 216 completed: 10000 files, 32 results, 0 errors
# 进度: 8.9% (217/2431), 已处理: 1,943,610, 发现变化: 3,727, 错误: 25
# Process 217 completed: 9856 files, 10 results, 0 errors
# 进度: 9.0% (218/2431), 已处理: 1,953,466, 发现变化: 3,737, 错误: 25
# Process 219 completed: 10000 files, 22 results, 2 errors
# 进度: 9.0% (220/2431), 已处理: 1,963,466, 发现变化: 3,759, 错误: 27
# Process 220 completed: 9 files, 0 results, 0 errors
# 进度: 9.1% (221/2431), 已处理: 1,963,475, 发现变化: 3,759, 错误: 27
# Process 218 completed: 10000 files, 33 results, 1 errors
# 进度: 9.0% (219/2431), 已处理: 1,973,475, 发现变化: 3,792, 错误: 28
# Process 222 completed: 9996 files, 11 results, 2 errors
# 进度: 9.2% (223/2431), 已处理: 1,983,471, 发现变化: 3,803, 错误: 30
# Process 221 completed: 10000 files, 24 results, 0 errors
# 进度: 9.1% (222/2431), 已处理: 1,993,471, 发现变化: 3,827, 错误: 30
# Process 224 completed: 10000 files, 15 results, 1 errors
# 进度: 9.3% (225/2431), 已处理: 2,003,471, 发现变化: 3,842, 错误: 31
# Process 225 completed: 59 files, 0 results, 0 errors
# 进度: 9.3% (226/2431), 已处理: 2,003,530, 发现变化: 3,842, 错误: 31
# Process 223 completed: 10000 files, 25 results, 0 errors
# 进度: 9.2% (224/2431), 已处理: 2,013,530, 发现变化: 3,867, 错误: 31
# Process 227 completed: 9839 files, 12 results, 0 errors
# 进度: 9.4% (228/2431), 已处理: 2,023,369, 发现变化: 3,879, 错误: 31
# Process 226 completed: 10000 files, 24 results, 0 errors
# 进度: 9.3% (227/2431), 已处理: 2,033,369, 发现变化: 3,903, 错误: 31
# Process 229 completed: 9936 files, 10 results, 0 errors
# 进度: 9.5% (230/2431), 已处理: 2,043,305, 发现变化: 3,913, 错误: 31
# Process 228 completed: 10000 files, 28 results, 0 errors
# 进度: 9.4% (229/2431), 已处理: 2,053,305, 发现变化: 3,941, 错误: 31
# Process 231 completed: 9934 files, 14 results, 0 errors
# 进度: 9.5% (232/2431), 已处理: 2,063,239, 发现变化: 3,955, 错误: 31
# Process 230 completed: 10000 files, 26 results, 0 errors
# 进度: 9.5% (231/2431), 已处理: 2,073,239, 发现变化: 3,981, 错误: 31
# Process 233 completed: 9894 files, 14 results, 0 errors
# 进度: 9.6% (234/2431), 已处理: 2,083,133, 发现变化: 3,995, 错误: 31
# Process 232 completed: 10000 files, 25 results, 1 errors
# 进度: 9.6% (233/2431), 已处理: 2,093,133, 发现变化: 4,020, 错误: 32
# Process 235 completed: 9968 files, 15 results, 1 errors
# 进度: 9.7% (236/2431), 已处理: 2,103,101, 发现变化: 4,035, 错误: 33
# Process 234 completed: 10000 files, 20 results, 1 errors
# 进度: 9.7% (235/2431), 已处理: 2,113,101, 发现变化: 4,055, 错误: 34
# Process 237 completed: 10000 files, 16 results, 1 errors
# 进度: 9.8% (238/2431), 已处理: 2,123,101, 发现变化: 4,071, 错误: 35
# Process 238 completed: 73 files, 0 results, 0 errors
# 进度: 9.8% (239/2431), 已处理: 2,123,174, 发现变化: 4,071, 错误: 35
# Process 236 completed: 10000 files, 25 results, 0 errors
# 进度: 9.7% (237/2431), 已处理: 2,133,174, 发现变化: 4,096, 错误: 35
# Process 240 completed: 9931 files, 6 results, 2 errors
# 进度: 9.9% (241/2431), 已处理: 2,143,105, 发现变化: 4,102, 错误: 37
# Process 239 completed: 10000 files, 21 results, 0 errors
# 进度: 9.9% (240/2431), 已处理: 2,153,105, 发现变化: 4,123, 错误: 37
# Process 242 completed: 9842 files, 10 results, 2 errors
# 进度: 10.0% (243/2431), 已处理: 2,162,947, 发现变化: 4,133, 错误: 39
# Process 241 completed: 10000 files, 29 results, 0 errors
# 进度: 10.0% (242/2431), 已处理: 2,172,947, 发现变化: 4,162, 错误: 39
# Process 244 completed: 9965 files, 11 results, 0 errors
# 进度: 10.1% (245/2431), 已处理: 2,182,912, 发现变化: 4,173, 错误: 39
# Process 243 completed: 10000 files, 19 results, 0 errors
# 进度: 10.0% (244/2431), 已处理: 2,192,912, 发现变化: 4,192, 错误: 39
# Process 245 completed: 10000 files, 35 results, 0 errors
# 进度: 10.1% (246/2431), 已处理: 2,202,912, 发现变化: 4,227, 错误: 39
# Process 246 completed: 9988 files, 9 results, 0 errors
# 进度: 10.2% (247/2431), 已处理: 2,212,900, 发现变化: 4,236, 错误: 39
# Process 248 completed: 9866 files, 14 results, 0 errors
# 进度: 10.2% (249/2431), 已处理: 2,222,766, 发现变化: 4,250, 错误: 39
# Process 247 completed: 10000 files, 22 results, 0 errors
# 进度: 10.2% (248/2431), 已处理: 2,232,766, 发现变化: 4,272, 错误: 39
# Process 250 completed: 9832 files, 9 results, 0 errors
# 进度: 10.3% (251/2431), 已处理: 2,242,598, 发现变化: 4,281, 错误: 39
# Process 249 completed: 10000 files, 26 results, 1 errors
# 进度: 10.3% (250/2431), 已处理: 2,252,598, 发现变化: 4,307, 错误: 40
# Process 252 completed: 9908 files, 12 results, 1 errors
# 进度: 10.4% (253/2431), 已处理: 2,262,506, 发现变化: 4,319, 错误: 41
# Process 251 completed: 10000 files, 22 results, 0 errors
# 进度: 10.4% (252/2431), 已处理: 2,272,506, 发现变化: 4,341, 错误: 41
# Process 254 completed: 9913 files, 12 results, 0 errors
# 进度: 10.5% (255/2431), 已处理: 2,282,419, 发现变化: 4,353, 错误: 41
# Process 253 completed: 10000 files, 20 results, 0 errors
# 进度: 10.4% (254/2431), 已处理: 2,292,419, 发现变化: 4,373, 错误: 41
# Process 256 completed: 10000 files, 10 results, 0 errors
# 进度: 10.6% (257/2431), 已处理: 2,302,419, 发现变化: 4,383, 错误: 41
# Process 257 completed: 10 files, 0 results, 0 errors
# 进度: 10.6% (258/2431), 已处理: 2,302,429, 发现变化: 4,383, 错误: 41
# Process 255 completed: 10000 files, 24 results, 1 errors
# 进度: 10.5% (256/2431), 已处理: 2,312,429, 发现变化: 4,407, 错误: 42
# Process 259 completed: 10000 files, 9 results, 0 errors
# 进度: 10.7% (260/2431), 已处理: 2,322,429, 发现变化: 4,416, 错误: 42
# Process 258 completed: 10000 files, 32 results, 0 errors
# 进度: 10.7% (259/2431), 已处理: 2,332,429, 发现变化: 4,448, 错误: 42
# Process 261 completed: 10000 files, 10 results, 0 errors
# 进度: 10.8% (262/2431), 已处理: 2,342,429, 发现变化: 4,458, 错误: 42
# Process 262 completed: 10 files, 0 results, 0 errors
# 进度: 10.8% (263/2431), 已处理: 2,342,439, 发现变化: 4,458, 错误: 42
# Process 260 completed: 10000 files, 23 results, 2 errors
# 进度: 10.7% (261/2431), 已处理: 2,352,439, 发现变化: 4,481, 错误: 44
# Process 264 completed: 9941 files, 18 results, 0 errors
# 进度: 10.9% (265/2431), 已处理: 2,362,380, 发现变化: 4,499, 错误: 44
# Process 263 completed: 10000 files, 41 results, 0 errors
# 进度: 10.9% (264/2431), 已处理: 2,372,380, 发现变化: 4,540, 错误: 44
# Process 266 completed: 10000 files, 14 results, 0 errors
# 进度: 11.0% (267/2431), 已处理: 2,382,380, 发现变化: 4,554, 错误: 44
# Process 267 completed: 16 files, 0 results, 0 errors
# 进度: 11.0% (268/2431), 已处理: 2,382,396, 发现变化: 4,554, 错误: 44
# Process 265 completed: 10000 files, 25 results, 0 errors
# 进度: 10.9% (266/2431), 已处理: 2,392,396, 发现变化: 4,579, 错误: 44
# Process 269 completed: 9897 files, 14 results, 0 errors
# 进度: 11.1% (270/2431), 已处理: 2,402,293, 发现变化: 4,593, 错误: 44
# Process 268 completed: 10000 files, 33 results, 0 errors
# 进度: 11.1% (269/2431), 已处理: 2,412,293, 发现变化: 4,626, 错误: 44
# Process 271 completed: 9933 files, 13 results, 0 errors
# 进度: 11.2% (272/2431), 已处理: 2,422,226, 发现变化: 4,639, 错误: 44
# Process 270 completed: 10000 files, 32 results, 0 errors
# 进度: 11.1% (271/2431), 已处理: 2,432,226, 发现变化: 4,671, 错误: 44
# Process 273 completed: 9838 files, 11 results, 0 errors
# 进度: 11.3% (274/2431), 已处理: 2,442,064, 发现变化: 4,682, 错误: 44
# Process 272 completed: 10000 files, 19 results, 0 errors
# 进度: 11.2% (273/2431), 已处理: 2,452,064, 发现变化: 4,701, 错误: 44
# Process 275 completed: 10000 files, 12 results, 0 errors
# 进度: 11.4% (276/2431), 已处理: 2,462,064, 发现变化: 4,713, 错误: 44
# Process 276 completed: 101 files, 0 results, 0 errors
# 进度: 11.4% (277/2431), 已处理: 2,462,165, 发现变化: 4,713, 错误: 44
# Process 274 completed: 10000 files, 27 results, 0 errors
# 进度: 11.3% (275/2431), 已处理: 2,472,165, 发现变化: 4,740, 错误: 44
# Process 278 completed: 9982 files, 11 results, 0 errors
# 进度: 11.5% (279/2431), 已处理: 2,482,147, 发现变化: 4,751, 错误: 44
# Process 277 completed: 10000 files, 20 results, 0 errors
# 进度: 11.4% (278/2431), 已处理: 2,492,147, 发现变化: 4,771, 错误: 44
# Process 280 completed: 10000 files, 10 results, 0 errors
# 进度: 11.6% (281/2431), 已处理: 2,502,147, 发现变化: 4,781, 错误: 44
# Process 281 completed: 15 files, 0 results, 0 errors
# 进度: 11.6% (282/2431), 已处理: 2,502,162, 发现变化: 4,781, 错误: 44
# Process 279 completed: 10000 files, 28 results, 0 errors
# 进度: 11.5% (280/2431), 已处理: 2,512,162, 发现变化: 4,809, 错误: 44
# Process 283 completed: 9920 files, 8 results, 0 errors
# 进度: 11.7% (284/2431), 已处理: 2,522,082, 发现变化: 4,817, 错误: 44
# Process 282 completed: 10000 files, 20 results, 0 errors
# 进度: 11.6% (283/2431), 已处理: 2,532,082, 发现变化: 4,837, 错误: 44
# Process 285 completed: 9830 files, 14 results, 0 errors
# 进度: 11.8% (286/2431), 已处理: 2,541,912, 发现变化: 4,851, 错误: 44
# Process 284 completed: 10000 files, 23 results, 0 errors
# 进度: 11.7% (285/2431), 已处理: 2,551,912, 发现变化: 4,874, 错误: 44
# Process 287 completed: 9867 files, 7 results, 0 errors
# 进度: 11.8% (288/2431), 已处理: 2,561,779, 发现变化: 4,881, 错误: 44
# Process 286 completed: 10000 files, 19 results, 1 errors
# 进度: 11.8% (287/2431), 已处理: 2,571,779, 发现变化: 4,900, 错误: 45
# Process 289 completed: 9992 files, 17 results, 0 errors
# 进度: 11.9% (290/2431), 已处理: 2,581,771, 发现变化: 4,917, 错误: 45
# Process 288 completed: 10000 files, 25 results, 0 errors
# 进度: 11.9% (289/2431), 已处理: 2,591,771, 发现变化: 4,942, 错误: 45
# Process 291 completed: 10000 files, 15 results, 0 errors
# 进度: 12.0% (292/2431), 已处理: 2,601,771, 发现变化: 4,957, 错误: 45
# Process 292 completed: 76 files, 0 results, 0 errors
# 进度: 12.1% (293/2431), 已处理: 2,601,847, 发现变化: 4,957, 错误: 45
# Process 290 completed: 10000 files, 20 results, 0 errors
# 进度: 12.0% (291/2431), 已处理: 2,611,847, 发现变化: 4,977, 错误: 45
# Process 293 completed: 10000 files, 20 results, 0 errors
# 进度: 12.1% (294/2431), 已处理: 2,621,847, 发现变化: 4,997, 错误: 45
# Process 294 completed: 9674 files, 12 results, 0 errors
# 进度: 12.1% (295/2431), 已处理: 2,631,521, 发现变化: 5,009, 错误: 45
# Process 296 completed: 9944 files, 20 results, 0 errors
# 进度: 12.2% (297/2431), 已处理: 2,641,465, 发现变化: 5,029, 错误: 45
# Process 295 completed: 10000 files, 23 results, 0 errors
# 进度: 12.2% (296/2431), 已处理: 2,651,465, 发现变化: 5,052, 错误: 45
# Process 298 completed: 9856 files, 11 results, 1 errors
# 进度: 12.3% (299/2431), 已处理: 2,661,321, 发现变化: 5,063, 错误: 46
# Process 297 completed: 10000 files, 22 results, 1 errors
# 进度: 12.3% (298/2431), 已处理: 2,671,321, 发现变化: 5,085, 错误: 47
# Process 300 completed: 9904 files, 9 results, 0 errors
# 进度: 12.4% (301/2431), 已处理: 2,681,225, 发现变化: 5,094, 错误: 47
# Process 299 completed: 10000 files, 19 results, 0 errors
# 进度: 12.3% (300/2431), 已处理: 2,691,225, 发现变化: 5,113, 错误: 47
# Process 302 completed: 10000 files, 19 results, 0 errors
# 进度: 12.5% (303/2431), 已处理: 2,701,225, 发现变化: 5,132, 错误: 47
# Process 303 completed: 66 files, 0 results, 0 errors
# 进度: 12.5% (304/2431), 已处理: 2,701,291, 发现变化: 5,132, 错误: 47
# Process 301 completed: 10000 files, 27 results, 0 errors
# 进度: 12.4% (302/2431), 已处理: 2,711,291, 发现变化: 5,159, 错误: 47
# Process 305 completed: 9839 files, 19 results, 1 errors
# 进度: 12.6% (306/2431), 已处理: 2,721,130, 发现变化: 5,178, 错误: 48
# Process 304 completed: 10000 files, 27 results, 0 errors
# 进度: 12.5% (305/2431), 已处理: 2,731,130, 发现变化: 5,205, 错误: 48
# Process 307 completed: 10000 files, 13 results, 0 errors
# 进度: 12.7% (308/2431), 已处理: 2,741,130, 发现变化: 5,218, 错误: 48
# Process 308 completed: 34 files, 0 results, 0 errors
# 进度: 12.7% (309/2431), 已处理: 2,741,164, 发现变化: 5,218, 错误: 48
# Process 306 completed: 10000 files, 20 results, 0 errors
# 进度: 12.6% (307/2431), 已处理: 2,751,164, 发现变化: 5,238, 错误: 48
# Process 310 completed: 10000 files, 21 results, 0 errors
# 进度: 12.8% (311/2431), 已处理: 2,761,164, 发现变化: 5,259, 错误: 48
# Process 311 completed: 77 files, 0 results, 0 errors
# 进度: 12.8% (312/2431), 已处理: 2,761,241, 发现变化: 5,259, 错误: 48
# Process 309 completed: 10000 files, 27 results, 0 errors
# 进度: 12.8% (310/2431), 已处理: 2,771,241, 发现变化: 5,286, 错误: 48
# Process 313 completed: 9932 files, 8 results, 0 errors
# 进度: 12.9% (314/2431), 已处理: 2,781,173, 发现变化: 5,294, 错误: 48
# Process 312 completed: 10000 files, 31 results, 0 errors
# 进度: 12.9% (313/2431), 已处理: 2,791,173, 发现变化: 5,325, 错误: 48
# Process 315 completed: 10000 files, 14 results, 0 errors
# 进度: 13.0% (316/2431), 已处理: 2,801,173, 发现变化: 5,339, 错误: 48
# Process 316 completed: 10 files, 0 results, 0 errors
# 进度: 13.0% (317/2431), 已处理: 2,801,183, 发现变化: 5,339, 错误: 48
# Process 314 completed: 10000 files, 23 results, 0 errors
# 进度: 13.0% (315/2431), 已处理: 2,811,183, 发现变化: 5,362, 错误: 48
# Process 318 completed: 9980 files, 16 results, 0 errors
# 进度: 13.1% (319/2431), 已处理: 2,821,163, 发现变化: 5,378, 错误: 48
# Process 317 completed: 10000 files, 25 results, 1 errors
# 进度: 13.1% (318/2431), 已处理: 2,831,163, 发现变化: 5,403, 错误: 49
# Process 319 completed: 10000 files, 23 results, 0 errors
# 进度: 13.2% (320/2431), 已处理: 2,841,163, 发现变化: 5,426, 错误: 49
# Process 320 completed: 9955 files, 21 results, 0 errors
# 进度: 13.2% (321/2431), 已处理: 2,851,118, 发现变化: 5,447, 错误: 49
# Process 322 completed: 9998 files, 14 results, 0 errors
# 进度: 13.3% (323/2431), 已处理: 2,861,116, 发现变化: 5,461, 错误: 49
# Process 321 completed: 10000 files, 24 results, 0 errors
# 进度: 13.2% (322/2431), 已处理: 2,871,116, 发现变化: 5,485, 错误: 49
# Process 324 completed: 10000 files, 14 results, 0 errors
# 进度: 13.4% (325/2431), 已处理: 2,881,116, 发现变化: 5,499, 错误: 49
# Process 325 completed: 87 files, 0 results, 0 errors
# 进度: 13.4% (326/2431), 已处理: 2,881,203, 发现变化: 5,499, 错误: 49
# Process 323 completed: 10000 files, 16 results, 0 errors
# 进度: 13.3% (324/2431), 已处理: 2,891,203, 发现变化: 5,515, 错误: 49
# Process 327 completed: 9999 files, 8 results, 1 errors
# 进度: 13.5% (328/2431), 已处理: 2,901,202, 发现变化: 5,523, 错误: 50
# Process 326 completed: 10000 files, 24 results, 0 errors
# 进度: 13.5% (327/2431), 已处理: 2,911,202, 发现变化: 5,547, 错误: 50
# Process 329 completed: 9794 files, 9 results, 0 errors
# 进度: 13.6% (330/2431), 已处理: 2,920,996, 发现变化: 5,556, 错误: 50
# Process 328 completed: 10000 files, 28 results, 0 errors
# 进度: 13.5% (329/2431), 已处理: 2,930,996, 发现变化: 5,584, 错误: 50
# Process 330 completed: 10000 files, 26 results, 0 errors
# 进度: 13.6% (331/2431), 已处理: 2,940,996, 发现变化: 5,610, 错误: 50
# Process 332 completed: 5 files, 0 results, 0 errors
# 进度: 13.7% (333/2431), 已处理: 2,941,001, 发现变化: 5,610, 错误: 50
# Process 331 completed: 10000 files, 14 results, 0 errors
# 进度: 13.7% (332/2431), 已处理: 2,951,001, 发现变化: 5,624, 错误: 50
# Process 334 completed: 10000 files, 11 results, 0 errors
# 进度: 13.8% (335/2431), 已处理: 2,961,001, 发现变化: 5,635, 错误: 50
# Process 335 completed: 39 files, 0 results, 0 errors
# 进度: 13.8% (336/2431), 已处理: 2,961,040, 发现变化: 5,635, 错误: 50
# Process 333 completed: 10000 files, 32 results, 0 errors
# 进度: 13.7% (334/2431), 已处理: 2,971,040, 发现变化: 5,667, 错误: 50
# Process 336 completed: 10000 files, 27 results, 0 errors
# 进度: 13.9% (337/2431), 已处理: 2,981,040, 发现变化: 5,694, 错误: 50
# Process 337 completed: 9834 files, 15 results, 0 errors
# 进度: 13.9% (338/2431), 已处理: 2,990,874, 发现变化: 5,709, 错误: 50
# Process 339 completed: 9834 files, 11 results, 0 errors
# 进度: 14.0% (340/2431), 已处理: 3,000,708, 发现变化: 5,720, 错误: 50
# Process 338 completed: 10000 files, 30 results, 0 errors
# 进度: 13.9% (339/2431), 已处理: 3,010,708, 发现变化: 5,750, 错误: 50
# Process 341 completed: 9961 files, 18 results, 0 errors
# 进度: 14.1% (342/2431), 已处理: 3,020,669, 发现变化: 5,768, 错误: 50
# Process 340 completed: 10000 files, 16 results, 0 errors
# 进度: 14.0% (341/2431), 已处理: 3,030,669, 发现变化: 5,784, 错误: 50
# Process 343 completed: 9955 files, 13 results, 0 errors
# 进度: 14.2% (344/2431), 已处理: 3,040,624, 发现变化: 5,797, 错误: 50
# Process 342 completed: 10000 files, 21 results, 0 errors
# 进度: 14.1% (343/2431), 已处理: 3,050,624, 发现变化: 5,818, 错误: 50
# Process 344 completed: 10000 files, 31 results, 0 errors
# 进度: 14.2% (345/2431), 已处理: 3,060,624, 发现变化: 5,849, 错误: 50
# Process 345 completed: 9933 files, 16 results, 0 errors
# 进度: 14.2% (346/2431), 已处理: 3,070,557, 发现变化: 5,865, 错误: 50
# Process 347 completed: 9981 files, 14 results, 1 errors
# 进度: 14.3% (348/2431), 已处理: 3,080,538, 发现变化: 5,879, 错误: 51
# Process 346 completed: 10000 files, 14 results, 0 errors
# 进度: 14.3% (347/2431), 已处理: 3,090,538, 发现变化: 5,893, 错误: 51
# Process 349 completed: 9905 files, 20 results, 1 errors
# 进度: 14.4% (350/2431), 已处理: 3,100,443, 发现变化: 5,913, 错误: 52
# Process 348 completed: 10000 files, 19 results, 0 errors
# 进度: 14.4% (349/2431), 已处理: 3,110,443, 发现变化: 5,932, 错误: 52
# Process 351 completed: 9919 files, 18 results, 0 errors
# 进度: 14.5% (352/2431), 已处理: 3,120,362, 发现变化: 5,950, 错误: 52
# Process 350 completed: 10000 files, 26 results, 0 errors
# 进度: 14.4% (351/2431), 已处理: 3,130,362, 发现变化: 5,976, 错误: 52
# Process 353 completed: 9760 files, 12 results, 0 errors
# 进度: 14.6% (354/2431), 已处理: 3,140,122, 发现变化: 5,988, 错误: 52
# Process 352 completed: 10000 files, 17 results, 1 errors
# 进度: 14.5% (353/2431), 已处理: 3,150,122, 发现变化: 6,005, 错误: 53
# Process 355 completed: 9944 files, 13 results, 0 errors
# 进度: 14.6% (356/2431), 已处理: 3,160,066, 发现变化: 6,018, 错误: 53
# Process 354 completed: 10000 files, 22 results, 0 errors
# 进度: 14.6% (355/2431), 已处理: 3,170,066, 发现变化: 6,040, 错误: 53
# Process 357 completed: 9980 files, 14 results, 0 errors
# 进度: 14.7% (358/2431), 已处理: 3,180,046, 发现变化: 6,054, 错误: 53
# Process 356 completed: 10000 files, 29 results, 0 errors
# 进度: 14.7% (357/2431), 已处理: 3,190,046, 发现变化: 6,083, 错误: 53
# Process 359 completed: 9995 files, 14 results, 1 errors
# 进度: 14.8% (360/2431), 已处理: 3,200,041, 发现变化: 6,097, 错误: 54
# Process 358 completed: 10000 files, 20 results, 0 errors
# 进度: 14.8% (359/2431), 已处理: 3,210,041, 发现变化: 6,117, 错误: 54
# Process 361 completed: 9901 files, 10 results, 0 errors
# 进度: 14.9% (362/2431), 已处理: 3,219,942, 发现变化: 6,127, 错误: 54
# Process 360 completed: 10000 files, 23 results, 0 errors
# 进度: 14.8% (361/2431), 已处理: 3,229,942, 发现变化: 6,150, 错误: 54
# Process 363 completed: 9865 files, 12 results, 0 errors
# 进度: 15.0% (364/2431), 已处理: 3,239,807, 发现变化: 6,162, 错误: 54
# Process 362 completed: 10000 files, 27 results, 0 errors
# 进度: 14.9% (363/2431), 已处理: 3,249,807, 发现变化: 6,189, 错误: 54
# Process 365 completed: 9901 files, 17 results, 0 errors
# 进度: 15.1% (366/2431), 已处理: 3,259,708, 发现变化: 6,206, 错误: 54
# Process 364 completed: 10000 files, 28 results, 0 errors
# 进度: 15.0% (365/2431), 已处理: 3,269,708, 发现变化: 6,234, 错误: 54
# Process 367 completed: 9873 files, 17 results, 0 errors
# 进度: 15.1% (368/2431), 已处理: 3,279,581, 发现变化: 6,251, 错误: 54
# Process 366 completed: 10000 files, 30 results, 0 errors
# 进度: 15.1% (367/2431), 已处理: 3,289,581, 发现变化: 6,281, 错误: 54
# Process 369 completed: 10000 files, 10 results, 0 errors
# 进度: 15.2% (370/2431), 已处理: 3,299,581, 发现变化: 6,291, 错误: 54
# Process 370 completed: 71 files, 0 results, 0 errors
# 进度: 15.3% (371/2431), 已处理: 3,299,652, 发现变化: 6,291, 错误: 54
# Process 368 completed: 10000 files, 23 results, 0 errors
# 进度: 15.2% (369/2431), 已处理: 3,309,652, 发现变化: 6,314, 错误: 54
# Process 371 completed: 10000 files, 23 results, 1 errors
# 进度: 15.3% (372/2431), 已处理: 3,319,652, 发现变化: 6,337, 错误: 55
# Process 372 completed: 9931 files, 8 results, 0 errors
# 进度: 15.3% (373/2431), 已处理: 3,329,583, 发现变化: 6,345, 错误: 55
# Process 374 completed: 10000 files, 9 results, 0 errors
# 进度: 15.4% (375/2431), 已处理: 3,339,583, 发现变化: 6,354, 错误: 55
# Process 375 completed: 124 files, 0 results, 0 errors
# 进度: 15.5% (376/2431), 已处理: 3,339,707, 发现变化: 6,354, 错误: 55
# Process 373 completed: 10000 files, 18 results, 0 errors
# 进度: 15.4% (374/2431), 已处理: 3,349,707, 发现变化: 6,372, 错误: 55
# Process 377 completed: 9869 files, 12 results, 0 errors
# 进度: 15.5% (378/2431), 已处理: 3,359,576, 发现变化: 6,384, 错误: 55
# Process 376 completed: 10000 files, 30 results, 0 errors
# 进度: 15.5% (377/2431), 已处理: 3,369,576, 发现变化: 6,414, 错误: 55
# Process 379 completed: 9795 files, 7 results, 0 errors
# 进度: 15.6% (380/2431), 已处理: 3,379,371, 发现变化: 6,421, 错误: 55
# Process 378 completed: 10000 files, 23 results, 0 errors
# 进度: 15.6% (379/2431), 已处理: 3,389,371, 发现变化: 6,444, 错误: 55
# Process 380 completed: 10000 files, 30 results, 0 errors
# 进度: 15.7% (381/2431), 已处理: 3,399,371, 发现变化: 6,474, 错误: 55
# Process 381 completed: 9828 files, 11 results, 0 errors
# 进度: 15.7% (382/2431), 已处理: 3,409,199, 发现变化: 6,485, 错误: 55
# Process 383 completed: 9871 files, 7 results, 0 errors
# 进度: 15.8% (384/2431), 已处理: 3,419,070, 发现变化: 6,492, 错误: 55
# Process 382 completed: 10000 files, 31 results, 0 errors
# 进度: 15.8% (383/2431), 已处理: 3,429,070, 发现变化: 6,523, 错误: 55
# Process 384 completed: 10000 files, 36 results, 0 errors
# 进度: 15.8% (385/2431), 已处理: 3,439,070, 发现变化: 6,559, 错误: 55
# Process 385 completed: 9952 files, 12 results, 0 errors
# 进度: 15.9% (386/2431), 已处理: 3,449,022, 发现变化: 6,571, 错误: 55
# Process 387 completed: 10000 files, 19 results, 0 errors
# 进度: 16.0% (388/2431), 已处理: 3,459,022, 发现变化: 6,590, 错误: 55
# Process 388 completed: 11 files, 0 results, 0 errors
# 进度: 16.0% (389/2431), 已处理: 3,459,033, 发现变化: 6,590, 错误: 55
# Process 386 completed: 10000 files, 21 results, 0 errors
# 进度: 15.9% (387/2431), 已处理: 3,469,033, 发现变化: 6,611, 错误: 55
# Process 390 completed: 10000 files, 16 results, 0 errors
# 进度: 16.1% (391/2431), 已处理: 3,479,033, 发现变化: 6,627, 错误: 55
# Process 391 completed: 65 files, 0 results, 0 errors
# 进度: 16.1% (392/2431), 已处理: 3,479,098, 发现变化: 6,627, 错误: 55
# Process 389 completed: 10000 files, 21 results, 0 errors
# 进度: 16.0% (390/2431), 已处理: 3,489,098, 发现变化: 6,648, 错误: 55
# Process 393 completed: 9871 files, 10 results, 0 errors
# 进度: 16.2% (394/2431), 已处理: 3,498,969, 发现变化: 6,658, 错误: 55
# Process 392 completed: 10000 files, 29 results, 0 errors
# 进度: 16.2% (393/2431), 已处理: 3,508,969, 发现变化: 6,687, 错误: 55
# Process 395 completed: 9835 files, 6 results, 0 errors
# 进度: 16.3% (396/2431), 已处理: 3,518,804, 发现变化: 6,693, 错误: 55
# Process 394 completed: 10000 files, 17 results, 0 errors
# 进度: 16.2% (395/2431), 已处理: 3,528,804, 发现变化: 6,710, 错误: 55
# Process 396 completed: 10000 files, 25 results, 0 errors
# 进度: 16.3% (397/2431), 已处理: 3,538,804, 发现变化: 6,735, 错误: 55
# Process 397 completed: 9979 files, 15 results, 0 errors
# 进度: 16.4% (398/2431), 已处理: 3,548,783, 发现变化: 6,750, 错误: 55
# Process 399 completed: 9810 files, 10 results, 1 errors
# 进度: 16.5% (400/2431), 已处理: 3,558,593, 发现变化: 6,760, 错误: 56
# Process 398 completed: 10000 files, 39 results, 0 errors
# 进度: 16.4% (399/2431), 已处理: 3,568,593, 发现变化: 6,799, 错误: 56
# Process 401 completed: 10000 files, 19 results, 0 errors
# 进度: 16.5% (402/2431), 已处理: 3,578,593, 发现变化: 6,818, 错误: 56
# Process 402 completed: 109 files, 0 results, 0 errors
# 进度: 16.6% (403/2431), 已处理: 3,578,702, 发现变化: 6,818, 错误: 56
# Process 400 completed: 10000 files, 28 results, 0 errors
# 进度: 16.5% (401/2431), 已处理: 3,588,702, 发现变化: 6,846, 错误: 56
# Process 404 completed: 9940 files, 19 results, 0 errors
# 进度: 16.7% (405/2431), 已处理: 3,598,642, 发现变化: 6,865, 错误: 56
# Process 403 completed: 10000 files, 30 results, 0 errors
# 进度: 16.6% (404/2431), 已处理: 3,608,642, 发现变化: 6,895, 错误: 56
# Process 406 completed: 9841 files, 7 results, 0 errors
# 进度: 16.7% (407/2431), 已处理: 3,618,483, 发现变化: 6,902, 错误: 56
# Process 405 completed: 10000 files, 30 results, 0 errors
# 进度: 16.7% (406/2431), 已处理: 3,628,483, 发现变化: 6,932, 错误: 56
# Process 408 completed: 9856 files, 13 results, 0 errors
# 进度: 16.8% (409/2431), 已处理: 3,638,339, 发现变化: 6,945, 错误: 56
# Process 407 completed: 10000 files, 24 results, 0 errors
# 进度: 16.8% (408/2431), 已处理: 3,648,339, 发现变化: 6,969, 错误: 56
# Process 410 completed: 9864 files, 12 results, 0 errors
# 进度: 16.9% (411/2431), 已处理: 3,658,203, 发现变化: 6,981, 错误: 56
# Process 409 completed: 10000 files, 12 results, 0 errors
# 进度: 16.9% (410/2431), 已处理: 3,668,203, 发现变化: 6,993, 错误: 56
# Process 412 completed: 9919 files, 12 results, 0 errors
# 进度: 17.0% (413/2431), 已处理: 3,678,122, 发现变化: 7,005, 错误: 56
# Process 411 completed: 10000 files, 29 results, 0 errors
# 进度: 16.9% (412/2431), 已处理: 3,688,122, 发现变化: 7,034, 错误: 56
# Process 414 completed: 9961 files, 15 results, 0 errors
# 进度: 17.1% (415/2431), 已处理: 3,698,083, 发现变化: 7,049, 错误: 56
# Process 413 completed: 10000 files, 21 results, 0 errors
# 进度: 17.0% (414/2431), 已处理: 3,708,083, 发现变化: 7,070, 错误: 56
# Process 416 completed: 10000 files, 8 results, 0 errors
# 进度: 17.2% (417/2431), 已处理: 3,718,083, 发现变化: 7,078, 错误: 56
# Process 417 completed: 42 files, 0 results, 0 errors
# 进度: 17.2% (418/2431), 已处理: 3,718,125, 发现变化: 7,078, 错误: 56
# Process 415 completed: 10000 files, 26 results, 0 errors
# 进度: 17.1% (416/2431), 已处理: 3,728,125, 发现变化: 7,104, 错误: 56
# Process 419 completed: 9865 files, 11 results, 0 errors
# 进度: 17.3% (420/2431), 已处理: 3,737,990, 发现变化: 7,115, 错误: 56
# Process 418 completed: 10000 files, 31 results, 0 errors
# 进度: 17.2% (419/2431), 已处理: 3,747,990, 发现变化: 7,146, 错误: 56
# Process 421 completed: 9981 files, 16 results, 0 errors
# 进度: 17.4% (422/2431), 已处理: 3,757,971, 发现变化: 7,162, 错误: 56
# Process 420 completed: 10000 files, 26 results, 0 errors
# 进度: 17.3% (421/2431), 已处理: 3,767,971, 发现变化: 7,188, 错误: 56
# Process 423 completed: 9840 files, 18 results, 0 errors
# 进度: 17.4% (424/2431), 已处理: 3,777,811, 发现变化: 7,206, 错误: 56
# Process 422 completed: 10000 files, 26 results, 0 errors
# 进度: 17.4% (423/2431), 已处理: 3,787,811, 发现变化: 7,232, 错误: 56
# Process 424 completed: 10000 files, 23 results, 0 errors
# 进度: 17.5% (425/2431), 已处理: 3,797,811, 发现变化: 7,255, 错误: 56
# Process 426 completed: 27 files, 0 results, 0 errors
# 进度: 17.6% (427/2431), 已处理: 3,797,838, 发现变化: 7,255, 错误: 56
# Process 425 completed: 10000 files, 16 results, 1 errors
# 进度: 17.5% (426/2431), 已处理: 3,807,838, 发现变化: 7,271, 错误: 57
# Process 428 completed: 9939 files, 13 results, 0 errors
# ...
# 进度: 38.9% (946/2431), 已处理: 8,553,766, 发现变化: 16,582, 错误: 135
# Process 948 completed: 9923 files, 12 results, 1 errors
# 进度: 39.0% (949/2431), 已处理: 8,563,689, 发现变化: 16,594, 错误: 136
# Process 947 completed: 10000 files, 19 results, 1 errors
# 进度: 39.0% (948/2431), 已处理: 8,573,689, 发现变化: 16,613, 错误: 137
# Process 950 completed: 9964 files, 9 results, 0 errors
# 进度: 39.1% (951/2431), 已处理: 8,583,653, 发现变化: 16,622, 错误: 137
# Process 949 completed: 10000 files, 25 results, 0 errors
# 进度: 39.1% (950/2431), 已处理: 8,593,653, 发现变化: 16,647, 错误: 137
# Process 952 completed: 9980 files, 12 results, 0 errors
# 进度: 39.2% (953/2431), 已处理: 8,603,633, 发现变化: 16,659, 错误: 137
# Process 951 completed: 10000 files, 34 results, 0 errors
# 进度: 39.2% (952/2431), 已处理: 8,613,633, 发现变化: 16,693, 错误: 137
# Process 954 completed: 9893 files, 21 results, 0 errors
# 进度: 39.3% (955/2431), 已处理: 8,623,526, 发现变化: 16,714, 错误: 137
# Process 953 completed: 10000 files, 20 results, 0 errors
# 进度: 39.2% (954/2431), 已处理: 8,633,526, 发现变化: 16,734, 错误: 137
# Process 956 completed: 9934 files, 20 results, 0 errors
# 进度: 39.4% (957/2431), 已处理: 8,643,460, 发现变化: 16,754, 错误: 137
# Process 955 completed: 10000 files, 31 results, 1 errors
# 进度: 39.3% (956/2431), 已处理: 8,653,460, 发现变化: 16,785, 错误: 138
# Process 958 completed: 10000 files, 13 results, 0 errors
# 进度: 39.4% (959/2431), 已处理: 8,663,460, 发现变化: 16,798, 错误: 138
# Process 959 completed: 32 files, 0 results, 0 errors
# 进度: 39.5% (960/2431), 已处理: 8,663,492, 发现变化: 16,798, 错误: 138
# Process 957 completed: 10000 files, 33 results, 0 errors
# 进度: 39.4% (958/2431), 已处理: 8,673,492, 发现变化: 16,831, 错误: 138
# Process 961 completed: 9822 files, 9 results, 1 errors
# 进度: 39.6% (962/2431), 已处理: 8,683,314, 发现变化: 16,840, 错误: 139
# Process 960 completed: 10000 files, 25 results, 0 errors
# 进度: 39.5% (961/2431), 已处理: 8,693,314, 发现变化: 16,865, 错误: 139
# Process 963 completed: 10000 files, 14 results, 0 errors
# 进度: 39.7% (964/2431), 已处理: 8,703,314, 发现变化: 16,879, 错误: 139
# Process 964 completed: 14 files, 0 results, 0 errors
# 进度: 39.7% (965/2431), 已处理: 8,703,328, 发现变化: 16,879, 错误: 139
# Process 962 completed: 10000 files, 26 results, 0 errors
# 进度: 39.6% (963/2431), 已处理: 8,713,328, 发现变化: 16,905, 错误: 139
# Process 966 completed: 9945 files, 18 results, 0 errors
# 进度: 39.8% (967/2431), 已处理: 8,723,273, 发现变化: 16,923, 错误: 139
# Process 965 completed: 10000 files, 22 results, 0 errors
# 进度: 39.7% (966/2431), 已处理: 8,733,273, 发现变化: 16,945, 错误: 139
# Process 967 completed: 10000 files, 24 results, 1 errors
# 进度: 39.8% (968/2431), 已处理: 8,743,273, 发现变化: 16,969, 错误: 140
# Process 968 completed: 9803 files, 21 results, 0 errors
# 进度: 39.9% (969/2431), 已处理: 8,753,076, 发现变化: 16,990, 错误: 140
# Process 970 completed: 9685 files, 5 results, 0 errors
# 进度: 39.9% (971/2431), 已处理: 8,762,761, 发现变化: 16,995, 错误: 140
# Process 969 completed: 10000 files, 22 results, 0 errors
# 进度: 39.9% (970/2431), 已处理: 8,772,761, 发现变化: 17,017, 错误: 140
# Process 972 completed: 9981 files, 12 results, 1 errors
# 进度: 40.0% (973/2431), 已处理: 8,782,742, 发现变化: 17,029, 错误: 141
# Process 971 completed: 10000 files, 26 results, 0 errors
# 进度: 40.0% (972/2431), 已处理: 8,792,742, 发现变化: 17,055, 错误: 141
# Process 974 completed: 9971 files, 12 results, 0 errors
# 进度: 40.1% (975/2431), 已处理: 8,802,713, 发现变化: 17,067, 错误: 141
# Process 973 completed: 10000 files, 29 results, 0 errors
# 进度: 40.1% (974/2431), 已处理: 8,812,713, 发现变化: 17,096, 错误: 141
# Process 975 completed: 10000 files, 30 results, 0 errors
# 进度: 40.1% (976/2431), 已处理: 8,822,713, 发现变化: 17,126, 错误: 141
# Process 976 completed: 9984 files, 9 results, 0 errors
# 进度: 40.2% (977/2431), 已处理: 8,832,697, 发现变化: 17,135, 错误: 141
# Process 978 completed: 9924 files, 12 results, 1 errors
# 进度: 40.3% (979/2431), 已处理: 8,842,621, 发现变化: 17,147, 错误: 142
# Process 977 completed: 10000 files, 25 results, 0 errors
# 进度: 40.2% (978/2431), 已处理: 8,852,621, 发现变化: 17,172, 错误: 142
# Process 980 completed: 9906 files, 13 results, 0 errors
# 进度: 40.4% (981/2431), 已处理: 8,862,527, 发现变化: 17,185, 错误: 142
# Process 979 completed: 10000 files, 29 results, 1 errors
# 进度: 40.3% (980/2431), 已处理: 8,872,527, 发现变化: 17,214, 错误: 143
# Process 982 completed: 10000 files, 16 results, 0 errors
# 进度: 40.4% (983/2431), 已处理: 8,882,527, 发现变化: 17,230, 错误: 143
# Process 983 completed: 2 files, 0 results, 0 errors
# 进度: 40.5% (984/2431), 已处理: 8,882,529, 发现变化: 17,230, 错误: 143
# Process 981 completed: 10000 files, 30 results, 0 errors
# 进度: 40.4% (982/2431), 已处理: 8,892,529, 发现变化: 17,260, 错误: 143
# Process 985 completed: 9965 files, 19 results, 0 errors
# 进度: 40.6% (986/2431), 已处理: 8,902,494, 发现变化: 17,279, 错误: 143
# Process 984 completed: 10000 files, 20 results, 0 errors
# 进度: 40.5% (985/2431), 已处理: 8,912,494, 发现变化: 17,299, 错误: 143
# Process 987 completed: 9928 files, 21 results, 0 errors
# 进度: 40.6% (988/2431), 已处理: 8,922,422, 发现变化: 17,320, 错误: 143
# Process 986 completed: 10000 files, 20 results, 0 errors
# 进度: 40.6% (987/2431), 已处理: 8,932,422, 发现变化: 17,340, 错误: 143
# Process 989 completed: 9873 files, 20 results, 0 errors
# 进度: 40.7% (990/2431), 已处理: 8,942,295, 发现变化: 17,360, 错误: 143
# Process 988 completed: 10000 files, 17 results, 3 errors
# 进度: 40.7% (989/2431), 已处理: 8,952,295, 发现变化: 17,377, 错误: 146
# Process 991 completed: 9868 files, 9 results, 0 errors
# 进度: 40.8% (992/2431), 已处理: 8,962,163, 发现变化: 17,386, 错误: 146
# Process 990 completed: 10000 files, 24 results, 0 errors
# 进度: 40.8% (991/2431), 已处理: 8,972,163, 发现变化: 17,410, 错误: 146
# Process 993 completed: 10000 files, 16 results, 1 errors
# 进度: 40.9% (994/2431), 已处理: 8,982,163, 发现变化: 17,426, 错误: 147
# Process 994 completed: 26 files, 0 results, 0 errors
# 进度: 40.9% (995/2431), 已处理: 8,982,189, 发现变化: 17,426, 错误: 147
# Process 992 completed: 10000 files, 23 results, 0 errors
# 进度: 40.8% (993/2431), 已处理: 8,992,189, 发现变化: 17,449, 错误: 147
# Process 996 completed: 9833 files, 9 results, 0 errors
# 进度: 41.0% (997/2431), 已处理: 9,002,022, 发现变化: 17,458, 错误: 147
# Process 995 completed: 10000 files, 23 results, 0 errors
# 进度: 41.0% (996/2431), 已处理: 9,012,022, 发现变化: 17,481, 错误: 147
# Process 997 completed: 10000 files, 22 results, 0 errors
# 进度: 41.1% (998/2431), 已处理: 9,022,022, 发现变化: 17,503, 错误: 147
# Process 998 completed: 9812 files, 25 results, 0 errors
# 进度: 41.1% (999/2431), 已处理: 9,031,834, 发现变化: 17,528, 错误: 147
# Process 1000 completed: 9895 files, 15 results, 0 errors
# 进度: 41.2% (1001/2431), 已处理: 9,041,729, 发现变化: 17,543, 错误: 147
# Process 999 completed: 10000 files, 9 results, 0 errors
# 进度: 41.1% (1000/2431), 已处理: 9,051,729, 发现变化: 17,552, 错误: 147
# Process 1001 completed: 10000 files, 24 results, 1 errors
# 进度: 41.2% (1002/2431), 已处理: 9,061,729, 发现变化: 17,576, 错误: 148
# Process 1002 completed: 9903 files, 16 results, 0 errors
# 进度: 41.3% (1003/2431), 已处理: 9,071,632, 发现变化: 17,592, 错误: 148
# Process 1004 completed: 9820 files, 16 results, 0 errors
# 进度: 41.3% (1005/2431), 已处理: 9,081,452, 发现变化: 17,608, 错误: 148
# Process 1003 completed: 10000 files, 26 results, 0 errors
# 进度: 41.3% (1004/2431), 已处理: 9,091,452, 发现变化: 17,634, 错误: 148
# Process 1006 completed: 9940 files, 15 results, 0 errors
# 进度: 41.4% (1007/2431), 已处理: 9,101,392, 发现变化: 17,649, 错误: 148
# Process 1005 completed: 10000 files, 25 results, 0 errors
# 进度: 41.4% (1006/2431), 已处理: 9,111,392, 发现变化: 17,674, 错误: 148
# Process 1008 completed: 9852 files, 14 results, 0 errors
# 进度: 41.5% (1009/2431), 已处理: 9,121,244, 发现变化: 17,688, 错误: 148
# Process 1007 completed: 10000 files, 23 results, 0 errors
# 进度: 41.5% (1008/2431), 已处理: 9,131,244, 发现变化: 17,711, 错误: 148
# Process 1010 completed: 9839 files, 17 results, 0 errors
# 进度: 41.6% (1011/2431), 已处理: 9,141,083, 发现变化: 17,728, 错误: 148
# Process 1009 completed: 10000 files, 37 results, 0 errors
# 进度: 41.5% (1010/2431), 已处理: 9,151,083, 发现变化: 17,765, 错误: 148
# Process 1012 completed: 9981 files, 19 results, 0 errors
# 进度: 41.7% (1013/2431), 已处理: 9,161,064, 发现变化: 17,784, 错误: 148
# Process 1011 completed: 10000 files, 19 results, 0 errors
# 进度: 41.6% (1012/2431), 已处理: 9,171,064, 发现变化: 17,803, 错误: 148
# Process 1014 completed: 9713 files, 8 results, 0 errors
# 进度: 41.8% (1015/2431), 已处理: 9,180,777, 发现变化: 17,811, 错误: 148
# Process 1013 completed: 10000 files, 34 results, 1 errors
# 进度: 41.7% (1014/2431), 已处理: 9,190,777, 发现变化: 17,845, 错误: 149
# Process 1016 completed: 9770 files, 14 results, 0 errors
# 进度: 41.8% (1017/2431), 已处理: 9,200,547, 发现变化: 17,859, 错误: 149
# Process 1015 completed: 10000 files, 22 results, 0 errors
# Process 1021 completed: 9958 files, 21 results, 0 errors
# 进度: 42.0% (1022/2431), 已处理: 9,240,513, 发现变化: 17,941, 错误: 149
# Process 1020 completed: 10000 files, 24 results, 1 errors
# 进度: 42.0% (1021/2431), 已处理: 9,250,513, 发现变化: 17,965, 错误: 150
# Process 1022 completed: 10000 files, 22 results, 0 errors
# 进度: 42.1% (1023/2431), 已处理: 9,260,513, 发现变化: 17,987, 错误: 150
# Process 1023 completed: 9913 files, 8 results, 0 errors
# 进度: 42.1% (1024/2431), 已处理: 9,270,426, 发现变化: 17,995, 错误: 150
# Process 1025 completed: 9841 files, 12 results, 0 errors
# 进度: 42.2% (1026/2431), 已处理: 9,280,267, 发现变化: 18,007, 错误: 150
# Process 1024 completed: 10000 files, 26 results, 0 errors
# 进度: 42.2% (1025/2431), 已处理: 9,290,267, 发现变化: 18,033, 错误: 150
# Process 1027 completed: 9917 files, 13 results, 0 errors
# 进度: 42.3% (1028/2431), 已处理: 9,300,184, 发现变化: 18,046, 错误: 150
# Process 1026 completed: 10000 files, 21 results, 0 errors
# 进度: 42.2% (1027/2431), 已处理: 9,310,184, 发现变化: 18,067, 错误: 150
# Process 1029 completed: 9934 files, 12 results, 0 errors
# 进度: 42.4% (1030/2431), 已处理: 9,320,118, 发现变化: 18,079, 错误: 150
# Process 1028 completed: 10000 files, 30 results, 0 errors
# 进度: 42.3% (1029/2431), 已处理: 9,330,118, 发现变化: 18,109, 错误: 150
# Process 1031 completed: 9852 files, 12 results, 0 errors
# 进度: 42.5% (1032/2431), 已处理: 9,339,970, 发现变化: 18,121, 错误: 150
# Process 1030 completed: 10000 files, 24 results, 0 errors
# 进度: 42.4% (1031/2431), 已处理: 9,349,970, 发现变化: 18,145, 错误: 150
# Process 1032 completed: 10000 files, 24 results, 0 errors
# 进度: 42.5% (1033/2431), 已处理: 9,359,970, 发现变化: 18,169, 错误: 150
# Process 1033 completed: 9859 files, 11 results, 0 errors
# 进度: 42.5% (1034/2431), 已处理: 9,369,829, 发现变化: 18,180, 错误: 150
# Process 1035 completed: 9907 files, 14 results, 0 errors
# 进度: 42.6% (1036/2431), 已处理: 9,379,736, 发现变化: 18,194, 错误: 150
# Process 1034 completed: 10000 files, 32 results, 0 errors
# 进度: 42.6% (1035/2431), 已处理: 9,389,736, 发现变化: 18,226, 错误: 150
# Process 1036 completed: 10000 files, 24 results, 0 errors
# 进度: 42.7% (1037/2431), 已处理: 9,399,736, 发现变化: 18,250, 错误: 150
# Process 1038 completed: 22 files, 0 results, 0 errors
# 进度: 42.7% (1039/2431), 已处理: 9,399,758, 发现变化: 18,250, 错误: 150
# Process 1037 completed: 10000 files, 16 results, 0 errors
# 进度: 42.7% (1038/2431), 已处理: 9,409,758, 发现变化: 18,266, 错误: 150
# Process 1040 completed: 10000 files, 13 results, 0 errors
# 进度: 42.8% (1041/2431), 已处理: 9,419,758, 发现变化: 18,279, 错误: 150
# Process 1041 completed: 42 files, 0 results, 0 errors
# 进度: 42.9% (1042/2431), 已处理: 9,419,800, 发现变化: 18,279, 错误: 150
# Process 1039 completed: 10000 files, 33 results, 0 errors
# 进度: 42.8% (1040/2431), 已处理: 9,429,800, 发现变化: 18,312, 错误: 150
# Process 1043 completed: 10000 files, 13 results, 0 errors
# 进度: 42.9% (1044/2431), 已处理: 9,439,800, 发现变化: 18,325, 错误: 150
# Process 1044 completed: 72 files, 0 results, 0 errors
# 进度: 43.0% (1045/2431), 已处理: 9,439,872, 发现变化: 18,325, 错误: 150
# Process 1042 completed: 10000 files, 15 results, 0 errors
# 进度: 42.9% (1043/2431), 已处理: 9,449,872, 发现变化: 18,340, 错误: 150
# Process 1046 completed: 9996 files, 11 results, 0 errors
# 进度: 43.1% (1047/2431), 已处理: 9,459,868, 发现变化: 18,351, 错误: 150
# Process 1045 completed: 10000 files, 30 results, 0 errors
# 进度: 43.0% (1046/2431), 已处理: 9,469,868, 发现变化: 18,381, 错误: 150
# Process 1047 completed: 10000 files, 31 results, 0 errors
# 进度: 43.1% (1048/2431), 已处理: 9,479,868, 发现变化: 18,412, 错误: 150
# Process 1048 completed: 9993 files, 10 results, 0 errors
# 进度: 43.2% (1049/2431), 已处理: 9,489,861, 发现变化: 18,422, 错误: 150
# Process 1050 completed: 9853 files, 7 results, 0 errors
# 进度: 43.2% (1051/2431), 已处理: 9,499,714, 发现变化: 18,429, 错误: 150
# Process 1049 completed: 10000 files, 27 results, 1 errors
# 进度: 43.2% (1050/2431), 已处理: 9,509,714, 发现变化: 18,456, 错误: 151
# Process 1052 completed: 9875 files, 13 results, 0 errors
# 进度: 43.3% (1053/2431), 已处理: 9,519,589, 发现变化: 18,469, 错误: 151
# Process 1051 completed: 10000 files, 24 results, 0 errors
# 进度: 43.3% (1052/2431), 已处理: 9,529,589, 发现变化: 18,493, 错误: 151
# Process 1054 completed: 9907 files, 16 results, 0 errors
# 进度: 43.4% (1055/2431), 已处理: 9,539,496, 发现变化: 18,509, 错误: 151
# Process 1053 completed: 10000 files, 18 results, 0 errors
# 进度: 43.4% (1054/2431), 已处理: 9,549,496, 发现变化: 18,527, 错误: 151
# Process 1056 completed: 9987 files, 14 results, 0 errors
# 进度: 43.5% (1057/2431), 已处理: 9,559,483, 发现变化: 18,541, 错误: 151
# Process 1055 completed: 10000 files, 23 results, 0 errors
# 进度: 43.4% (1056/2431), 已处理: 9,569,483, 发现变化: 18,564, 错误: 151
# Process 1058 completed: 9949 files, 10 results, 0 errors
# 进度: 43.6% (1059/2431), 已处理: 9,579,432, 发现变化: 18,574, 错误: 151
# Process 1057 completed: 10000 files, 17 results, 0 errors
# 进度: 43.5% (1058/2431), 已处理: 9,589,432, 发现变化: 18,591, 错误: 151
# Process 1060 completed: 9982 files, 5 results, 0 errors
# 进度: 43.6% (1061/2431), 已处理: 9,599,414, 发现变化: 18,596, 错误: 151
# Process 1059 completed: 10000 files, 32 results, 0 errors
# 进度: 43.6% (1060/2431), 已处理: 9,609,414, 发现变化: 18,628, 错误: 151
# Process 1062 completed: 9935 files, 10 results, 0 errors
# 进度: 43.7% (1063/2431), 已处理: 9,619,349, 发现变化: 18,638, 错误: 151
# Process 1061 completed: 10000 files, 19 results, 0 errors
# 进度: 43.7% (1062/2431), 已处理: 9,629,349, 发现变化: 18,657, 错误: 151
# Process 1064 completed: 9828 files, 13 results, 0 errors
# 进度: 43.8% (1065/2431), 已处理: 9,639,177, 发现变化: 18,670, 错误: 151
# Process 1063 completed: 10000 files, 29 results, 1 errors
# 进度: 43.8% (1064/2431), 已处理: 9,649,177, 发现变化: 18,699, 错误: 152
# Process 1065 completed: 10000 files, 25 results, 0 errors
# 进度: 43.9% (1066/2431), 已处理: 9,659,177, 发现变化: 18,724, 错误: 152
# Process 1066 completed: 9967 files, 10 results, 0 errors
# 进度: 43.9% (1067/2431), 已处理: 9,669,144, 发现变化: 18,734, 错误: 152
# Process 1068 completed: 9995 files, 15 results, 0 errors
# 进度: 44.0% (1069/2431), 已处理: 9,679,139, 发现变化: 18,749, 错误: 152
# Process 1067 completed: 10000 files, 27 results, 1 errors
# 进度: 43.9% (1068/2431), 已处理: 9,689,139, 发现变化: 18,776, 错误: 153
# Process 1070 completed: 10000 files, 16 results, 0 errors
# 进度: 44.1% (1071/2431), 已处理: 9,699,139, 发现变化: 18,792, 错误: 153
# Process 1071 completed: 16 files, 0 results, 0 errors
# 进度: 44.1% (1072/2431), 已处理: 9,699,155, 发现变化: 18,792, 错误: 153
# Process 1069 completed: 10000 files, 33 results, 1 errors
# 进度: 44.0% (1070/2431), 已处理: 9,709,155, 发现变化: 18,825, 错误: 154
# Process 1073 completed: 9795 files, 11 results, 0 errors
# 进度: 44.2% (1074/2431), 已处理: 9,718,950, 发现变化: 18,836, 错误: 154
# Process 1072 completed: 10000 files, 27 results, 0 errors
# 进度: 44.1% (1073/2431), 已处理: 9,728,950, 发现变化: 18,863, 错误: 154
# Process 1075 completed: 10000 files, 16 results, 0 errors
# 进度: 44.3% (1076/2431), 已处理: 9,738,950, 发现变化: 18,879, 错误: 154
# Process 1076 completed: 97 files, 1 results, 0 errors
# 进度: 44.3% (1077/2431), 已处理: 9,739,047, 发现变化: 18,880, 错误: 154
# Process 1074 completed: 10000 files, 35 results, 0 errors
# 进度: 44.2% (1075/2431), 已处理: 9,749,047, 发现变化: 18,915, 错误: 154
# Process 1078 completed: 9936 files, 14 results, 0 errors
# 进度: 44.4% (1079/2431), 已处理: 9,758,983, 发现变化: 18,929, 错误: 154
# Process 1077 completed: 10000 files, 26 results, 0 errors
# 进度: 44.3% (1078/2431), 已处理: 9,768,983, 发现变化: 18,955, 错误: 154
# Process 1080 completed: 9918 files, 17 results, 0 errors
# 进度: 44.5% (1081/2431), 已处理: 9,778,901, 发现变化: 18,972, 错误: 154
# Process 1079 completed: 10000 files, 30 results, 0 errors
# 进度: 44.4% (1080/2431), 已处理: 9,788,901, 发现变化: 19,002, 错误: 154
# Process 1082 completed: 9908 files, 16 results, 0 errors
# 进度: 44.5% (1083/2431), 已处理: 9,798,809, 发现变化: 19,018, 错误: 154
# Process 1081 completed: 10000 files, 32 results, 1 errors
# 进度: 44.5% (1082/2431), 已处理: 9,808,809, 发现变化: 19,050, 错误: 155
# Process 1084 completed: 10000 files, 12 results, 0 errors
# 进度: 44.6% (1085/2431), 已处理: 9,818,809, 发现变化: 19,062, 错误: 155
# Process 1085 completed: 5 files, 0 results, 0 errors
# 进度: 44.7% (1086/2431), 已处理: 9,818,814, 发现变化: 19,062, 错误: 155
# Process 1083 completed: 10000 files, 26 results, 0 errors
# 进度: 44.6% (1084/2431), 已处理: 9,828,814, 发现变化: 19,088, 错误: 155

# %%
#!/usr/bin/env python3
"""
ORCID 姓名变化检测程序 - 大文件重新处理版本
专门用于处理因体积过大而被主程序跳过的XML文件。
"""

import os
import csv
import logging
import multiprocessing as mp
from multiprocessing import Pool, Manager, Lock
from concurrent.futures import ProcessPoolExecutor, as_completed
import time
from pathlib import Path
from typing import Dict, List, Optional, Tuple
import signal
import sys
from functools import partial
import shutil
import traceback

from bs4 import BeautifulSoup
import gender_guesser.detector as gender
import Levenshtein
from datetime import datetime


# 增加递归限制
sys.setrecursionlimit(15000)

# 全局配置
CONFIG = {
    'base_path': '/hy-tmp/problem_xml_files/large_files',  # 指向大文件目录
    'output_file': '/hy-tmp/large_files_results.csv',    # 新的输出文件名
    'problem_files_dir': '/hy-tmp/problem_xml_files_reprocessing', # 新的问题文件目录
    'max_workers': 2,  # 根据你的CPU核心数调整
    'chunk_size': 50,  # 文件总数少，chunk可以小一点
    'batch_size': 10,
}

def setup_problem_files_dir():
    """创建问题文件存储目录"""
    problem_dir = Path(CONFIG['problem_files_dir'])
    problem_dir.mkdir(parents=True, exist_ok=True)
    
    # 创建子目录
    (problem_dir / 'recursion_error').mkdir(exist_ok=True)
    (problem_dir / 'parse_error').mkdir(exist_ok=True)
    (problem_dir / 'large_files').mkdir(exist_ok=True)
    (problem_dir / 'other_errors').mkdir(exist_ok=True)
    
    return problem_dir

def copy_problem_file(file_path: Path, error_type: str, error_msg: str = ""):
    """复制问题文件到指定目录"""
    try:
        problem_dir = Path(CONFIG['problem_files_dir'])
        error_dir = problem_dir / error_type
        
        # 创建唯一的文件名（避免重名）
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")
        new_filename = f"{file_path.stem}_{timestamp}{file_path.suffix}"
        dest_path = error_dir / new_filename
        
        shutil.copy2(file_path, dest_path)
        
        # 记录错误信息
        log_file = error_dir / "error_log.txt"
        with open(log_file, 'a', encoding='utf-8') as f:
            f.write(f"{datetime.now().isoformat()}\t{file_path}\t{new_filename}\t{error_msg}\n")
            
        return True
    except Exception as e:
        print(f"无法复制问题文件 {file_path}: {e}")
        return False

def safe_parse_xml(file_path: Path) -> Optional[BeautifulSoup]:
    """安全的XML解析函数 - 移除了文件大小限制以重新处理大文件"""
    try:
        # ## 核心修改：注释掉文件大小检查 ##
        # file_size = file_path.stat().st_size
        # if file_size > SOME_LIMIT:
        #     return None
        
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
            
        # ## 移除内容长度检查 ##
        # if len(content) > 10_000_000:
        #     return None
            
        soup = BeautifulSoup(content, 'lxml-xml')
        return soup
            
    except Exception as e:
        error_msg = f"{type(e).__name__}: {str(e)}"
        copy_problem_file(file_path, 'reprocessing_errors', error_msg)
        return None

def extract_name_info(soup: BeautifulSoup, gender_detector) -> Optional[Dict]:
    """从BeautifulSoup对象中提取姓名信息和性别"""
    try:
        person_name_tag = soup.find("person:name")
        if not person_name_tag:
            return None

        # 提取person:name基本信息
        person_created_date_tag = person_name_tag.find("common:created-date")
        given_names_tag = person_name_tag.find("personal-details:given-names")
        family_name_tag = person_name_tag.find("personal-details:family-name")

        # <-- FIX: Convert all extracted text to plain Python strings
        person_created_date = person_created_date_tag.get_text(strip=True) if person_created_date_tag else None
        given_name = given_names_tag.get_text(strip=True) if given_names_tag else None
        family_name = family_name_tag.get_text(strip=True) if family_name_tag else None

        # 性别识别 - 只处理女性
        if not given_name:
            return None
        
        gender_result = gender_detector.get_gender(given_name.split()[0])
        if gender_result not in ['female', 'mostly_female']:
            return None 

        # 构建基准姓名 (given_name + family_name)
        if not family_name:
            return None
        base_name = f"{given_name} {family_name}".strip()

        # 提取other-name信息 - 可能有多个
        other_names_data = []
        other_name_tags = soup.find_all("other-name:other-name")
        
        for other_name_tag in other_name_tags:
            other_created_date_tag = other_name_tag.find("common:created-date")
            other_name_content_tag = other_name_tag.find("other-name:content")
            
            # <-- FIX: Convert all extracted text to plain Python strings
            other_created_date = other_created_date_tag.get_text(strip=True) if other_created_date_tag else None
            other_name_content = other_name_content_tag.get_text(strip=True) if other_name_content_tag else None
            
            if other_created_date and other_name_content:
                other_names_data.append({
                    'other_name_content': other_name_content,
                    'other_created_date': other_created_date
                })

        if not other_names_data:
            return None

        return {
            'person_created_date': person_created_date,
            'given_name': given_name,
            'family_name': family_name,
            'base_name': base_name,
            'other_names_data': other_names_data,
            'gender': gender_result
        }

    except RecursionError:
        raise  # 让上层处理
    except Exception as e:
        return None

def process_single_file(file_path: Path, port_name: str, gender_detector) -> Optional[Dict]:
    """处理单个XML文件 - 增强错误处理"""
    try:
        # 使用安全的XML解析
        soup = safe_parse_xml(file_path)
        if not soup:
            return None
            
        name_info = extract_name_info(soup, gender_detector)
        if not name_info:
            return None

        is_change, change_data = is_name_change_candidate(name_info)
        if is_change and change_data:
            path_tag = soup.find("common:path")
            # <-- FIX: Convert the ORCID ID to a plain Python string
            orcid_id = path_tag.get_text(strip=True) if path_tag else "unknown"
            
            return {
                'port_name': port_name,
                'id': orcid_id,
                'person_name': change_data[0],
                'person_date': change_data[1],
                'other_name': change_data[2],
                'other_date': change_data[3],
                'gender': name_info['gender']
            }
        return None

    except RecursionError as e:
        copy_problem_file(file_path, 'recursion_error', f"RecursionError in process_single_file: {str(e)}")
        return None
    except Exception as e:
        # 对于其他异常，不复制文件（因为safe_parse_xml已经处理了）
        return None

def _extract_name_parts(full_name: str) -> Dict[str, str]:
    """从全名中提取姓、名、中间名"""
    parts = full_name.strip().split()
    if not parts:
        return {'given': '', 'middle': '', 'family': ''}
    
    given = parts[0]
    if len(parts) == 1:
        return {'given': given, 'middle': '', 'family': ''}
    
    family = parts[-1]
    middle = ' '.join(parts[1:-1])
    return {'given': given, 'middle': middle, 'family': family}

def is_name_change_candidate(name_info: Dict) -> Tuple[bool, Optional[List]]:
    """
    判断是否为姓名变化候选者
    """
    try:
        # --- 1. 数据提取 ---
        base_name = name_info['base_name']
        person_created_date = name_info['person_created_date']
        other_names_data = name_info['other_names_data']
        family_name = name_info['family_name']
        given_name = name_info['given_name']

        if not all([base_name, person_created_date, other_names_data, family_name, given_name]):
            return False, None

        # 解析person:name的创建日期 
        try:
            person_date = datetime.fromisoformat(person_created_date.replace('Z', '+00:00'))
        except ValueError:
            return False, None

        # --- 2. 遍历 other-names，进行筛选和判断 ---
        for other_data in other_names_data:
            other_name_content = other_data.get('other_name_content')
            other_created_date = other_data.get('other_created_date')
            
            if not other_name_content or not other_created_date:
                continue

            try:
                other_date = datetime.fromisoformat(other_created_date.replace('Z', '+00:00'))
            except ValueError:
                continue

            # 时间差过滤
            if abs((person_date - other_date).days) < 30:
                continue

            # --- 3. 姓名标准化与结构化 ---
            cleaned_base = ' '.join(str(base_name).lower().strip().replace('.', '').replace(',', '').replace('-', ' ').split())
            cleaned_other = ' '.join(str(other_name_content).lower().strip().replace('.', '').replace(',', '').replace('-', ' ').split())
            
            # Levenshtein 距离
            if Levenshtein.distance(cleaned_base, cleaned_other) < 2:
                continue

            base_parts = _extract_name_parts(cleaned_base)
            other_parts = _extract_name_parts(cleaned_other)

            if not all([base_parts['given'], other_parts['given'], base_parts['family'], other_parts['family']]):
                continue

            # --- 4. 核心逻辑判断 ---
            
            # a) 验证是否为同一个人 (名字部分容错判断)
            if Levenshtein.distance(base_parts['given'], other_parts['given']) >= 2:
                continue
            
            # b) 获取并比较完整的姓氏部分
            base_full_surname = f"{base_parts['middle']} {base_parts['family']}".strip()
            other_full_surname = f"{other_parts['middle']} {other_parts['family']}".strip()

            if Levenshtein.distance(base_full_surname, other_full_surname) < 2:
                continue

            # c) 排除只增加/减少中间名的情况
            is_subset_change = (base_full_surname in other_full_surname or other_full_surname in base_full_surname)
            if is_subset_change and Levenshtein.distance(base_parts['family'], other_parts['family']) <= 1:
                continue

            # d) 排除缩写情况
            if (len(base_parts['family']) == 1 and len(other_parts['family']) > 1 and base_parts['family'] == other_parts['family'][0]) or \
               (len(other_parts['family']) == 1 and len(base_parts['family']) > 1 and other_parts['family'] == base_parts['family'][0]):
                continue

            # --- 5. 确认是候选者 ---
            
            if person_date < other_date:
                older_name, newer_name = cleaned_base, cleaned_other
                older_date_str, newer_date_str = person_created_date, other_created_date
            else:
                older_name, newer_name = cleaned_other, cleaned_base
                older_date_str, newer_date_str = other_created_date, person_created_date

            return True, [older_name, older_date_str, newer_name, newer_date_str]

        return False, None

    except RecursionError:
        raise  # 让上层处理
    except Exception as e:
        return False, None

def process_file_chunk(args):
    """处理文件块的工作函数 - 增强错误处理"""
    file_paths, port_name, process_id = args
    
    # 在子进程中初始化 gender detector
    try:
        local_gender_detector = gender.Detector()
    except Exception as e:
        print(f"Process {process_id}: Failed to initialize gender detector: {e}")
        return [], 0, 0, 0  # 增加错误文件计数
    
    results = []
    processed = 0
    error_count = 0
    
    for file_path in file_paths:
        try:
            # 检查文件大小
            # file_size = file_path.stat().st_size
            # if file_size > CONFIG['max_file_size']:
            #     copy_problem_file(file_path, 'large_files', f"File size: {file_size} bytes")
            #     error_count += 1
            #     processed += 1
            #     continue
            
            result = process_single_file(file_path, port_name, local_gender_detector)
            if result:
                results.append(result)
            processed += 1
            
            # 每处理100000个文件报告一次进度
            if processed % 100000 == 0:
                print(f"Process {process_id}: Processed {processed}/{len(file_paths)} files in {port_name}, errors: {error_count}")
                
        except RecursionError as e:
            copy_problem_file(file_path, 'recursion_error', f"RecursionError: {str(e)}")
            error_count += 1
            processed += 1
        except MemoryError as e:
            copy_problem_file(file_path, 'large_files', f"MemoryError: {str(e)}")
            error_count += 1
            processed += 1
        except Exception as e:
            error_msg = f"{type(e).__name__}: {str(e)}"
            if "recursion" in str(e).lower():
                copy_problem_file(file_path, 'recursion_error', error_msg)
            elif any(keyword in str(e).lower() for keyword in ['parse', 'xml', 'malformed']):
                copy_problem_file(file_path, 'parse_error', error_msg)
            else:
                copy_problem_file(file_path, 'other_errors', error_msg)
            error_count += 1
            processed += 1
    
    print(f"Process {process_id} completed: {processed} files, {len(results)} results, {error_count} errors")
    return results, processed, len(results), error_count

# --- 修改 get_file_chunks (简化文件发现) ---
def get_file_chunks(base_path: str, chunk_size: int) -> List[Tuple]:
    """获取文件分块信息 - 简化版，用于处理单个文件夹内的文件"""
    base_path = Path(base_path)
    chunks = []
    chunk_id = 0
    
    all_files = [f for f in base_path.iterdir() if f.is_file()]
    print(f"在 {base_path} 中找到 {len(all_files)} 个大文件进行重新处理。")
    
    if not all_files:
        return []
        
    for i in range(0, len(all_files), chunk_size):
        file_chunk = all_files[i:i + chunk_size]
        # port_name 在这里不重要，可以设为固定值
        chunks.append((file_chunk, 'large_files_reprocess', chunk_id))
        chunk_id += 1
    
    return chunks
    
def write_results_batch(results_batch: List[Dict], output_file: str, write_header: bool = False):
    """批量写入结果到CSV文件"""
    mode = 'w' if write_header else 'a'
    with open(output_file, mode, newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['port_name', 'id', 'person_name', 'person_date', 
                                             'other_name', 'other_date', 'gender'])
        if write_header:
            writer.writeheader()
        writer.writerows(results_batch)

def signal_handler(signum, frame):
    """信号处理器"""
    print("\n收到中断信号，正在安全退出...")
    sys.exit(0)

def write_summary_report(total_processed: int, total_results: int, total_errors: int, duration: float):
    """写入处理总结报告"""
    summary_file = Path(CONFIG['problem_files_dir']) / 'processing_summary.txt'
    with open(summary_file, 'w', encoding='utf-8') as f:
        f.write(f"ORCID 姓名变化检测处理总结\n")
        f.write(f"处理时间: {datetime.now().isoformat()}\n")
        f.write(f"="*50 + "\n")
        f.write(f"总处理文件数: {total_processed:,}\n")
        f.write(f"发现姓名变化: {total_results:,}\n")
        f.write(f"错误文件数: {total_errors:,}\n")
        f.write(f"成功率: {((total_processed - total_errors) / total_processed * 100):.2f}%\n")
        f.write(f"处理时间: {duration/3600:.2f} 小时\n")
        f.write(f"平均速度: {total_processed/duration:.0f} 文件/秒\n")
        f.write(f"\n错误文件分类:\n")
        
        # 统计各类错误文件数量
        problem_dir = Path(CONFIG['problem_files_dir'])
        for error_type in ['recursion_error', 'parse_error', 'large_files', 'other_errors']:
            error_dir = problem_dir / error_type
            if error_dir.exists():
                error_files = list(error_dir.glob("*.xml"))
                f.write(f"  {error_type}: {len(error_files)} 个文件\n")


def main():
    """主函数 - 用于重新处理"""
    signal.signal(signal.SIGINT, signal_handler)
    signal.signal(signal.SIGTERM, signal_handler)
    
    start_time = time.time()
    
    print(f"设置新的问题文件目录: {CONFIG['problem_files_dir']}")
    setup_problem_files_dir() # 你需要把这个函数复制过来
    
    print(f"正在从 {CONFIG['base_path']} 收集大文件...")
    chunks = get_file_chunks(CONFIG['base_path'], CONFIG['chunk_size'])
    total_chunks = len(chunks)
    
    if total_chunks == 0:
        print("没有找到需要重新处理的文件。")
        return
    
    print(f"发现 {total_chunks} 个文件块，开始重新处理...")
    write_results_batch([], CONFIG['output_file'], write_header=True) # 你需要把这个函数复制过来
    
    total_processed = 0
    total_results = 0
    results_buffer = []
    
    try:
        with ProcessPoolExecutor(max_workers=CONFIG['max_workers']) as executor:
            future_to_chunk_idx = {executor.submit(process_file_chunk, chunk): i for i, chunk in enumerate(chunks)}
            
            for i, future in enumerate(as_completed(future_to_chunk_idx)):
                try:
                    chunk_results, chunk_processed, chunk_found, _ = future.result()
                    total_processed += chunk_processed
                    total_results += chunk_found
                    results_buffer.extend(chunk_results)
                    
                    if len(results_buffer) >= CONFIG['batch_size']:
                        write_results_batch(results_buffer, CONFIG['output_file'])
                        results_buffer = []
                    
                    progress = (i + 1) / total_chunks * 100
                    print(f"重新处理进度: {progress:.1f}% ({i + 1}/{total_chunks})", end='\r')
                except Exception as e:
                    print(f"\n处理块时出错: {e}")
    finally:
        if results_buffer:
            write_results_batch(results_buffer, CONFIG['output_file'])
    
    duration = time.time() - start_time
    print(f"\n大文件重新处理完成！")
    print(f"总共处理文件数: {total_processed}")
    print(f"新发现姓名变化: {total_results}")
    print(f"处理时间: {duration:.1f} 秒")
    print(f"新结果已保存至: {CONFIG['output_file']}")

if __name__ == "__main__":
    main()
# Out:
# 设置新的问题文件目录: /hy-tmp/problem_xml_files_reprocessing
# 正在从 /hy-tmp/problem_xml_files/large_files 收集大文件...
# 在 /hy-tmp/problem_xml_files/large_files 中找到 363 个大文件进行重新处理。
# 发现 8 个文件块，开始重新处理...
# Process 0 completed: 50 files, 0 results, 0 errors
# Process 1 completed: 50 files, 0 results, 0 errors
# Process 3 completed: 50 files, 0 results, 0 errors
# Process 2 completed: 50 files, 0 results, 0 errors
# Process 4 completed: 50 files, 0 results, 0 errors
# Process 5 completed: 50 files, 0 results, 0 errors
# Process 7 completed: 13 files, 0 results, 0 errors
# Process 6 completed: 50 files, 0 results, 0 errors
# 重新处理进度: 100.0% (8/8)
# 大文件重新处理完成！
# 总共处理文件数: 363
# 新发现姓名变化: 0
# 处理时间: 1117.0 秒
# 新结果已保存至: /hy-tmp/large_files_results.csv

# %%
#!/usr/bin/env python3
"""
合并ORCID姓名变化检测结果的脚本
"""
import pandas as pd
import os

# --- 配置 ---
ORIGINAL_RESULTS_FILE = '/hy-tmp/female_name_changes.csv'
LARGE_FILES_RESULTS_FILE = '/hy-tmp/large_files_results.csv'
MERGED_OUTPUT_FILE = '/hy-tmp/final_female_name_changes.csv'

def merge_results():

    df_original = pd.read_csv(ORIGINAL_RESULTS_FILE)
    print(f"原始结果包含 {len(df_original):,} 条记录。")

    df_large = pd.read_csv(LARGE_FILES_RESULTS_FILE)
    print(f"大文件结果包含 {len(df_large):,} 条记录。")

    df_merged = pd.concat([df_original, df_large], ignore_index=True)
    df_merged.drop_duplicates(subset=['id'], inplace=True)

    total_records = len(df_merged)
    print(f"合并后总记录数: {total_records:,}")

    print(f"正在保存最终结果至: {MERGED_OUTPUT_FILE}")
    df_merged.to_csv(MERGED_OUTPUT_FILE, index=False, encoding='utf-8')

if __name__ == "__main__":
    merge_results()
# Out:
# 原始结果包含 42,389 条记录。
# 大文件结果包含 0 条记录。
# 合并后总记录数: 42,389
# 正在保存最终结果至: /hy-tmp/final_female_name_changes.csv
