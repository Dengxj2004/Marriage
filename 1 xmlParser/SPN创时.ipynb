# %%
#!/usr/bin/env python3
"""
ORCID 女性姓名变化检测程序 - 修复版本
添加了对难以处理的XML文件的错误处理和复制功能
解决了多进程返回结果时的 Pickling RecursionError 问题
"""

import os
import csv
import logging
import multiprocessing as mp
from multiprocessing import Pool, Manager, Lock
from concurrent.futures import ProcessPoolExecutor, as_completed
import time
from pathlib import Path
from typing import Dict, List, Optional, Tuple
import signal
import sys
from functools import partial
import shutil
import traceback

from bs4 import BeautifulSoup
import gender_guesser.detector as gender
import Levenshtein
from datetime import datetime


# 增加递归限制
sys.setrecursionlimit(150000)

# 全局配置
CONFIG = {
    'base_path': '/hy-tmp/orcid/ORCID_2024_10_summaries',
    'output_file': '/hy-tmp/female_name_changes1.csv',
    'log_file': '/hy-tmp/orcid_processing1.log',
    'problem_files_dir': '/hy-tmp/problem_xml_files1',  # 问题文件存储目录
    'max_workers': 42,  
    'chunk_size': 150000,  # 每个进程处理的文件数量
    'batch_size': 1000,  # 批量写入CSV的记录数
    'max_file_size': 1000 * 1024 * 1024,  # 10MB 文件大小限制
}

def setup_problem_files_dir():
    """创建问题文件存储目录"""
    problem_dir = Path(CONFIG['problem_files_dir'])
    problem_dir.mkdir(parents=True, exist_ok=True)
    
    # 创建子目录
    (problem_dir / 'recursion_error').mkdir(exist_ok=True)
    (problem_dir / 'parse_error').mkdir(exist_ok=True)
    (problem_dir / 'large_files').mkdir(exist_ok=True)
    (problem_dir / 'other_errors').mkdir(exist_ok=True)
    
    return problem_dir

def copy_problem_file(file_path: Path, error_type: str, error_msg: str = ""):
    """复制问题文件到指定目录"""
    try:
        problem_dir = Path(CONFIG['problem_files_dir'])
        error_dir = problem_dir / error_type
        
        # 创建唯一的文件名（避免重名）
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")
        new_filename = f"{file_path.stem}_{timestamp}{file_path.suffix}"
        dest_path = error_dir / new_filename
        
        shutil.copy2(file_path, dest_path)
        
        # 记录错误信息
        log_file = error_dir / "error_log.txt"
        with open(log_file, 'a', encoding='utf-8') as f:
            f.write(f"{datetime.now().isoformat()}\t{file_path}\t{new_filename}\t{error_msg}\n")
            
        return True
    except Exception as e:
        print(f"无法复制问题文件 {file_path}: {e}")
        return False

def safe_parse_xml(file_path: Path) -> Optional[BeautifulSoup]:
    """安全的XML解析函数，包含各种错误处理"""
    try:
        # 检查文件大小
        file_size = file_path.stat().st_size
        if file_size > CONFIG['max_file_size']:
            copy_problem_file(file_path, 'large_files', f"File size: {file_size} bytes")
            return None
        
        # 尝试解析XML
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
            
            # 检查内容长度
            if len(content) > 10000000000:  # 1000MB文本内容限制
                copy_problem_file(file_path, 'large_files', f"Content length: {len(content)} chars")
                return None
            
            soup = BeautifulSoup(content, 'lxml-xml')
            return soup
            
    except RecursionError as e:
        copy_problem_file(file_path, 'recursion_error', f"RecursionError: {str(e)}")
        return None
    except Exception as e:
        error_msg = f"{type(e).__name__}: {str(e)}"
        if "recursion" in str(e).lower():
            copy_problem_file(file_path, 'recursion_error', error_msg)
        elif any(keyword in str(e).lower() for keyword in ['parse', 'xml', 'malformed']):
            copy_problem_file(file_path, 'parse_error', error_msg)
        else:
            copy_problem_file(file_path, 'other_errors', error_msg)
        return None

def extract_name_info(soup: BeautifulSoup, gender_detector) -> Optional[Dict]:
    """从BeautifulSoup对象中提取姓名信息和性别"""
    try:
        person_name_tag = soup.find("person:name")
        if not person_name_tag:
            return None

        # 提取person:name基本信息
        person_created_date_tag = person_name_tag.find("common:created-date")
        given_names_tag = person_name_tag.find("personal-details:given-names")
        family_name_tag = person_name_tag.find("personal-details:family-name")

        # <-- FIX: Convert all extracted text to plain Python strings
        person_created_date = person_created_date_tag.get_text(strip=True) if person_created_date_tag else None
        given_name = given_names_tag.get_text(strip=True) if given_names_tag else None
        family_name = family_name_tag.get_text(strip=True) if family_name_tag else None

        # 性别识别 - 只处理女性
        if not given_name:
            return None
        
        gender_result = gender_detector.get_gender(given_name.split()[0])
        if gender_result not in ['female', 'mostly_female']:
            return None 

        # --- 修改开始 ---
        # 原来的构建基准姓名方式:
        # if not family_name:
        #     return None
        # base_name = f"{given_name} {family_name}".strip()

        # 新的构建基准姓名方式 (根据您的要求):
        # 从第一个 other-name:other-name 中提取 source-name 作为 base_name
        base_name = None
        first_other_name_tag = soup.find("other-name:other-name")
        if first_other_name_tag:
            source_name_tag = first_other_name_tag.find("common:source-name")
            if source_name_tag:
                # 使用 .get_text(strip=True) 以保持代码风格一致性和健壮性
                base_name = source_name_tag.get_text(strip=True)

        # 如果没有成功提取到新的 base_name，则无法进行后续比较，直接返回 None
        if not base_name:
            return None
        # --- 修改结束 ---

        # 提取other-name信息 - 可能有多个
        other_names_data = []
        other_name_tags = soup.find_all("other-name:other-name")
        
        for other_name_tag in other_name_tags:
            other_created_date_tag = other_name_tag.find("common:created-date")
            other_name_content_tag = other_name_tag.find("other-name:content")
            
            # <-- FIX: Convert all extracted text to plain Python strings
            other_created_date = other_created_date_tag.get_text(strip=True) if other_created_date_tag else None
            other_name_content = other_name_content_tag.get_text(strip=True) if other_name_content_tag else None
            
            if other_created_date and other_name_content:
                other_names_data.append({
                    'other_name_content': other_name_content,
                    'other_created_date': other_created_date
                })

        if not other_names_data:
            return None

        return {
            'person_created_date': person_created_date,
            'given_name': given_name,
            'family_name': family_name,
            'base_name': base_name,
            'other_names_data': other_names_data,
            'gender': gender_result
        }

    except RecursionError:
        raise  # 让上层处理
    except Exception as e:
        return None

def process_single_file(file_path: Path, port_name: str, gender_detector) -> Optional[Dict]:
    """处理单个XML文件 - 增强错误处理"""
    try:
        # 使用安全的XML解析
        soup = safe_parse_xml(file_path)
        if not soup:
            return None
            
        name_info = extract_name_info(soup, gender_detector)
        if not name_info:
            return None

        is_change, change_data = is_name_change_candidate(name_info)
        if is_change and change_data:
            path_tag = soup.find("common:path")
            # <-- FIX: Convert the ORCID ID to a plain Python string
            orcid_id = path_tag.get_text(strip=True) if path_tag else "unknown"
            
            return {
                'port_name': port_name,
                'id': orcid_id,
                'person_name': change_data[0],
                'person_date': change_data[1],
                'other_name': change_data[2],
                'other_date': change_data[3],
                'gender': name_info['gender']
            }
        return None

    except RecursionError as e:
        copy_problem_file(file_path, 'recursion_error', f"RecursionError in process_single_file: {str(e)}")
        return None
    except Exception as e:
        # 对于其他异常，不复制文件（因为safe_parse_xml已经处理了）
        return None

def _extract_name_parts(full_name: str) -> Dict[str, str]:
    """从全名中提取姓、名、中间名"""
    parts = full_name.strip().split()
    if not parts:
        return {'given': '', 'middle': '', 'family': ''}
    
    given = parts[0]
    if len(parts) == 1:
        return {'given': given, 'middle': '', 'family': ''}
    
    family = parts[-1]
    middle = ' '.join(parts[1:-1])
    return {'given': given, 'middle': middle, 'family': family}

def is_name_change_candidate(name_info: Dict) -> Tuple[bool, Optional[List]]:
    """
    判断是否为姓名变化候选者
    """
    try:
        # --- 1. 数据提取 ---
        base_name = name_info['base_name']
        person_created_date = name_info['person_created_date']
        other_names_data = name_info['other_names_data']
        family_name = name_info['family_name']
        given_name = name_info['given_name']

        if not all([base_name, person_created_date, other_names_data, family_name, given_name]):
            return False, None

        # 解析person:name的创建日期 
        try:
            person_date = datetime.fromisoformat(person_created_date.replace('Z', '+00:00'))
        except ValueError:
            return False, None

        # --- 2. 遍历 other-names，进行筛选和判断 ---
        for other_data in other_names_data:
            other_name_content = other_data.get('other_name_content')
            other_created_date = other_data.get('other_created_date')
            
            if not other_name_content or not other_created_date:
                continue

            try:
                other_date = datetime.fromisoformat(other_created_date.replace('Z', '+00:00'))
            except ValueError:
                continue

            # 时间差过滤
            if abs((person_date - other_date).days) < 30:
                continue

            # --- 3. 姓名标准化与结构化 ---
            cleaned_base = ' '.join(str(base_name).lower().strip().replace('.', '').replace(',', '').replace('-', ' ').split())
            cleaned_other = ' '.join(str(other_name_content).lower().strip().replace('.', '').replace(',', '').replace('-', ' ').split())
            
            # Levenshtein 距离
            if Levenshtein.distance(cleaned_base, cleaned_other) < 2:
                continue

            base_parts = _extract_name_parts(cleaned_base)
            other_parts = _extract_name_parts(cleaned_other)

            if not all([base_parts['given'], other_parts['given'], base_parts['family'], other_parts['family']]):
                continue

            # --- 4. 核心逻辑判断 ---
            
            # a) 验证是否为同一个人 (名字部分容错判断)
            if Levenshtein.distance(base_parts['given'], other_parts['given']) >= 2:
                continue
            
            # b) 获取并比较完整的姓氏部分
            base_full_surname = f"{base_parts['middle']} {base_parts['family']}".strip()
            other_full_surname = f"{other_parts['middle']} {other_parts['family']}".strip()

            if Levenshtein.distance(base_full_surname, other_full_surname) < 2:
                continue

            # c) 排除只增加/减少中间名的情况
            is_subset_change = (base_full_surname in other_full_surname or other_full_surname in base_full_surname)
            if is_subset_change and Levenshtein.distance(base_parts['family'], other_parts['family']) <= 1:
                continue

            # d) 排除缩写情况
            if (len(base_parts['family']) == 1 and len(other_parts['family']) > 1 and base_parts['family'] == other_parts['family'][0]) or \
               (len(other_parts['family']) == 1 and len(base_parts['family']) > 1 and other_parts['family'] == base_parts['family'][0]):
                continue

            # --- 5. 确认是候选者 ---
            
            if person_date < other_date:
                older_name, newer_name = cleaned_base, cleaned_other
                older_date_str, newer_date_str = person_created_date, other_created_date
            else:
                older_name, newer_name = cleaned_other, cleaned_base
                older_date_str, newer_date_str = other_created_date, person_created_date

            return True, [older_name, older_date_str, newer_name, newer_date_str]

        return False, None

    except RecursionError:
        raise  # 让上层处理
    except Exception as e:
        return False, None

def process_file_chunk(args):
    """处理文件块的工作函数 - 增强错误处理"""
    file_paths, port_name, process_id = args
    
    # 在子进程中初始化 gender detector
    try:
        local_gender_detector = gender.Detector()
    except Exception as e:
        print(f"Process {process_id}: Failed to initialize gender detector: {e}")
        return [], 0, 0, 0  # 增加错误文件计数
    
    results = []
    processed = 0
    error_count = 0
    
    for file_path in file_paths:
        try:
            # 检查文件大小
            file_size = file_path.stat().st_size
            if file_size > CONFIG['max_file_size']:
                copy_problem_file(file_path, 'large_files', f"File size: {file_size} bytes")
                error_count += 1
                processed += 1
                continue
            
            result = process_single_file(file_path, port_name, local_gender_detector)
            if result:
                results.append(result)
            processed += 1
            
            # 每处理100000个文件报告一次进度
            if processed % 10000000 == 0:
                print(f"Process {process_id}: Processed {processed}/{len(file_paths)} files in {port_name}, errors: {error_count}")
                
        except RecursionError as e:
            copy_problem_file(file_path, 'recursion_error', f"RecursionError: {str(e)}")
            error_count += 1
            processed += 1
        except MemoryError as e:
            copy_problem_file(file_path, 'large_files', f"MemoryError: {str(e)}")
            error_count += 1
            processed += 1
        except Exception as e:
            error_msg = f"{type(e).__name__}: {str(e)}"
            if "recursion" in str(e).lower():
                copy_problem_file(file_path, 'recursion_error', error_msg)
            elif any(keyword in str(e).lower() for keyword in ['parse', 'xml', 'malformed']):
                copy_problem_file(file_path, 'parse_error', error_msg)
            else:
                copy_problem_file(file_path, 'other_errors', error_msg)
            error_count += 1
            processed += 1
    
    print(f"Process {process_id} completed: {processed} files, {len(results)} results, {error_count} errors")
    return results, processed, len(results), error_count

def get_file_chunks(base_path: str, chunk_size: int = 10000) -> List[Tuple]:
    """获取文件分块信息"""
    base_path = Path(base_path)
    chunks = []
    chunk_id = 0
    
    for portfolio_folder in base_path.iterdir():
        if not portfolio_folder.is_dir():
            continue
            
        # 获取文件夹中的所有XML文件
        xml_files = list(portfolio_folder.glob("*.xml"))
        if not xml_files:
            xml_files = [f for f in portfolio_folder.iterdir() if f.is_file()]  # 如果没有.xml扩展名
            
        # 将文件分块
        for i in range(0, len(xml_files), chunk_size):
            file_chunk = xml_files[i:i + chunk_size]
            chunks.append((file_chunk, portfolio_folder.name, chunk_id))
            chunk_id += 1
    
    return chunks
    
def write_results_batch(results_batch: List[Dict], output_file: str, write_header: bool = False):
    """批量写入结果到CSV文件"""
    mode = 'w' if write_header else 'a'
    with open(output_file, mode, newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['port_name', 'id', 'person_name', 'person_date', 
                                             'other_name', 'other_date', 'gender'])
        if write_header:
            writer.writeheader()
        writer.writerows(results_batch)

def signal_handler(signum, frame):
    """信号处理器"""
    print("\n收到中断信号，正在安全退出...")
    sys.exit(0)

def write_summary_report(total_processed: int, total_results: int, total_errors: int, duration: float):
    """写入处理总结报告"""
    summary_file = Path(CONFIG['problem_files_dir']) / 'processing_summary1.txt'
    with open(summary_file, 'w', encoding='utf-8') as f:
        f.write(f"ORCID 姓名变化检测处理总结\n")
        f.write(f"处理时间: {datetime.now().isoformat()}\n")
        f.write(f"="*50 + "\n")
        f.write(f"总处理文件数: {total_processed:,}\n")
        f.write(f"发现姓名变化: {total_results:,}\n")
        f.write(f"错误文件数: {total_errors:,}\n")
        f.write(f"成功率: {((total_processed - total_errors) / total_processed * 100):.2f}%\n")
        f.write(f"处理时间: {duration/3600:.2f} 小时\n")
        f.write(f"平均速度: {total_processed/duration:.0f} 文件/秒\n")
        f.write(f"\n错误文件分类:\n")
        
        # 统计各类错误文件数量
        problem_dir = Path(CONFIG['problem_files_dir'])
        for error_type in ['recursion_error', 'parse_error', 'large_files', 'other_errors']:
            error_dir = problem_dir / error_type
            if error_dir.exists():
                error_files = list(error_dir.glob("*.xml"))
                f.write(f"  {error_type}: {len(error_files)} 个文件\n")

def main():
    """主函数"""
    # 注册信号处理器
    signal.signal(signal.SIGINT, signal_handler)
    signal.signal(signal.SIGTERM, signal_handler)
    
    start_time = time.time()
    
    # 设置问题文件目录
    print("设置问题文件存储目录...")
    setup_problem_files_dir()
    
    # 获取文件分块
    print("正在分析文件结构...")
    chunks = get_file_chunks(CONFIG['base_path'], CONFIG['chunk_size'])
    total_chunks = len(chunks)
    
    print(f"发现 {total_chunks} 个文件块")
    if total_chunks == 0:
        print("没有找到需要处理的文件")
        return
    
    # 初始化输出文件
    write_results_batch([], CONFIG['output_file'], write_header=True)
    
    # 统计变量
    total_processed = 0
    total_results = 0
    total_errors = 0
    results_buffer = []
    
    try:
        # 使用进程池处理
        with ProcessPoolExecutor(max_workers=CONFIG['max_workers']) as executor:
            print(f"启动 {CONFIG['max_workers']} 个工作进程...")
            print(f"问题文件将保存到: {CONFIG['problem_files_dir']}")
            
            # 提交所有任务
            future_to_chunk = {executor.submit(process_file_chunk, chunk): i 
                              for i, chunk in enumerate(chunks)}
            
            # 处理完成的任务
            for future in as_completed(future_to_chunk):
                chunk_idx = future_to_chunk[future]
                try:
                    chunk_results, chunk_processed, chunk_found, chunk_errors = future.result()
                    
                    total_processed += chunk_processed
                    total_results += chunk_found
                    total_errors += chunk_errors
                    results_buffer.extend(chunk_results)
                    
                    # 批量写入结果
                    if len(results_buffer) >= CONFIG['batch_size']:
                        write_results_batch(results_buffer, CONFIG['output_file'])
                        results_buffer = []
                    
                    # 进度报告
                    progress = (chunk_idx + 1) / total_chunks * 100
                    print(f"进度: {progress:.1f}% ({chunk_idx + 1}/{total_chunks}), "
                          f"已处理: {total_processed:,}, 发现变化: {total_results:,}, 错误: {total_errors:,}")
                    
                except Exception as e:
                    print(f"处理块 {chunk_idx} 时出错: {e}")
                    print(f"错误详情: {traceback.format_exc()}")
    
    except KeyboardInterrupt:
        print("\n用户中断程序执行")
        return
    except Exception as e:
        print(f"程序执行出错: {e}")
        print(f"错误详情: {traceback.format_exc()}")
        return
    finally:
        # 写入剩余结果
        if results_buffer:
            write_results_batch(results_buffer, CONFIG['output_file'])
    
    # 最终统计
    end_time = time.time()
    duration = end_time - start_time
    
    print("\n" + "="*60)
    print("处理完成!")
    print(f"总处理文件数: {total_processed:,}")
    print(f"发现姓名变化: {total_results:,}")
    print(f"错误文件数: {total_errors:,}")
    print(f"成功率: {((total_processed - total_errors) / total_processed * 100):.2f}%" if total_processed > 0 else "N/A")
    print(f"处理时间: {duration/3600:.1f} 小时 ({duration/60:.1f} 分钟)")
    print(f"平均速度: {total_processed/duration:.0f} 文件/秒" if duration > 0 else "N/A")
    print(f"结果已保存至: {CONFIG['output_file']}")
    print(f"问题文件已保存至: {CONFIG['problem_files_dir']}")
    print("="*60)
    
    # 写入处理总结报告
    write_summary_report(total_processed, total_results, total_errors, duration)

if __name__ == "__main__":   
    main()
# Out:
# 设置问题文件存储目录...
# 正在分析文件结构...
# 发现 1100 个文件块
# 启动 42 个工作进程...
# 问题文件将保存到: /hy-tmp/problem_xml_files1
# Process 13 completed: 19931 files, 48 results, 0 errors
# 进度: 1.3% (14/1100), 已处理: 19,931, 发现变化: 48, 错误: 0
# Process 5 completed: 20060 files, 34 results, 0 errors
# 进度: 0.5% (6/1100), 已处理: 39,991, 发现变化: 82, 错误: 0
# Process 35 completed: 19890 files, 29 results, 0 errors
# 进度: 3.3% (36/1100), 已处理: 59,881, 发现变化: 111, 错误: 0
# Process 40 completed: 19895 files, 46 results, 0 errors
# Process 19 completed: 20007 files, 28 results, 0 errors
# 进度: 3.7% (41/1100), 已处理: 79,776, 发现变化: 157, 错误: 0
# 进度: 1.8% (20/1100), 已处理: 99,783, 发现变化: 185, 错误: 0
# Process 12 completed: 19917 files, 42 results, 0 errors
# 进度: 1.2% (13/1100), 已处理: 119,700, 发现变化: 227, 错误: 0
# Process 1 completed: 19856 files, 37 results, 0 errors
# 进度: 0.2% (2/1100), 已处理: 139,556, 发现变化: 264, 错误: 0
# Process 8 completed: 20063 files, 41 results, 0 errors
# 进度: 0.8% (9/1100), 已处理: 159,619, 发现变化: 305, 错误: 0
# Process 25 completed: 19910 files, 42 results, 0 errors
# 进度: 2.4% (26/1100), 已处理: 179,529, 发现变化: 347, 错误: 0
# Process 33 completed: 19880 files, 31 results, 0 errors
# 进度: 3.1% (34/1100), 已处理: 199,409, 发现变化: 378, 错误: 0
# Process 4 completed: 20007 files, 37 results, 0 errors
# 进度: 0.5% (5/1100), 已处理: 219,416, 发现变化: 415, 错误: 0
# Process 22 completed: 19970 files, 41 results, 0 errors
# 进度: 2.1% (23/1100), 已处理: 239,386, 发现变化: 456, 错误: 0
# Process 29 completed: 19943 files, 30 results, 0 errors
# 进度: 2.7% (30/1100), 已处理: 259,329, 发现变化: 486, 错误: 0
# Process 16 completed: 19917 files, 49 results, 0 errors
# Process 7 completed: 19843 files, 32 results, 0 errors
# 进度: 1.5% (17/1100), 已处理: 279,246, 发现变化: 535, 错误: 0
# 进度: 0.7% (8/1100), 已处理: 299,089, 发现变化: 567, 错误: 0
# Process 23 completed: 19939 files, 34 results, 0 errors
# Process 15 completed: 20049 files, 36 results, 0 errors
# 进度: 2.2% (24/1100), 已处理: 319,028, 发现变化: 601, 错误: 0
# 进度: 1.5% (16/1100), 已处理: 339,077, 发现变化: 637, 错误: 0
# Process 28 completed: 19874 files, 32 results, 0 errors
# 进度: 2.6% (29/1100), 已处理: 358,951, 发现变化: 669, 错误: 0
# Process 2 completed: 19863 files, 32 results, 0 errors
# 进度: 0.3% (3/1100), 已处理: 378,814, 发现变化: 701, 错误: 0
# Process 30 completed: 20011 files, 44 results, 0 errors
# 进度: 2.8% (31/1100), 已处理: 398,825, 发现变化: 745, 错误: 0
# Process 10 completed: 20002 files, 37 results, 0 errors
# 进度: 1.0% (11/1100), 已处理: 418,827, 发现变化: 782, 错误: 0
# Process 21 completed: 19904 files, 33 results, 0 errors
# 进度: 2.0% (22/1100), 已处理: 438,731, 发现变化: 815, 错误: 0
# Process 18 completed: 19896 files, 44 results, 0 errors
# 进度: 1.7% (19/1100), 已处理: 458,627, 发现变化: 859, 错误: 0
# Process 34 completed: 20023 files, 36 results, 0 errors
# 进度: 3.2% (35/1100), 已处理: 478,650, 发现变化: 895, 错误: 0
# Process 3 completed: 19992 files, 39 results, 0 errors
# 进度: 0.4% (4/1100), 已处理: 498,642, 发现变化: 934, 错误: 0
# Process 24 completed: 19883 files, 39 results, 0 errors
# Process 37 completed: 19865 files, 33 results, 0 errors
# 进度: 2.3% (25/1100), 已处理: 518,525, 发现变化: 973, 错误: 0
# 进度: 3.5% (38/1100), 已处理: 538,390, 发现变化: 1,006, 错误: 0
# Process 39 completed: 19746 files, 38 results, 0 errors
# 进度: 3.6% (40/1100), 已处理: 558,136, 发现变化: 1,044, 错误: 0
# Process 27 completed: 19803 files, 44 results, 0 errors
# Process 41 completed: 19967 files, 48 results, 0 errors
# 进度: 2.5% (28/1100), 已处理: 577,939, 发现变化: 1,088, 错误: 0
# 进度: 3.8% (42/1100), 已处理: 597,906, 发现变化: 1,136, 错误: 0
# Process 6 completed: 19782 files, 43 results, 0 errors
# 进度: 0.6% (7/1100), 已处理: 617,688, 发现变化: 1,179, 错误: 0
# Process 14 completed: 19862 files, 37 results, 0 errors
# 进度: 1.4% (15/1100), 已处理: 637,550, 发现变化: 1,216, 错误: 0
# Process 20 completed: 20003 files, 41 results, 0 errors
# Process 31 completed: 19941 files, 30 results, 0 errors
# 进度: 1.9% (21/1100), 已处理: 657,553, 发现变化: 1,257, 错误: 0
# 进度: 2.9% (32/1100), 已处理: 677,494, 发现变化: 1,287, 错误: 0
# Process 9 completed: 19910 files, 34 results, 0 errors
# 进度: 0.9% (10/1100), 已处理: 697,404, 发现变化: 1,321, 错误: 0
# Process 11 completed: 19997 files, 43 results, 0 errors
# 进度: 1.1% (12/1100), 已处理: 717,401, 发现变化: 1,364, 错误: 0
# Process 38 completed: 19812 files, 36 results, 0 errors
# 进度: 3.5% (39/1100), 已处理: 737,213, 发现变化: 1,400, 错误: 0
# Process 32 completed: 19988 files, 45 results, 0 errors
# 进度: 3.0% (33/1100), 已处理: 757,201, 发现变化: 1,445, 错误: 0
# Process 17 completed: 20003 files, 27 results, 0 errors
# 进度: 1.6% (18/1100), 已处理: 777,204, 发现变化: 1,472, 错误: 0
# Process 0 completed: 19980 files, 34 results, 0 errors
# 进度: 0.1% (1/1100), 已处理: 797,184, 发现变化: 1,506, 错误: 0
# Process 36 completed: 19881 files, 44 results, 0 errors
# 进度: 3.4% (37/1100), 已处理: 817,065, 发现变化: 1,550, 错误: 0
# Process 26 completed: 19904 files, 43 results, 0 errors
# 进度: 2.5% (27/1100), 已处理: 836,969, 发现变化: 1,593, 错误: 0
# Process 42 completed: 19990 files, 40 results, 0 errors
# 进度: 3.9% (43/1100), 已处理: 856,959, 发现变化: 1,633, 错误: 0
# Process 72 completed: 20009 files, 48 results, 0 errors
# 进度: 6.6% (73/1100), 已处理: 876,968, 发现变化: 1,681, 错误: 0
# Process 46 completed: 19896 files, 35 results, 0 errors
# 进度: 4.3% (47/1100), 已处理: 896,864, 发现变化: 1,716, 错误: 0
# Process 48 completed: 19961 files, 34 results, 0 errors
# 进度: 4.5% (49/1100), 已处理: 916,825, 发现变化: 1,750, 错误: 0
# Process 62 completed: 19932 files, 48 results, 0 errors
# 进度: 5.7% (63/1100), 已处理: 936,757, 发现变化: 1,798, 错误: 0
# Process 43 completed: 20025 files, 32 results, 0 errors
# 进度: 4.0% (44/1100), 已处理: 956,782, 发现变化: 1,830, 错误: 0
# Process 65 completed: 19832 files, 35 results, 0 errors
# 进度: 6.0% (66/1100), 已处理: 976,614, 发现变化: 1,865, 错误: 0
# Process 53 completed: 19941 files, 36 results, 0 errors
# Process 50 completed: 20013 files, 37 results, 0 errors
# 进度: 4.9% (54/1100), 已处理: 996,555, 发现变化: 1,901, 错误: 0
# 进度: 4.6% (51/1100), 已处理: 1,016,568, 发现变化: 1,938, 错误: 0
# Process 58 completed: 19775 files, 45 results, 0 errors
# 进度: 5.4% (59/1100), 已处理: 1,036,343, 发现变化: 1,983, 错误: 0
# Process 59 completed: 20045 files, 36 results, 0 errors
# 进度: 5.5% (60/1100), 已处理: 1,056,388, 发现变化: 2,019, 错误: 0
# Process 49 completed: 19927 files, 32 results, 0 errors
# 进度: 4.5% (50/1100), 已处理: 1,076,315, 发现变化: 2,051, 错误: 0
# Process 45 completed: 19860 files, 35 results, 0 errors
# 进度: 4.2% (46/1100), 已处理: 1,096,175, 发现变化: 2,086, 错误: 0
# Process 63 completed: 20000 files, 50 results, 0 errors
# 进度: 5.8% (64/1100), 已处理: 1,116,175, 发现变化: 2,136, 错误: 0
# Process 44 completed: 20071 files, 47 results, 0 errors
# 进度: 4.1% (45/1100), 已处理: 1,136,246, 发现变化: 2,183, 错误: 0
# Process 66 completed: 19959 files, 54 results, 0 errors
# 进度: 6.1% (67/1100), 已处理: 1,156,205, 发现变化: 2,237, 错误: 0
# Process 51 completed: 19857 files, 42 results, 0 errors
# 进度: 4.7% (52/1100), 已处理: 1,176,062, 发现变化: 2,279, 错误: 0
# Process 47 completed: 19832 files, 36 results, 0 errors
# Process 57 completed: 20015 files, 48 results, 0 errors
# 进度: 4.4% (48/1100), 已处理: 1,195,894, 发现变化: 2,315, 错误: 0
# 进度: 5.3% (58/1100), 已处理: 1,215,909, 发现变化: 2,363, 错误: 0
# Process 75 completed: 19895 files, 49 results, 0 errors
# Process 55 completed: 19952 files, 32 results, 0 errors
# 进度: 6.9% (76/1100), 已处理: 1,235,804, 发现变化: 2,412, 错误: 0
# 进度: 5.1% (56/1100), 已处理: 1,255,756, 发现变化: 2,444, 错误: 0
# Process 52 completed: 20037 files, 43 results, 0 errors
# 进度: 4.8% (53/1100), 已处理: 1,275,793, 发现变化: 2,487, 错误: 0
# Process 60 completed: 19934 files, 43 results, 0 errors
# 进度: 5.5% (61/1100), 已处理: 1,295,727, 发现变化: 2,530, 错误: 0
# Process 67 completed: 19955 files, 48 results, 0 errors
# 进度: 6.2% (68/1100), 已处理: 1,315,682, 发现变化: 2,578, 错误: 0
# Process 54 completed: 19830 files, 38 results, 0 errors
# 进度: 5.0% (55/1100), 已处理: 1,335,512, 发现变化: 2,616, 错误: 0
# Process 71 completed: 19844 files, 31 results, 0 errors
# 进度: 6.5% (72/1100), 已处理: 1,355,356, 发现变化: 2,647, 错误: 0
# Process 80 completed: 19893 files, 41 results, 0 errors
# 进度: 7.4% (81/1100), 已处理: 1,375,249, 发现变化: 2,688, 错误: 0
# Process 56 completed: 19930 files, 46 results, 0 errors
# 进度: 5.2% (57/1100), 已处理: 1,395,179, 发现变化: 2,734, 错误: 0
# Process 70 completed: 20051 files, 47 results, 0 errors
# 进度: 6.5% (71/1100), 已处理: 1,415,230, 发现变化: 2,781, 错误: 0
# Process 69 completed: 19875 files, 37 results, 0 errors
# 进度: 6.4% (70/1100), 已处理: 1,435,105, 发现变化: 2,818, 错误: 0
# Process 76 completed: 19897 files, 33 results, 0 errors
# 进度: 7.0% (77/1100), 已处理: 1,455,002, 发现变化: 2,851, 错误: 0
# Process 68 completed: 19906 files, 40 results, 0 errors
# 进度: 6.3% (69/1100), 已处理: 1,474,908, 发现变化: 2,891, 错误: 0
# Process 81 completed: 19907 files, 40 results, 0 errors
# 进度: 7.5% (82/1100), 已处理: 1,494,815, 发现变化: 2,931, 错误: 0
# Process 79 completed: 20034 files, 36 results, 0 errors
# 进度: 7.3% (80/1100), 已处理: 1,514,849, 发现变化: 2,967, 错误: 0
# Process 61 completed: 19949 files, 29 results, 0 errors
# 进度: 5.6% (62/1100), 已处理: 1,534,798, 发现变化: 2,996, 错误: 0
# Process 83 completed: 19919 files, 47 results, 0 errors
# 进度: 7.6% (84/1100), 已处理: 1,554,717, 发现变化: 3,043, 错误: 0
# Process 74 completed: 19936 files, 35 results, 0 errors
# 进度: 6.8% (75/1100), 已处理: 1,574,653, 发现变化: 3,078, 错误: 0
# Process 78 completed: 19885 files, 43 results, 0 errors
# 进度: 7.2% (79/1100), 已处理: 1,594,538, 发现变化: 3,121, 错误: 0
# Process 64 completed: 20071 files, 41 results, 0 errors
# 进度: 5.9% (65/1100), 已处理: 1,614,609, 发现变化: 3,162, 错误: 0
# Process 77 completed: 19951 files, 38 results, 0 errors
# 进度: 7.1% (78/1100), 已处理: 1,634,560, 发现变化: 3,200, 错误: 0
# Process 73 completed: 19931 files, 36 results, 0 errors
# 进度: 6.7% (74/1100), 已处理: 1,654,491, 发现变化: 3,236, 错误: 0
# Process 82 completed: 19937 files, 47 results, 0 errors
# 进度: 7.5% (83/1100), 已处理: 1,674,428, 发现变化: 3,283, 错误: 0
# Process 87 completed: 19849 files, 37 results, 0 errors
# Process 84 completed: 19954 files, 29 results, 0 errors
# 进度: 8.0% (88/1100), 已处理: 1,694,277, 发现变化: 3,320, 错误: 0
# 进度: 7.7% (85/1100), 已处理: 1,714,231, 发现变化: 3,349, 错误: 0
# Process 89 completed: 19899 files, 57 results, 0 errors
# 进度: 8.2% (90/1100), 已处理: 1,734,130, 发现变化: 3,406, 错误: 0
# Process 90 completed: 19964 files, 31 results, 0 errors
# 进度: 8.3% (91/1100), 已处理: 1,754,094, 发现变化: 3,437, 错误: 0
# Process 93 completed: 19966 files, 37 results, 0 errors
# 进度: 8.5% (94/1100), 已处理: 1,774,060, 发现变化: 3,474, 错误: 0
# Process 85 completed: 20001 files, 43 results, 0 errors
# 进度: 7.8% (86/1100), 已处理: 1,794,061, 发现变化: 3,517, 错误: 0
# Process 94 completed: 19917 files, 44 results, 0 errors
# 进度: 8.6% (95/1100), 已处理: 1,813,978, 发现变化: 3,561, 错误: 0
# Process 101 completed: 19839 files, 34 results, 0 errors
# 进度: 9.3% (102/1100), 已处理: 1,833,817, 发现变化: 3,595, 错误: 0
# Process 95 completed: 19821 files, 48 results, 0 errors
# 进度: 8.7% (96/1100), 已处理: 1,853,638, 发现变化: 3,643, 错误: 0
# Process 92 completed: 20011 files, 44 results, 0 errors
# 进度: 8.5% (93/1100), 已处理: 1,873,649, 发现变化: 3,687, 错误: 0
# Process 106 completed: 20073 files, 45 results, 0 errors
# 进度: 9.7% (107/1100), 已处理: 1,893,722, 发现变化: 3,732, 错误: 0
# Process 91 completed: 19929 files, 44 results, 0 errors
# 进度: 8.4% (92/1100), 已处理: 1,913,651, 发现变化: 3,776, 错误: 0
# Process 104 completed: 19894 files, 41 results, 0 errors
# 进度: 9.5% (105/1100), 已处理: 1,933,545, 发现变化: 3,817, 错误: 0
# Process 88 completed: 19938 files, 37 results, 0 errors
# 进度: 8.1% (89/1100), 已处理: 1,953,483, 发现变化: 3,854, 错误: 0
# Process 97 completed: 19856 files, 41 results, 0 errors
# 进度: 8.9% (98/1100), 已处理: 1,973,339, 发现变化: 3,895, 错误: 0
# Process 96 completed: 19947 files, 45 results, 0 errors
# 进度: 8.8% (97/1100), 已处理: 1,993,286, 发现变化: 3,940, 错误: 0
# Process 86 completed: 19986 files, 49 results, 0 errors
# 进度: 7.9% (87/1100), 已处理: 2,013,272, 发现变化: 3,989, 错误: 0
# Process 103 completed: 19934 files, 38 results, 0 errors
# 进度: 9.5% (104/1100), 已处理: 2,033,206, 发现变化: 4,027, 错误: 0
# Process 109 completed: 19965 files, 32 results, 0 errors
# 进度: 10.0% (110/1100), 已处理: 2,053,171, 发现变化: 4,059, 错误: 0
# Process 112 completed: 19832 files, 36 results, 0 errors
# Process 111 completed: 19866 files, 37 results, 0 errors
# Process 110 completed: 19988 files, 43 results, 0 errors
# Process 122 completed: 19838 files, 32 results, 0 errors进度: 10.3% (113/1100), 已处理: 2,073,003, 发现变化: 4,095, 错误: 0
# 进度: 10.2% (112/1100), 已处理: 2,092,869, 发现变化: 4,132, 错误: 0
# 进度: 10.1% (111/1100), 已处理: 2,112,857, 发现变化: 4,175, 错误: 0
# 进度: 11.2% (123/1100), 已处理: 2,132,695, 发现变化: 4,207, 错误: 0
#
# Process 98 completed: 20009 files, 62 results, 0 errors
# 进度: 9.0% (99/1100), 已处理: 2,152,704, 发现变化: 4,269, 错误: 0
# Process 102 completed: 19936 files, 38 results, 0 errors
# 进度: 9.4% (103/1100), 已处理: 2,172,640, 发现变化: 4,307, 错误: 0
# Process 116 completed: 20000 files, 43 results, 0 errors
# 进度: 10.6% (117/1100), 已处理: 2,192,640, 发现变化: 4,350, 错误: 0
# Process 100 completed: 20059 files, 47 results, 0 errors
# 进度: 9.2% (101/1100), 已处理: 2,212,699, 发现变化: 4,397, 错误: 0
# Process 114 completed: 19913 files, 33 results, 0 errors
# 进度: 10.5% (115/1100), 已处理: 2,232,612, 发现变化: 4,430, 错误: 0
# Process 119 completed: 20016 files, 40 results, 0 errors
# 进度: 10.9% (120/1100), 已处理: 2,252,628, 发现变化: 4,470, 错误: 0
# Process 121 completed: 19933 files, 44 results, 0 errors
# 进度: 11.1% (122/1100), 已处理: 2,272,561, 发现变化: 4,514, 错误: 0
# Process 108 completed: 19842 files, 37 results, 0 errors
# 进度: 9.9% (109/1100), 已处理: 2,292,403, 发现变化: 4,551, 错误: 0
# Process 105 completed: 19968 files, 41 results, 0 errors
# Process 113 completed: 19908 files, 41 results, 0 errors
# 进度: 9.6% (106/1100), 已处理: 2,312,371, 发现变化: 4,592, 错误: 0
# 进度: 10.4% (114/1100), 已处理: 2,332,279, 发现变化: 4,633, 错误: 0
# Process 118 completed: 19941 files, 58 results, 0 errors
# 进度: 10.8% (119/1100), 已处理: 2,352,220, 发现变化: 4,691, 错误: 0
# Process 99 completed: 19996 files, 34 results, 0 errors
# Process 120 completed: 19897 files, 46 results, 0 errors
# 进度: 9.1% (100/1100), 已处理: 2,372,216, 发现变化: 4,725, 错误: 0
# 进度: 11.0% (121/1100), 已处理: 2,392,113, 发现变化: 4,771, 错误: 0
# Process 117 completed: 20010 files, 33 results, 0 errors
# 进度: 10.7% (118/1100), 已处理: 2,412,123, 发现变化: 4,804, 错误: 0
# Process 124 completed: 19982 files, 33 results, 0 errors
# 进度: 11.4% (125/1100), 已处理: 2,432,105, 发现变化: 4,837, 错误: 0
# Process 123 completed: 20101 files, 38 results, 0 errors
# 进度: 11.3% (124/1100), 已处理: 2,452,206, 发现变化: 4,875, 错误: 0
# Process 125 completed: 20015 files, 37 results, 0 errors
# 进度: 11.5% (126/1100), 已处理: 2,472,221, 发现变化: 4,912, 错误: 0
# Process 107 completed: 19931 files, 34 results, 0 errors
# 进度: 9.8% (108/1100), 已处理: 2,492,152, 发现变化: 4,946, 错误: 0
# Process 115 completed: 20010 files, 34 results, 0 errors
# 进度: 10.5% (116/1100), 已处理: 2,512,162, 发现变化: 4,980, 错误: 0
# Process 127 completed: 19830 files, 38 results, 0 errors
# 进度: 11.6% (128/1100), 已处理: 2,531,992, 发现变化: 5,018, 错误: 0
# Process 126 completed: 19920 files, 30 results, 0 errors
# 进度: 11.5% (127/1100), 已处理: 2,551,912, 发现变化: 5,048, 错误: 0
# Process 129 completed: 19992 files, 47 results, 0 errors
# 进度: 11.8% (130/1100), 已处理: 2,571,904, 发现变化: 5,095, 错误: 0
# Process 131 completed: 19674 files, 36 results, 0 errors
# 进度: 12.0% (132/1100), 已处理: 2,591,578, 发现变化: 5,131, 错误: 0
# Process 137 completed: 20034 files, 32 results, 0 errors
# 进度: 12.5% (138/1100), 已处理: 2,611,612, 发现变化: 5,163, 错误: 0
# Process 128 completed: 19867 files, 29 results, 0 errors
# 进度: 11.7% (129/1100), 已处理: 2,631,479, 发现变化: 5,192, 错误: 0
# Process 130 completed: 20076 files, 38 results, 0 errors
# 进度: 11.9% (131/1100), 已处理: 2,651,555, 发现变化: 5,230, 错误: 0
# Process 143 completed: 19998 files, 37 results, 0 errors
# 进度: 13.1% (144/1100), 已处理: 2,671,553, 发现变化: 5,267, 错误: 0
# Process 148 completed: 20039 files, 43 results, 0 errors
# 进度: 13.5% (149/1100), 已处理: 2,691,592, 发现变化: 5,310, 错误: 0
# Process 132 completed: 19944 files, 44 results, 0 errors
# 进度: 12.1% (133/1100), 已处理: 2,711,536, 发现变化: 5,354, 错误: 0
# Process 142 completed: 19955 files, 45 results, 0 errors
# 进度: 13.0% (143/1100), 已处理: 2,731,491, 发现变化: 5,399, 错误: 0
# Process 135 completed: 20066 files, 46 results, 0 errors
# 进度: 12.4% (136/1100), 已处理: 2,751,557, 发现变化: 5,445, 错误: 0
# Process 141 completed: 19980 files, 42 results, 0 errors
# 进度: 12.9% (142/1100), 已处理: 2,771,537, 发现变化: 5,487, 错误: 0
# Process 153 completed: 19933 files, 46 results, 0 errors
# 进度: 14.0% (154/1100), 已处理: 2,791,470, 发现变化: 5,533, 错误: 0
# Process 134 completed: 19904 files, 30 results, 0 errors
# Process 159 completed: 19980 files, 46 results, 0 errors
# 进度: 12.3% (135/1100), 已处理: 2,811,374, 发现变化: 5,563, 错误: 0
# 进度: 14.5% (160/1100), 已处理: 2,831,354, 发现变化: 5,609, 错误: 0
# Process 139 completed: 19932 files, 40 results, 0 errors
# Process 152 completed: 19955 files, 37 results, 0 errors
# 进度: 12.7% (140/1100), 已处理: 2,851,286, 发现变化: 5,649, 错误: 0
# 进度: 13.9% (153/1100), 已处理: 2,871,241, 发现变化: 5,686, 错误: 0
# Process 140 completed: 20010 files, 42 results, 0 errors
# 进度: 12.8% (141/1100), 已处理: 2,891,251, 发现变化: 5,728, 错误: 0
# Process 138 completed: 20077 files, 46 results, 0 errors
# 进度: 12.6% (139/1100), 已处理: 2,911,328, 发现变化: 5,774, 错误: 0
# Process 150 completed: 19834 files, 41 results, 0 errors
# 进度: 13.7% (151/1100), 已处理: 2,931,162, 发现变化: 5,815, 错误: 0
# Process 147 completed: 20005 files, 46 results, 0 errors
# 进度: 13.5% (148/1100), 已处理: 2,951,167, 发现变化: 5,861, 错误: 0
# Process 154 completed: 19981 files, 29 results, 0 errors
# 进度: 14.1% (155/1100), 已处理: 2,971,148, 发现变化: 5,890, 错误: 0
# Process 149 completed: 19834 files, 44 results, 0 errors
# 进度: 13.6% (150/1100), 已处理: 2,990,982, 发现变化: 5,934, 错误: 0
# Process 162 completed: 19865 files, 37 results, 0 errors
# 进度: 14.8% (163/1100), 已处理: 3,010,847, 发现变化: 5,971, 错误: 0
# Process 157 completed: 19760 files, 29 results, 0 errors
# 进度: 14.4% (158/1100), 已处理: 3,030,607, 发现变化: 6,000, 错误: 0
# Process 144 completed: 20087 files, 31 results, 0 errors
# Process 146 completed: 19794 files, 37 results, 0 errors
# 进度: 13.2% (145/1100), 已处理: 3,050,694, 发现变化: 6,031, 错误: 0
# 进度: 13.4% (147/1100), 已处理: 3,070,488, 发现变化: 6,068, 错误: 0
# Process 151 completed: 19961 files, 40 results, 0 errors
# 进度: 13.8% (152/1100), 已处理: 3,090,449, 发现变化: 6,108, 错误: 0
# Process 155 completed: 19905 files, 39 results, 0 errors
# 进度: 14.2% (156/1100), 已处理: 3,110,354, 发现变化: 6,147, 错误: 0
# Process 158 completed: 19944 files, 37 results, 0 errors
# 进度: 14.5% (159/1100), 已处理: 3,130,298, 发现变化: 6,184, 错误: 0
# Process 156 completed: 19919 files, 47 results, 0 errors
# 进度: 14.3% (157/1100), 已处理: 3,150,217, 发现变化: 6,231, 错误: 0
# Process 133 completed: 19856 files, 30 results, 0 errors
# 进度: 12.2% (134/1100), 已处理: 3,170,073, 发现变化: 6,261, 错误: 0
# Process 161 completed: 19901 files, 36 results, 0 errors
# 进度: 14.7% (162/1100), 已处理: 3,189,974, 发现变化: 6,297, 错误: 0
# Process 136 completed: 19839 files, 45 results, 0 errors
# 进度: 12.5% (137/1100), 已处理: 3,209,813, 发现变化: 6,342, 错误: 0
# Process 145 completed: 19999 files, 35 results, 0 errors
# 进度: 13.3% (146/1100), 已处理: 3,229,812, 发现变化: 6,377, 错误: 0
# Process 165 completed: 20071 files, 37 results, 0 errors
# 进度: 15.1% (166/1100), 已处理: 3,249,883, 发现变化: 6,414, 错误: 0
# Process 163 completed: 19901 files, 45 results, 0 errors
# 进度: 14.9% (164/1100), 已处理: 3,269,784, 发现变化: 6,459, 错误: 0
# Process 160 completed: 19995 files, 35 results, 0 errors
# 进度: 14.6% (161/1100), 已处理: 3,289,779, 发现变化: 6,494, 错误: 0
# Process 166 completed: 19931 files, 31 results, 0 errors
# 进度: 15.2% (167/1100), 已处理: 3,309,710, 发现变化: 6,525, 错误: 0
# Process 167 completed: 20124 files, 31 results, 0 errors
# 进度: 15.3% (168/1100), 已处理: 3,329,834, 发现变化: 6,556, 错误: 0
# Process 164 completed: 19873 files, 47 results, 0 errors
# 进度: 15.0% (165/1100), 已处理: 3,349,707, 发现变化: 6,603, 错误: 0
# Process 168 completed: 19869 files, 42 results, 0 errors
# 进度: 15.4% (169/1100), 已处理: 3,369,576, 发现变化: 6,645, 错误: 0
# Process 171 completed: 19871 files, 37 results, 0 errors
# 进度: 15.6% (172/1100), 已处理: 3,389,447, 发现变化: 6,682, 错误: 0
# Process 169 completed: 19795 files, 38 results, 0 errors
# 进度: 15.5% (170/1100), 已处理: 3,409,242, 发现变化: 6,720, 错误: 0
# Process 170 completed: 19828 files, 43 results, 0 errors
# 进度: 15.5% (171/1100), 已处理: 3,429,070, 发现变化: 6,763, 错误: 0
# Process 172 completed: 19952 files, 46 results, 0 errors
# 进度: 15.7% (173/1100), 已处理: 3,449,022, 发现变化: 6,809, 错误: 0
# Process 173 completed: 20011 files, 43 results, 0 errors
# 进度: 15.8% (174/1100), 已处理: 3,469,033, 发现变化: 6,852, 错误: 0
# Process 174 completed: 20065 files, 40 results, 0 errors
# 进度: 15.9% (175/1100), 已处理: 3,489,098, 发现变化: 6,892, 错误: 0
# Process 180 completed: 19940 files, 47 results, 0 errors
# 进度: 16.5% (181/1100), 已处理: 3,509,038, 发现变化: 6,939, 错误: 0
# Process 178 completed: 19810 files, 51 results, 0 errors
# 进度: 16.3% (179/1100), 已处理: 3,528,848, 发现变化: 6,990, 错误: 0
# Process 179 completed: 20109 files, 48 results, 0 errors
# 进度: 16.4% (180/1100), 已处理: 3,548,957, 发现变化: 7,038, 错误: 0
# Process 175 completed: 19871 files, 42 results, 0 errors
# 进度: 16.0% (176/1100), 已处理: 3,568,828, 发现变化: 7,080, 错误: 0
# Process 190 completed: 20027 files, 41 results, 0 errors
# Process 177 completed: 19979 files, 44 results, 0 errors
# 进度: 17.4% (191/1100), 已处理: 3,588,855, 发现变化: 7,121, 错误: 0
# 进度: 16.2% (178/1100), 已处理: 3,608,834, 发现变化: 7,165, 错误: 0
# Process 196 completed: 19851 files, 56 results, 0 errors
# 进度: 17.9% (197/1100), 已处理: 3,628,685, 发现变化: 7,221, 错误: 0
# Process 197 completed: 19881 files, 38 results, 0 errors
# 进度: 18.0% (198/1100), 已处理: 3,648,566, 发现变化: 7,259, 错误: 0
# Process 187 completed: 19865 files, 49 results, 0 errors
# Process 184 completed: 19919 files, 38 results, 0 errors
# 进度: 17.1% (188/1100), 已处理: 3,668,431, 发现变化: 7,308, 错误: 0
# 进度: 16.8% (185/1100), 已处理: 3,688,350, 发现变化: 7,346, 错误: 0
# Process 188 completed: 19981 files, 44 results, 0 errors
# 进度: 17.2% (189/1100), 已处理: 3,708,331, 发现变化: 7,390, 错误: 0
# Process 181 completed: 19841 files, 44 results, 0 errors
# 进度: 16.5% (182/1100), 已处理: 3,728,172, 发现变化: 7,434, 错误: 0
# Process 191 completed: 19939 files, 40 results, 0 errors
# 进度: 17.5% (192/1100), 已处理: 3,748,111, 发现变化: 7,474, 错误: 0
# Process 185 completed: 19961 files, 37 results, 0 errors
# 进度: 16.9% (186/1100), 已处理: 3,768,072, 发现变化: 7,511, 错误: 0
# Process 176 completed: 19835 files, 31 results, 0 errors
# 进度: 16.1% (177/1100), 已处理: 3,787,907, 发现变化: 7,542, 错误: 0
# Process 186 completed: 20042 files, 34 results, 0 errors
# 进度: 17.0% (187/1100), 已处理: 3,807,949, 发现变化: 7,576, 错误: 0
# Process 201 completed: 19961 files, 55 results, 0 errors
# 进度: 18.4% (202/1100), 已处理: 3,827,910, 发现变化: 7,631, 错误: 0
# Process 182 completed: 19856 files, 43 results, 0 errors
# 进度: 16.6% (183/1100), 已处理: 3,847,766, 发现变化: 7,674, 错误: 0
# Process 200 completed: 19946 files, 36 results, 0 errors
# 进度: 18.3% (201/1100), 已处理: 3,867,712, 发现变化: 7,710, 错误: 0
# Process 194 completed: 19828 files, 45 results, 0 errors
# 进度: 17.7% (195/1100), 已处理: 3,887,540, 发现变化: 7,755, 错误: 0
# Process 183 completed: 19864 files, 27 results, 0 errors
# 进度: 16.7% (184/1100), 已处理: 3,907,404, 发现变化: 7,782, 错误: 0
# Process 195 completed: 19953 files, 44 results, 0 errors
# Process 189 completed: 19840 files, 44 results, 0 errors
# 进度: 17.8% (196/1100), 已处理: 3,927,357, 发现变化: 7,826, 错误: 0
# 进度: 17.3% (190/1100), 已处理: 3,947,197, 发现变化: 7,870, 错误: 0
# Process 203 completed: 19915 files, 25 results, 0 errors
# Process 204 completed: 19879 files, 46 results, 0 errors
# 进度: 18.5% (204/1100), 已处理: 3,967,112, 发现变化: 7,895, 错误: 0
# 进度: 18.6% (205/1100), 已处理: 3,986,991, 发现变化: 7,941, 错误: 0
# Process 198 completed: 19810 files, 38 results, 0 errors
# 进度: 18.1% (199/1100), 已处理: 4,006,801, 发现变化: 7,979, 错误: 0
# Process 206 completed: 19840 files, 33 results, 0 errors
# 进度: 18.8% (207/1100), 已处理: 4,026,641, 发现变化: 8,012, 错误: 0
# Process 202 completed: 19939 files, 39 results, 0 errors
# 进度: 18.5% (203/1100), 已处理: 4,046,580, 发现变化: 8,051, 错误: 0
# Process 199 completed: 20036 files, 41 results, 0 errors
# 进度: 18.2% (200/1100), 已处理: 4,066,616, 发现变化: 8,092, 错误: 0
# Process 205 completed: 19791 files, 48 results, 0 errors
# 进度: 18.7% (206/1100), 已处理: 4,086,407, 发现变化: 8,140, 错误: 0
# Process 193 completed: 19986 files, 43 results, 0 errors
# 进度: 17.6% (194/1100), 已处理: 4,106,393, 发现变化: 8,183, 错误: 0
# Process 192 completed: 19955 files, 34 results, 0 errors
# 进度: 17.5% (193/1100), 已处理: 4,126,348, 发现变化: 8,217, 错误: 0
# Process 207 completed: 19989 files, 39 results, 0 errors
# 进度: 18.9% (208/1100), 已处理: 4,146,337, 发现变化: 8,256, 错误: 0
# Process 209 completed: 20018 files, 43 results, 0 errors
# 进度: 19.1% (210/1100), 已处理: 4,166,355, 发现变化: 8,299, 错误: 0
# Process 208 completed: 20097 files, 33 results, 0 errors
# 进度: 19.0% (209/1100), 已处理: 4,186,452, 发现变化: 8,332, 错误: 0
# Process 210 completed: 19980 files, 39 results, 0 errors
# 进度: 19.2% (211/1100), 已处理: 4,206,432, 发现变化: 8,371, 错误: 0
# Process 212 completed: 19929 files, 39 results, 0 errors
# 进度: 19.4% (213/1100), 已处理: 4,226,361, 发现变化: 8,410, 错误: 0
# Process 213 completed: 19905 files, 42 results, 0 errors
# 进度: 19.5% (214/1100), 已处理: 4,246,266, 发现变化: 8,452, 错误: 0
# Process 215 completed: 19911 files, 33 results, 0 errors
# 进度: 19.6% (216/1100), 已处理: 4,266,177, 发现变化: 8,485, 错误: 0
# Process 211 completed: 19930 files, 34 results, 0 errors
# 进度: 19.3% (212/1100), 已处理: 4,286,107, 发现变化: 8,519, 错误: 0
# Process 216 completed: 19979 files, 36 results, 0 errors
# 进度: 19.7% (217/1100), 已处理: 4,306,086, 发现变化: 8,555, 错误: 0
# Process 214 completed: 19905 files, 35 results, 0 errors
# 进度: 19.5% (215/1100), 已处理: 4,325,991, 发现变化: 8,590, 错误: 0
# Process 221 completed: 20099 files, 34 results, 0 errors
# 进度: 20.2% (222/1100), 已处理: 4,346,090, 发现变化: 8,624, 错误: 0
# Process 217 completed: 19819 files, 34 results, 0 errors
# 进度: 19.8% (218/1100), 已处理: 4,365,909, 发现变化: 8,658, 错误: 0
# Process 219 completed: 19872 files, 47 results, 0 errors
# 进度: 20.0% (220/1100), 已处理: 4,385,781, 发现变化: 8,705, 错误: 0
# Process 224 completed: 19991 files, 46 results, 0 errors
# 进度: 20.5% (225/1100), 已处理: 4,405,772, 发现变化: 8,751, 错误: 0
# Process 220 completed: 19939 files, 44 results, 0 errors
# Process 225 completed: 19994 files, 54 results, 0 errors
# 进度: 20.1% (221/1100), 已处理: 4,425,711, 发现变化: 8,795, 错误: 0
# 进度: 20.5% (226/1100), 已处理: 4,445,705, 发现变化: 8,849, 错误: 0
# Process 223 completed: 19900 files, 37 results, 0 errors
# 进度: 20.4% (224/1100), 已处理: 4,465,605, 发现变化: 8,886, 错误: 0
# Process 230 completed: 19962 files, 33 results, 0 errors
# 进度: 21.0% (231/1100), 已处理: 4,485,567, 发现变化: 8,919, 错误: 0
# Process 222 completed: 19997 files, 42 results, 0 errors
# 进度: 20.3% (223/1100), 已处理: 4,505,564, 发现变化: 8,961, 错误: 0
# Process 234 completed: 19776 files, 36 results, 0 errors
# 进度: 21.4% (235/1100), 已处理: 4,525,340, 发现变化: 8,997, 错误: 0
# Process 237 completed: 19761 files, 50 results, 0 errors
# 进度: 21.6% (238/1100), 已处理: 4,545,101, 发现变化: 9,047, 错误: 0
# Process 226 completed: 19935 files, 34 results, 0 errors
# 进度: 20.6% (227/1100), 已处理: 4,565,036, 发现变化: 9,081, 错误: 0
# Process 241 completed: 19980 files, 53 results, 0 errors
# 进度: 22.0% (242/1100), 已处理: 4,585,016, 发现变化: 9,134, 错误: 0
# Process 228 completed: 19941 files, 42 results, 0 errors
# Process 232 completed: 19881 files, 47 results, 0 errors
# 进度: 20.8% (229/1100), 已处理: 4,604,957, 发现变化: 9,176, 错误: 0
# 进度: 21.2% (233/1100), 已处理: 4,624,838, 发现变化: 9,223, 错误: 0
# Process 239 completed: 19933 files, 38 results, 0 errors
# 进度: 21.8% (240/1100), 已处理: 4,644,771, 发现变化: 9,261, 错误: 0
# Process 227 completed: 19969 files, 45 results, 0 errors
# 进度: 20.7% (228/1100), 已处理: 4,664,740, 发现变化: 9,306, 错误: 0
# Process 229 completed: 19933 files, 38 results, 0 errors
# Process 233 completed: 19852 files, 46 results, 0 errors
# 进度: 20.9% (230/1100), 已处理: 4,684,673, 发现变化: 9,344, 错误: 0
# 进度: 21.3% (234/1100), 已处理: 4,704,525, 发现变化: 9,390, 错误: 0
# Process 231 completed: 20000 files, 47 results, 0 errors
# Process 238 completed: 19892 files, 48 results, 0 errors
# Process 244 completed: 20004 files, 36 results, 0 errors
# 进度: 21.1% (232/1100), 已处理: 4,724,525, 发现变化: 9,437, 错误: 0
# 进度: 21.7% (239/1100), 已处理: 4,744,417, 发现变化: 9,485, 错误: 0
# 进度: 22.3% (245/1100), 已处理: 4,764,421, 发现变化: 9,521, 错误: 0
# Process 236 completed: 19842 files, 53 results, 0 errors
# 进度: 21.5% (237/1100), 已处理: 4,784,263, 发现变化: 9,574, 错误: 0
# Process 218 completed: 19997 files, 42 results, 0 errors
# 进度: 19.9% (219/1100), 已处理: 4,804,260, 发现变化: 9,616, 错误: 0
# Process 246 completed: 19872 files, 47 results, 0 errors
# 进度: 22.5% (247/1100), 已处理: 4,824,132, 发现变化: 9,663, 错误: 0
# Process 240 completed: 19970 files, 40 results, 0 errors
# 进度: 21.9% (241/1100), 已处理: 4,844,102, 发现变化: 9,703, 错误: 0
# Process 247 completed: 19922 files, 37 results, 0 errors
# 进度: 22.5% (248/1100), 已处理: 4,864,024, 发现变化: 9,740, 错误: 0
# Process 235 completed: 19897 files, 27 results, 0 errors
# 进度: 21.5% (236/1100), 已处理: 4,883,921, 发现变化: 9,767, 错误: 0
# Process 243 completed: 20048 files, 47 results, 0 errors
# 进度: 22.2% (244/1100), 已处理: 4,903,969, 发现变化: 9,814, 错误: 0
# Process 248 completed: 19889 files, 41 results, 0 errors
# 进度: 22.6% (249/1100), 已处理: 4,923,858, 发现变化: 9,855, 错误: 0
# Process 245 completed: 19838 files, 33 results, 0 errors
# 进度: 22.4% (246/1100), 已处理: 4,943,696, 发现变化: 9,888, 错误: 0
# Process 242 completed: 19935 files, 41 results, 0 errors
# 进度: 22.1% (243/1100), 已处理: 4,963,631, 发现变化: 9,929, 错误: 0
# Process 249 completed: 20052 files, 49 results, 0 errors
# 进度: 22.7% (250/1100), 已处理: 4,983,683, 发现变化: 9,978, 错误: 0
# Process 250 completed: 19858 files, 35 results, 0 errors
# 进度: 22.8% (251/1100), 已处理: 5,003,541, 发现变化: 10,013, 错误: 0
# Process 251 completed: 19904 files, 40 results, 0 errors
# 进度: 22.9% (252/1100), 已处理: 5,023,445, 发现变化: 10,053, 错误: 0
# Process 252 completed: 19951 files, 36 results, 0 errors
# 进度: 23.0% (253/1100), 已处理: 5,043,396, 发现变化: 10,089, 错误: 0
# Process 253 completed: 19936 files, 52 results, 0 errors
# 进度: 23.1% (254/1100), 已处理: 5,063,332, 发现变化: 10,141, 错误: 0
# Process 254 completed: 19963 files, 37 results, 0 errors
# 进度: 23.2% (255/1100), 已处理: 5,083,295, 发现变化: 10,178, 错误: 0
# Process 255 completed: 19882 files, 34 results, 0 errors
# 进度: 23.3% (256/1100), 已处理: 5,103,177, 发现变化: 10,212, 错误: 0
# Process 258 completed: 19991 files, 35 results, 0 errors
# 进度: 23.5% (259/1100), 已处理: 5,123,168, 发现变化: 10,247, 错误: 0
# Process 261 completed: 19912 files, 42 results, 0 errors
# 进度: 23.8% (262/1100), 已处理: 5,143,080, 发现变化: 10,289, 错误: 0
# Process 256 completed: 19988 files, 44 results, 0 errors
# 进度: 23.4% (257/1100), 已处理: 5,163,068, 发现变化: 10,333, 错误: 0
# Process 260 completed: 19890 files, 41 results, 0 errors
# 进度: 23.7% (261/1100), 已处理: 5,182,958, 发现变化: 10,374, 错误: 0
# Process 259 completed: 19959 files, 40 results, 0 errors
# 进度: 23.6% (260/1100), 已处理: 5,202,917, 发现变化: 10,414, 错误: 0
# Process 262 completed: 19740 files, 37 results, 0 errors
# 进度: 23.9% (263/1100), 已处理: 5,222,657, 发现变化: 10,451, 错误: 0
# Process 257 completed: 20056 files, 50 results, 0 errors
# Process 270 completed: 19873 files, 52 results, 0 errors
# 进度: 23.5% (258/1100), 已处理: 5,242,713, 发现变化: 10,501, 错误: 0
# 进度: 24.6% (271/1100), 已处理: 5,262,586, 发现变化: 10,553, 错误: 0
# Process 266 completed: 19896 files, 38 results, 0 errors
# 进度: 24.3% (267/1100), 已处理: 5,282,482, 发现变化: 10,591, 错误: 0
# Process 276 completed: 19986 files, 35 results, 0 errors
# 进度: 25.2% (277/1100), 已处理: 5,302,468, 发现变化: 10,626, 错误: 0
# Process 267 completed: 19900 files, 34 results, 0 errors
# 进度: 24.4% (268/1100), 已处理: 5,322,368, 发现变化: 10,660, 错误: 0
# Process 263 completed: 19939 files, 42 results, 0 errors
# 进度: 24.0% (264/1100), 已处理: 5,342,307, 发现变化: 10,702, 错误: 0
# Process 268 completed: 19905 files, 50 results, 0 errors
# 进度: 24.5% (269/1100), 已处理: 5,362,212, 发现变化: 10,752, 错误: 0
# Process 269 completed: 19934 files, 45 results, 0 errors
# 进度: 24.5% (270/1100), 已处理: 5,382,146, 发现变化: 10,797, 错误: 0
# Process 264 completed: 20059 files, 36 results, 0 errors
# 进度: 24.1% (265/1100), 已处理: 5,402,205, 发现变化: 10,833, 错误: 0
# Process 271 completed: 19936 files, 41 results, 0 errors
# 进度: 24.7% (272/1100), 已处理: 5,422,141, 发现变化: 10,874, 错误: 0
# Process 265 completed: 20078 files, 47 results, 0 errors
# 进度: 24.2% (266/1100), 已处理: 5,442,219, 发现变化: 10,921, 错误: 0
# Process 282 completed: 19987 files, 30 results, 0 errors
# 进度: 25.7% (283/1100), 已处理: 5,462,206, 发现变化: 10,951, 错误: 0
# Process 275 completed: 19898 files, 39 results, 0 errors
# Process 280 completed: 20049 files, 41 results, 0 errors
# 进度: 25.1% (276/1100), 已处理: 5,482,104, 发现变化: 10,990, 错误: 0
# 进度: 25.5% (281/1100), 已处理: 5,502,153, 发现变化: 11,031, 错误: 0
# Process 273 completed: 19848 files, 34 results, 0 errors
# 进度: 24.9% (274/1100), 已处理: 5,522,001, 发现变化: 11,065, 错误: 0
# Process 277 completed: 19891 files, 34 results, 0 errors
# 进度: 25.3% (278/1100), 已处理: 5,541,892, 发现变化: 11,099, 错误: 0
# Process 288 completed: 19762 files, 31 results, 0 errors
# 进度: 26.3% (289/1100), 已处理: 5,561,654, 发现变化: 11,130, 错误: 0
# Process 286 completed: 19930 files, 31 results, 0 errors
# 进度: 26.1% (287/1100), 已处理: 5,581,584, 发现变化: 11,161, 错误: 0
# Process 287 completed: 19853 files, 36 results, 0 errors
# 进度: 26.2% (288/1100), 已处理: 5,601,437, 发现变化: 11,197, 错误: 0
# Process 274 completed: 19948 files, 42 results, 0 errors
# 进度: 25.0% (275/1100), 已处理: 5,621,385, 发现变化: 11,239, 错误: 0
# Process 279 completed: 20023 files, 36 results, 0 errors
# 进度: 25.5% (280/1100), 已处理: 5,641,408, 发现变化: 11,275, 错误: 0
# Process 272 completed: 19904 files, 34 results, 0 errors
# 进度: 24.8% (273/1100), 已处理: 5,661,312, 发现变化: 11,309, 错误: 0
# Process 285 completed: 20159 files, 28 results, 0 errors
# 进度: 26.0% (286/1100), 已处理: 5,681,471, 发现变化: 11,337, 错误: 0
# Process 281 completed: 19938 files, 45 results, 0 errors
# Process 278 completed: 20025 files, 46 results, 0 errors
# 进度: 25.6% (282/1100), 已处理: 5,701,409, 发现变化: 11,382, 错误: 0
# 进度: 25.4% (279/1100), 已处理: 5,721,434, 发现变化: 11,428, 错误: 0
# Process 291 completed: 19968 files, 42 results, 0 errors
# 进度: 26.5% (292/1100), 已处理: 5,741,402, 发现变化: 11,470, 错误: 0
# Process 289 completed: 19944 files, 35 results, 0 errors
# 进度: 26.4% (290/1100), 已处理: 5,761,346, 发现变化: 11,505, 错误: 0
# Process 284 completed: 19951 files, 40 results, 0 errors
# 进度: 25.9% (285/1100), 已处理: 5,781,297, 发现变化: 11,545, 错误: 0
# Process 283 completed: 19997 files, 52 results, 0 errors
# 进度: 25.8% (284/1100), 已处理: 5,801,294, 发现变化: 11,597, 错误: 0
# Process 293 completed: 20058 files, 47 results, 0 errors
# Process 292 completed: 19884 files, 44 results, 0 errors
# 进度: 26.7% (294/1100), 已处理: 5,821,352, 发现变化: 11,644, 错误: 0
# 进度: 26.6% (293/1100), 已处理: 5,841,236, 发现变化: 11,688, 错误: 0
# Process 290 completed: 19983 files, 41 results, 0 errors
# 进度: 26.5% (291/1100), 已处理: 5,861,219, 发现变化: 11,729, 错误: 0
# Process 294 completed: 19856 files, 46 results, 0 errors
# 进度: 26.8% (295/1100), 已处理: 5,881,075, 发现变化: 11,775, 错误: 0
# Process 295 completed: 19932 files, 50 results, 0 errors
# 进度: 26.9% (296/1100), 已处理: 5,901,007, 发现变化: 11,825, 错误: 0
# Process 297 completed: 19964 files, 49 results, 0 errors
# 进度: 27.1% (298/1100), 已处理: 5,920,971, 发现变化: 11,874, 错误: 0
# Process 296 completed: 19910 files, 39 results, 0 errors
# 进度: 27.0% (297/1100), 已处理: 5,940,881, 发现变化: 11,913, 错误: 0
# Process 298 completed: 19908 files, 37 results, 0 errors
# 进度: 27.2% (299/1100), 已处理: 5,960,789, 发现变化: 11,950, 错误: 0
# Process 302 completed: 19881 files, 43 results, 0 errors
# Process 305 completed: 20008 files, 36 results, 0 errors
# 进度: 27.5% (303/1100), 已处理: 5,980,670, 发现变化: 11,993, 错误: 0
# 进度: 27.8% (306/1100), 已处理: 6,000,678, 发现变化: 12,029, 错误: 0
# Process 304 completed: 19999 files, 46 results, 0 errors
# 进度: 27.7% (305/1100), 已处理: 6,020,677, 发现变化: 12,075, 错误: 0
# Process 301 completed: 20050 files, 37 results, 0 errors
# Process 307 completed: 19958 files, 39 results, 0 errors
# 进度: 27.5% (302/1100), 已处理: 6,040,727, 发现变化: 12,112, 错误: 0
# 进度: 28.0% (308/1100), 已处理: 6,060,685, 发现变化: 12,151, 错误: 0
# Process 311 completed: 19978 files, 35 results, 0 errors
# 进度: 28.4% (312/1100), 已处理: 6,080,663, 发现变化: 12,186, 错误: 0
# Process 315 completed: 20126 files, 42 results, 0 errors
# 进度: 28.7% (316/1100), 已处理: 6,100,789, 发现变化: 12,228, 错误: 0
# Process 313 completed: 19954 files, 33 results, 0 errors
# 进度: 28.5% (314/1100), 已处理: 6,120,743, 发现变化: 12,261, 错误: 0
# Process 308 completed: 19949 files, 45 results, 0 errors
# 进度: 28.1% (309/1100), 已处理: 6,140,692, 发现变化: 12,306, 错误: 0
# Process 316 completed: 20021 files, 43 results, 0 errors
# 进度: 28.8% (317/1100), 已处理: 6,160,713, 发现变化: 12,349, 错误: 0
# Process 306 completed: 19912 files, 35 results, 0 errors
# 进度: 27.9% (307/1100), 已处理: 6,180,625, 发现变化: 12,384, 错误: 0
# Process 300 completed: 19977 files, 36 results, 0 errors
# 进度: 27.4% (301/1100), 已处理: 6,200,602, 发现变化: 12,420, 错误: 0
# Process 319 completed: 19971 files, 45 results, 0 errors
# 进度: 29.1% (320/1100), 已处理: 6,220,573, 发现变化: 12,465, 错误: 0
# Process 303 completed: 19990 files, 38 results, 0 errors
# 进度: 27.6% (304/1100), 已处理: 6,240,563, 发现变化: 12,503, 错误: 0
# Process 321 completed: 19866 files, 34 results, 0 errors
# Process 310 completed: 19957 files, 35 results, 0 errors
# 进度: 29.3% (322/1100), 已处理: 6,260,429, 发现变化: 12,537, 错误: 0
# 进度: 28.3% (311/1100), 已处理: 6,280,386, 发现变化: 12,572, 错误: 0
# Process 309 completed: 19897 files, 35 results, 0 errors
# 进度: 28.2% (310/1100), 已处理: 6,300,283, 发现变化: 12,607, 错误: 0
# Process 299 completed: 20107 files, 36 results, 0 errors
# 进度: 27.3% (300/1100), 已处理: 6,320,390, 发现变化: 12,643, 错误: 0
# Process 318 completed: 20040 files, 40 results, 0 errors
# 进度: 29.0% (319/1100), 已处理: 6,340,430, 发现变化: 12,683, 错误: 0
# Process 312 completed: 19827 files, 42 results, 0 errors
# 进度: 28.5% (313/1100), 已处理: 6,360,257, 发现变化: 12,725, 错误: 0
# Process 317 completed: 19895 files, 45 results, 0 errors
# 进度: 28.9% (318/1100), 已处理: 6,380,152, 发现变化: 12,770, 错误: 0
# Process 322 completed: 20103 files, 40 results, 0 errors
# 进度: 29.4% (323/1100), 已处理: 6,400,255, 发现变化: 12,810, 错误: 0
# Process 324 completed: 19811 files, 47 results, 0 errors
# 进度: 29.5% (325/1100), 已处理: 6,420,066, 发现变化: 12,857, 错误: 0
# Process 325 completed: 19826 files, 32 results, 0 errors
# Process 330 completed: 19874 files, 42 results, 0 errors
# Process 314 completed: 19881 files, 33 results, 0 errors
# 进度: 29.6% (326/1100), 已处理: 6,439,892, 发现变化: 12,889, 错误: 0
# 进度: 30.1% (331/1100), 已处理: 6,459,766, 发现变化: 12,931, 错误: 0
# 进度: 28.6% (315/1100), 已处理: 6,479,647, 发现变化: 12,964, 错误: 0
# Process 323 completed: 19846 files, 38 results, 0 errors
# 进度: 29.5% (324/1100), 已处理: 6,499,493, 发现变化: 13,002, 错误: 0
# Process 320 completed: 19876 files, 47 results, 0 errors
# 进度: 29.2% (321/1100), 已处理: 6,519,369, 发现变化: 13,049, 错误: 0
# Process 326 completed: 19909 files, 42 results, 0 errors
# 进度: 29.7% (327/1100), 已处理: 6,539,278, 发现变化: 13,091, 错误: 0
# Process 328 completed: 19962 files, 41 results, 0 errors
# 进度: 29.9% (329/1100), 已处理: 6,559,240, 发现变化: 13,132, 错误: 0
# Process 329 completed: 19900 files, 39 results, 0 errors
# 进度: 30.0% (330/1100), 已处理: 6,579,140, 发现变化: 13,171, 错误: 0
# Process 333 completed: 20070 files, 39 results, 0 errors
# 进度: 30.4% (334/1100), 已处理: 6,599,210, 发现变化: 13,210, 错误: 0
# Process 335 completed: 20039 files, 28 results, 0 errors
# 进度: 30.5% (336/1100), 已处理: 6,619,249, 发现变化: 13,238, 错误: 0
# Process 327 completed: 19912 files, 38 results, 0 errors
# 进度: 29.8% (328/1100), 已处理: 6,639,161, 发现变化: 13,276, 错误: 0
# Process 331 completed: 19908 files, 39 results, 0 errors
# 进度: 30.2% (332/1100), 已处理: 6,659,069, 发现变化: 13,315, 错误: 0
# Process 332 completed: 19980 files, 42 results, 0 errors
# 进度: 30.3% (333/1100), 已处理: 6,679,049, 发现变化: 13,357, 错误: 0
# Process 334 completed: 19970 files, 35 results, 0 errors
# 进度: 30.5% (335/1100), 已处理: 6,699,019, 发现变化: 13,392, 错误: 0
# Process 336 completed: 19810 files, 38 results, 0 errors
# 进度: 30.6% (337/1100), 已处理: 6,718,829, 发现变化: 13,430, 错误: 0
# Process 339 completed: 19958 files, 39 results, 0 errors
# 进度: 30.9% (340/1100), 已处理: 6,738,787, 发现变化: 13,469, 错误: 0
# Process 337 completed: 19776 files, 42 results, 0 errors
# 进度: 30.7% (338/1100), 已处理: 6,758,563, 发现变化: 13,511, 错误: 0
# Process 338 completed: 19920 files, 36 results, 0 errors
# 进度: 30.8% (339/1100), 已处理: 6,778,483, 发现变化: 13,547, 错误: 0
# Process 347 completed: 19978 files, 39 results, 0 errors
# 进度: 31.6% (348/1100), 已处理: 6,798,461, 发现变化: 13,586, 错误: 0
# Process 343 completed: 19943 files, 32 results, 0 errors
# 进度: 31.3% (344/1100), 已处理: 6,818,404, 发现变化: 13,618, 错误: 0
# Process 341 completed: 20002 files, 55 results, 0 errors
# 进度: 31.1% (342/1100), 已处理: 6,838,406, 发现变化: 13,673, 错误: 0
# Process 342 completed: 20031 files, 33 results, 0 errors
# 进度: 31.2% (343/1100), 已处理: 6,858,437, 发现变化: 13,706, 错误: 0
# Process 340 completed: 20005 files, 40 results, 0 errors
# Process 345 completed: 19913 files, 55 results, 0 errors
# 进度: 31.0% (341/1100), 已处理: 6,878,442, 发现变化: 13,746, 错误: 0
# 进度: 31.5% (346/1100), 已处理: 6,898,355, 发现变化: 13,801, 错误: 0
# Process 344 completed: 19938 files, 37 results, 0 errors
# 进度: 31.4% (345/1100), 已处理: 6,918,293, 发现变化: 13,838, 错误: 0
# Process 348 completed: 20006 files, 37 results, 0 errors
# 进度: 31.7% (349/1100), 已处理: 6,938,299, 发现变化: 13,875, 错误: 0
# Process 351 completed: 19967 files, 41 results, 0 errors
# 进度: 32.0% (352/1100), 已处理: 6,958,266, 发现变化: 13,916, 错误: 0
# Process 352 completed: 19950 files, 50 results, 0 errors
# 进度: 32.1% (353/1100), 已处理: 6,978,216, 发现变化: 13,966, 错误: 0
# Process 350 completed: 19940 files, 38 results, 0 errors
# 进度: 31.9% (351/1100), 已处理: 6,998,156, 发现变化: 14,004, 错误: 0
# Process 349 completed: 19878 files, 41 results, 0 errors
# 进度: 31.8% (350/1100), 已处理: 7,018,034, 发现变化: 14,045, 错误: 0
# Process 346 completed: 19947 files, 34 results, 0 errors
# 进度: 31.5% (347/1100), 已处理: 7,037,981, 发现变化: 14,079, 错误: 0
# Process 358 completed: 20009 files, 41 results, 0 errors
# 进度: 32.6% (359/1100), 已处理: 7,057,990, 发现变化: 14,120, 错误: 0
# Process 356 completed: 19868 files, 35 results, 0 errors
# 进度: 32.5% (357/1100), 已处理: 7,077,858, 发现变化: 14,155, 错误: 0
# Process 354 completed: 20026 files, 36 results, 0 errors
# 进度: 32.3% (355/1100), 已处理: 7,097,884, 发现变化: 14,191, 错误: 0
# Process 353 completed: 19863 files, 39 results, 0 errors
# 进度: 32.2% (354/1100), 已处理: 7,117,747, 发现变化: 14,230, 错误: 0
# Process 357 completed: 19989 files, 44 results, 0 errors
# 进度: 32.5% (358/1100), 已处理: 7,137,736, 发现变化: 14,274, 错误: 0
# Process 355 completed: 19926 files, 34 results, 0 errors
# 进度: 32.4% (356/1100), 已处理: 7,157,662, 发现变化: 14,308, 错误: 0
# Process 363 completed: 19869 files, 40 results, 0 errors
# 进度: 33.1% (364/1100), 已处理: 7,177,531, 发现变化: 14,348, 错误: 0
# Process 359 completed: 19954 files, 37 results, 0 errors
# 进度: 32.7% (360/1100), 已处理: 7,197,485, 发现变化: 14,385, 错误: 0
# Process 362 completed: 19849 files, 45 results, 0 errors
# 进度: 33.0% (363/1100), 已处理: 7,217,334, 发现变化: 14,430, 错误: 0
# Process 368 completed: 19816 files, 32 results, 0 errors
# 进度: 33.5% (369/1100), 已处理: 7,237,150, 发现变化: 14,462, 错误: 0
# Process 365 completed: 19939 files, 53 results, 0 errors
# Process 373 completed: 19850 files, 45 results, 0 errors
# 进度: 33.3% (366/1100), 已处理: 7,257,089, 发现变化: 14,515, 错误: 0
# 进度: 34.0% (374/1100), 已处理: 7,276,939, 发现变化: 14,560, 错误: 0
# Process 367 completed: 19978 files, 45 results, 0 errors
# 进度: 33.5% (368/1100), 已处理: 7,296,917, 发现变化: 14,605, 错误: 0
# Process 361 completed: 19801 files, 39 results, 0 errors
# 进度: 32.9% (362/1100), 已处理: 7,316,718, 发现变化: 14,644, 错误: 0
# Process 372 completed: 19885 files, 34 results, 0 errors
# 进度: 33.9% (373/1100), 已处理: 7,336,603, 发现变化: 14,678, 错误: 0
# Process 371 completed: 19829 files, 42 results, 0 errors
# 进度: 33.8% (372/1100), 已处理: 7,356,432, 发现变化: 14,720, 错误: 0
# Process 369 completed: 20006 files, 40 results, 0 errors
# 进度: 33.6% (370/1100), 已处理: 7,376,438, 发现变化: 14,760, 错误: 0
# Process 360 completed: 19803 files, 52 results, 0 errors
# 进度: 32.8% (361/1100), 已处理: 7,396,241, 发现变化: 14,812, 错误: 0
# Process 370 completed: 20139 files, 42 results, 0 errors
# 进度: 33.7% (371/1100), 已处理: 7,416,380, 发现变化: 14,854, 错误: 0
# Process 366 completed: 19849 files, 30 results, 0 errors
# 进度: 33.4% (367/1100), 已处理: 7,436,229, 发现变化: 14,884, 错误: 0
# Process 364 completed: 19948 files, 46 results, 0 errors
# 进度: 33.2% (365/1100), 已处理: 7,456,177, 发现变化: 14,930, 错误: 0
# Process 377 completed: 19936 files, 41 results, 0 errors
# 进度: 34.4% (378/1100), 已处理: 7,476,113, 发现变化: 14,971, 错误: 0
# Process 376 completed: 19889 files, 37 results, 0 errors
# 进度: 34.3% (377/1100), 已处理: 7,496,002, 发现变化: 15,008, 错误: 0
# Process 374 completed: 19897 files, 43 results, 0 errors
# 进度: 34.1% (375/1100), 已处理: 7,515,899, 发现变化: 15,051, 错误: 0
# Process 375 completed: 19907 files, 42 results, 0 errors
# 进度: 34.2% (376/1100), 已处理: 7,535,806, 发现变化: 15,093, 错误: 0
# Process 378 completed: 19799 files, 29 results, 0 errors
# 进度: 34.5% (379/1100), 已处理: 7,555,605, 发现变化: 15,122, 错误: 0
# Process 380 completed: 19982 files, 41 results, 0 errors
# 进度: 34.6% (381/1100), 已处理: 7,575,587, 发现变化: 15,163, 错误: 0
# Process 379 completed: 19957 files, 40 results, 0 errors
# 进度: 34.5% (380/1100), 已处理: 7,595,544, 发现变化: 15,203, 错误: 0
# Process 387 completed: 19728 files, 30 results, 0 errors
# 进度: 35.3% (388/1100), 已处理: 7,615,272, 发现变化: 15,233, 错误: 0
# Process 381 completed: 19917 files, 32 results, 0 errors
# 进度: 34.7% (382/1100), 已处理: 7,635,189, 发现变化: 15,265, 错误: 0
# Process 383 completed: 19899 files, 44 results, 0 errors
# 进度: 34.9% (384/1100), 已处理: 7,655,088, 发现变化: 15,309, 错误: 0
# Process 384 completed: 20071 files, 47 results, 0 errors
# 进度: 35.0% (385/1100), 已处理: 7,675,159, 发现变化: 15,356, 错误: 0
# Process 382 completed: 19941 files, 39 results, 0 errors
# Process 385 completed: 19847 files, 36 results, 0 errors
# 进度: 34.8% (383/1100), 已处理: 7,695,100, 发现变化: 15,395, 错误: 0
# 进度: 35.1% (386/1100), 已处理: 7,714,947, 发现变化: 15,431, 错误: 0
# Process 386 completed: 20004 files, 39 results, 0 errors
# 进度: 35.2% (387/1100), 已处理: 7,734,951, 发现变化: 15,470, 错误: 0
# Process 389 completed: 19985 files, 38 results, 0 errors
# 进度: 35.5% (390/1100), 已处理: 7,754,936, 发现变化: 15,508, 错误: 0
# Process 388 completed: 19938 files, 38 results, 0 errors
# 进度: 35.4% (389/1100), 已处理: 7,774,874, 发现变化: 15,546, 错误: 0
# Process 391 completed: 20126 files, 38 results, 0 errors
# 进度: 35.6% (392/1100), 已处理: 7,795,000, 发现变化: 15,584, 错误: 0
# Process 390 completed: 19932 files, 39 results, 0 errors
# Process 393 completed: 20022 files, 44 results, 0 errors
# 进度: 35.5% (391/1100), 已处理: 7,814,932, 发现变化: 15,623, 错误: 0
# 进度: 35.8% (394/1100), 已处理: 7,834,954, 发现变化: 15,667, 错误: 0
# Process 394 completed: 20070 files, 29 results, 0 errors
# 进度: 35.9% (395/1100), 已处理: 7,855,024, 发现变化: 15,696, 错误: 0
# Process 396 completed: 19946 files, 45 results, 0 errors
# 进度: 36.1% (397/1100), 已处理: 7,874,970, 发现变化: 15,741, 错误: 0
# Process 397 completed: 19974 files, 42 results, 0 errors
# 进度: 36.2% (398/1100), 已处理: 7,894,944, 发现变化: 15,783, 错误: 0
# Process 392 completed: 19994 files, 46 results, 0 errors
# 进度: 35.7% (393/1100), 已处理: 7,914,938, 发现变化: 15,829, 错误: 0
# Process 402 completed: 19966 files, 36 results, 0 errors
# 进度: 36.6% (403/1100), 已处理: 7,934,904, 发现变化: 15,865, 错误: 0
# Process 398 completed: 19918 files, 36 results, 0 errors
# 进度: 36.3% (399/1100), 已处理: 7,954,822, 发现变化: 15,901, 错误: 0
# Process 400 completed: 19863 files, 41 results, 0 errors
# 进度: 36.5% (401/1100), 已处理: 7,974,685, 发现变化: 15,942, 错误: 0
# Process 395 completed: 19997 files, 45 results, 0 errors
# 进度: 36.0% (396/1100), 已处理: 7,994,682, 发现变化: 15,987, 错误: 0
# Process 408 completed: 20010 files, 37 results, 0 errors
# 进度: 37.2% (409/1100), 已处理: 8,014,692, 发现变化: 16,024, 错误: 0
# Process 401 completed: 19935 files, 50 results, 0 errors
# 进度: 36.5% (402/1100), 已处理: 8,034,627, 发现变化: 16,074, 错误: 0
# Process 406 completed: 19987 files, 30 results, 0 errors
# 进度: 37.0% (407/1100), 已处理: 8,054,614, 发现变化: 16,104, 错误: 0
# Process 404 completed: 20167 files, 45 results, 0 errors
# 进度: 36.8% (405/1100), 已处理: 8,074,781, 发现变化: 16,149, 错误: 0
# Process 412 completed: 19809 files, 46 results, 0 errors
# 进度: 37.5% (413/1100), 已处理: 8,094,590, 发现变化: 16,195, 错误: 0
# Process 410 completed: 20041 files, 38 results, 0 errors
# 进度: 37.4% (411/1100), 已处理: 8,114,631, 发现变化: 16,233, 错误: 0
# Process 403 completed: 19986 files, 43 results, 0 errors
# 进度: 36.7% (404/1100), 已处理: 8,134,617, 发现变化: 16,276, 错误: 0
# Process 407 completed: 19959 files, 40 results, 0 errors
# 进度: 37.1% (408/1100), 已处理: 8,154,576, 发现变化: 16,316, 错误: 0
# Process 399 completed: 19975 files, 44 results, 0 errors
# 进度: 36.4% (400/1100), 已处理: 8,174,551, 发现变化: 16,360, 错误: 0
# Process 411 completed: 20024 files, 43 results, 0 errors
# Process 405 completed: 19791 files, 32 results, 0 errors
# 进度: 37.5% (412/1100), 已处理: 8,194,575, 发现变化: 16,403, 错误: 0
# 进度: 36.9% (406/1100), 已处理: 8,214,366, 发现变化: 16,435, 错误: 0
# Process 409 completed: 19977 files, 37 results, 0 errors
# 进度: 37.3% (410/1100), 已处理: 8,234,343, 发现变化: 16,472, 错误: 0
# Process 415 completed: 20061 files, 37 results, 0 errors
# Process 414 completed: 19949 files, 44 results, 0 errors
# 进度: 37.8% (416/1100), 已处理: 8,254,404, 发现变化: 16,509, 错误: 0
# 进度: 37.7% (415/1100), 已处理: 8,274,353, 发现变化: 16,553, 错误: 0
# Process 419 completed: 19903 files, 39 results, 0 errors
# 进度: 38.2% (420/1100), 已处理: 8,294,256, 发现变化: 16,592, 错误: 0
# Process 413 completed: 19944 files, 46 results, 0 errors
# 进度: 37.6% (414/1100), 已处理: 8,314,200, 发现变化: 16,638, 错误: 0
# Process 416 completed: 20110 files, 47 results, 0 errors
# 进度: 37.9% (417/1100), 已处理: 8,334,310, 发现变化: 16,685, 错误: 0
# Process 417 completed: 19982 files, 42 results, 0 errors
# 进度: 38.0% (418/1100), 已处理: 8,354,292, 发现变化: 16,727, 错误: 0
# Process 418 completed: 20037 files, 43 results, 0 errors
# 进度: 38.1% (419/1100), 已处理: 8,374,329, 发现变化: 16,770, 错误: 0
# Process 421 completed: 19824 files, 45 results, 0 errors
# 进度: 38.4% (422/1100), 已处理: 8,394,153, 发现变化: 16,815, 错误: 0
# Process 420 completed: 19926 files, 42 results, 0 errors
# 进度: 38.3% (421/1100), 已处理: 8,414,079, 发现变化: 16,857, 错误: 0
# Process 423 completed: 19886 files, 39 results, 0 errors
# 进度: 38.5% (424/1100), 已处理: 8,433,965, 发现变化: 16,896, 错误: 0
# ...
# Process 964 completed: 19866 files, 55 results, 0 errors
# 进度: 87.7% (965/1100), 已处理: 19,239,852, 发现变化: 38,326, 错误: 0
# Process 965 completed: 19885 files, 48 results, 0 errors
# 进度: 87.8% (966/1100), 已处理: 19,259,737, 发现变化: 38,374, 错误: 0
# Process 966 completed: 19937 files, 50 results, 0 errors
# 进度: 87.9% (967/1100), 已处理: 19,279,674, 发现变化: 38,424, 错误: 0
# Process 967 completed: 19981 files, 53 results, 0 errors
# 进度: 88.0% (968/1100), 已处理: 19,299,655, 发现变化: 38,477, 错误: 0
# Process 969 completed: 19864 files, 41 results, 0 errors
# 进度: 88.2% (970/1100), 已处理: 19,319,519, 发现变化: 38,518, 错误: 0
# Process 968 completed: 19862 files, 46 results, 0 errors
# 进度: 88.1% (969/1100), 已处理: 19,339,381, 发现变化: 38,564, 错误: 0
# Process 970 completed: 19904 files, 42 results, 0 errors
# 进度: 88.3% (971/1100), 已处理: 19,359,285, 发现变化: 38,606, 错误: 0
# Process 972 completed: 19994 files, 37 results, 0 errors
# 进度: 88.5% (973/1100), 已处理: 19,379,279, 发现变化: 38,643, 错误: 0
# Process 975 completed: 19973 files, 41 results, 0 errors
# 进度: 88.7% (976/1100), 已处理: 19,399,252, 发现变化: 38,684, 错误: 0
# Process 973 completed: 19808 files, 35 results, 0 errors
# 进度: 88.5% (974/1100), 已处理: 19,419,060, 发现变化: 38,719, 错误: 0
# Process 971 completed: 19764 files, 36 results, 0 errors
# 进度: 88.4% (972/1100), 已处理: 19,438,824, 发现变化: 38,755, 错误: 0
# Process 976 completed: 19999 files, 45 results, 0 errors
# 进度: 88.8% (977/1100), 已处理: 19,458,823, 发现变化: 38,800, 错误: 0
# Process 980 completed: 19932 files, 41 results, 0 errors
# 进度: 89.2% (981/1100), 已处理: 19,478,755, 发现变化: 38,841, 错误: 0
# Process 974 completed: 20026 files, 42 results, 0 errors
# 进度: 88.6% (975/1100), 已处理: 19,498,781, 发现变化: 38,883, 错误: 0
# Process 981 completed: 19916 files, 32 results, 0 errors
# 进度: 89.3% (982/1100), 已处理: 19,518,697, 发现变化: 38,915, 错误: 0
# Process 978 completed: 19944 files, 30 results, 0 errors
# 进度: 89.0% (979/1100), 已处理: 19,538,641, 发现变化: 38,945, 错误: 0
# Process 984 completed: 19887 files, 42 results, 0 errors
# 进度: 89.5% (985/1100), 已处理: 19,558,528, 发现变化: 38,987, 错误: 0
# Process 977 completed: 19998 files, 44 results, 0 errors
# 进度: 88.9% (978/1100), 已处理: 19,578,526, 发现变化: 39,031, 错误: 0
# Process 983 completed: 19893 files, 32 results, 0 errors
# 进度: 89.5% (984/1100), 已处理: 19,598,419, 发现变化: 39,063, 错误: 0
# Process 982 completed: 20093 files, 38 results, 0 errors
# 进度: 89.4% (983/1100), 已处理: 19,618,512, 发现变化: 39,101, 错误: 0
# Process 985 completed: 19957 files, 45 results, 0 errors
# 进度: 89.6% (986/1100), 已处理: 19,638,469, 发现变化: 39,146, 错误: 0
# Process 986 completed: 19851 files, 37 results, 0 errors
# 进度: 89.7% (987/1100), 已处理: 19,658,320, 发现变化: 39,183, 错误: 0
# Process 979 completed: 19810 files, 48 results, 0 errors
# 进度: 89.1% (980/1100), 已处理: 19,678,130, 发现变化: 39,231, 错误: 0
# Process 987 completed: 20011 files, 44 results, 0 errors
# 进度: 89.8% (988/1100), 已处理: 19,698,141, 发现变化: 39,275, 错误: 0
# Process 990 completed: 20002 files, 32 results, 0 errors
# 进度: 90.1% (991/1100), 已处理: 19,718,143, 发现变化: 39,307, 错误: 0
# Process 994 completed: 20056 files, 45 results, 0 errors
# 进度: 90.5% (995/1100), 已处理: 19,738,199, 发现变化: 39,352, 错误: 0
# Process 992 completed: 19900 files, 42 results, 0 errors
# 进度: 90.3% (993/1100), 已处理: 19,758,099, 发现变化: 39,394, 错误: 0
# Process 989 completed: 19929 files, 40 results, 0 errors
# 进度: 90.0% (990/1100), 已处理: 19,778,028, 发现变化: 39,434, 错误: 0
# Process 996 completed: 19797 files, 38 results, 0 errors
# 进度: 90.6% (997/1100), 已处理: 19,797,825, 发现变化: 39,472, 错误: 0
# Process 988 completed: 20050 files, 43 results, 0 errors
# 进度: 89.9% (989/1100), 已处理: 19,817,875, 发现变化: 39,515, 错误: 0
# Process 991 completed: 19768 files, 37 results, 0 errors
# 进度: 90.2% (992/1100), 已处理: 19,837,643, 发现变化: 39,552, 错误: 0
# Process 995 completed: 19909 files, 35 results, 0 errors
# 进度: 90.5% (996/1100), 已处理: 19,857,552, 发现变化: 39,587, 错误: 0
# Process 998 completed: 19727 files, 38 results, 0 errors
# 进度: 90.8% (999/1100), 已处理: 19,877,279, 发现变化: 39,625, 错误: 0
# Process 997 completed: 19879 files, 33 results, 0 errors
# 进度: 90.7% (998/1100), 已处理: 19,897,158, 发现变化: 39,658, 错误: 0
# Process 993 completed: 19838 files, 41 results, 0 errors
# 进度: 90.4% (994/1100), 已处理: 19,916,996, 发现变化: 39,699, 错误: 0
# Process 999 completed: 19867 files, 44 results, 0 errors
# 进度: 90.9% (1000/1100), 已处理: 19,936,863, 发现变化: 39,743, 错误: 0
# Process 1000 completed: 19947 files, 35 results, 0 errors
# 进度: 91.0% (1001/1100), 已处理: 19,956,810, 发现变化: 39,778, 错误: 0
# Process 1001 completed: 20005 files, 36 results, 0 errors
# 进度: 91.1% (1002/1100), 已处理: 19,976,815, 发现变化: 39,814, 错误: 0
# Process 1002 completed: 19933 files, 36 results, 0 errors
# 进度: 91.2% (1003/1100), 已处理: 19,996,748, 发现变化: 39,850, 错误: 0
# Process 1003 completed: 19958 files, 46 results, 0 errors
# 进度: 91.3% (1004/1100), 已处理: 20,016,706, 发现变化: 39,896, 错误: 0
# Process 1006 completed: 19975 files, 35 results, 0 errors
# 进度: 91.5% (1007/1100), 已处理: 20,036,681, 发现变化: 39,931, 错误: 0
# Process 1004 completed: 19932 files, 33 results, 0 errors
# 进度: 91.4% (1005/1100), 已处理: 20,056,613, 发现变化: 39,964, 错误: 0
# Process 1005 completed: 19940 files, 40 results, 0 errors
# 进度: 91.5% (1006/1100), 已处理: 20,076,553, 发现变化: 40,004, 错误: 0
# Process 1007 completed: 19960 files, 41 results, 0 errors
# 进度: 91.6% (1008/1100), 已处理: 20,096,513, 发现变化: 40,045, 错误: 0
# Process 1009 completed: 20010 files, 39 results, 0 errors
# 进度: 91.8% (1010/1100), 已处理: 20,116,523, 发现变化: 40,084, 错误: 0
# Process 1008 completed: 19961 files, 39 results, 0 errors
# 进度: 91.7% (1009/1100), 已处理: 20,136,484, 发现变化: 40,123, 错误: 0
# Process 1010 completed: 19954 files, 47 results, 0 errors
# 进度: 91.9% (1011/1100), 已处理: 20,156,438, 发现变化: 40,170, 错误: 0
# Process 1011 completed: 19941 files, 50 results, 0 errors
# 进度: 92.0% (1012/1100), 已处理: 20,176,379, 发现变化: 40,220, 错误: 0
# Process 1012 completed: 19993 files, 34 results, 0 errors
# 进度: 92.1% (1013/1100), 已处理: 20,196,372, 发现变化: 40,254, 错误: 0
# Process 1013 completed: 19797 files, 43 results, 0 errors
# 进度: 92.2% (1014/1100), 已处理: 20,216,169, 发现变化: 40,297, 错误: 0
# Process 1014 completed: 19946 files, 49 results, 0 errors
# 进度: 92.3% (1015/1100), 已处理: 20,236,115, 发现变化: 40,346, 错误: 0
# Process 1018 completed: 19926 files, 30 results, 0 errors
# 进度: 92.6% (1019/1100), 已处理: 20,256,041, 发现变化: 40,376, 错误: 0
# Process 1015 completed: 19971 files, 38 results, 0 errors
# 进度: 92.4% (1016/1100), 已处理: 20,276,012, 发现变化: 40,414, 错误: 0
# Process 1019 completed: 19813 files, 32 results, 0 errors
# 进度: 92.7% (1020/1100), 已处理: 20,295,825, 发现变化: 40,446, 错误: 0
# Process 1025 completed: 19872 files, 36 results, 0 errors
# 进度: 93.3% (1026/1100), 已处理: 20,315,697, 发现变化: 40,482, 错误: 0
# Process 1020 completed: 19818 files, 38 results, 0 errors
# Process 1022 completed: 19844 files, 35 results, 0 errors
# 进度: 92.8% (1021/1100), 已处理: 20,335,515, 发现变化: 40,520, 错误: 0
# 进度: 93.0% (1023/1100), 已处理: 20,355,359, 发现变化: 40,555, 错误: 0
# Process 1017 completed: 19953 files, 44 results, 0 errors
# 进度: 92.5% (1018/1100), 已处理: 20,375,312, 发现变化: 40,599, 错误: 0
# Process 1021 completed: 20020 files, 33 results, 0 errors
# 进度: 92.9% (1022/1100), 已处理: 20,395,332, 发现变化: 40,632, 错误: 0
# Process 1016 completed: 19957 files, 44 results, 0 errors
# 进度: 92.5% (1017/1100), 已处理: 20,415,289, 发现变化: 40,676, 错误: 0
# Process 1023 completed: 19917 files, 42 results, 0 errors
# 进度: 93.1% (1024/1100), 已处理: 20,435,206, 发现变化: 40,718, 错误: 0
# Process 1024 completed: 19699 files, 49 results, 0 errors
# 进度: 93.2% (1025/1100), 已处理: 20,454,905, 发现变化: 40,767, 错误: 0
# Process 1026 completed: 19927 files, 39 results, 0 errors
# 进度: 93.4% (1027/1100), 已处理: 20,474,832, 发现变化: 40,806, 错误: 0
# Process 1028 completed: 19997 files, 39 results, 0 errors
# 进度: 93.5% (1029/1100), 已处理: 20,494,829, 发现变化: 40,845, 错误: 0
# Process 1029 completed: 19996 files, 47 results, 0 errors
# 进度: 93.6% (1030/1100), 已处理: 20,514,825, 发现变化: 40,892, 错误: 0
# Process 1027 completed: 19915 files, 40 results, 0 errors
# 进度: 93.5% (1028/1100), 已处理: 20,534,740, 发现变化: 40,932, 错误: 0
# Process 1032 completed: 19947 files, 34 results, 0 errors
# 进度: 93.9% (1033/1100), 已处理: 20,554,687, 发现变化: 40,966, 错误: 0
# Process 1031 completed: 19854 files, 32 results, 0 errors
# 进度: 93.8% (1032/1100), 已处理: 20,574,541, 发现变化: 40,998, 错误: 0
# Process 1034 completed: 19864 files, 44 results, 0 errors
# 进度: 94.1% (1035/1100), 已处理: 20,594,405, 发现变化: 41,042, 错误: 0
# Process 1039 completed: 19890 files, 40 results, 0 errors
# Process 1033 completed: 20068 files, 29 results, 0 errors
# 进度: 94.5% (1040/1100), 已处理: 20,614,295, 发现变化: 41,082, 错误: 0
# 进度: 94.0% (1034/1100), 已处理: 20,634,363, 发现变化: 41,111, 错误: 0
# Process 1035 completed: 20048 files, 40 results, 0 errors
# 进度: 94.2% (1036/1100), 已处理: 20,654,411, 发现变化: 41,151, 错误: 0
# Process 1038 completed: 19858 files, 42 results, 0 errors
# 进度: 94.5% (1039/1100), 已处理: 20,674,269, 发现变化: 41,193, 错误: 0
# Process 1037 completed: 19983 files, 46 results, 0 errors
# 进度: 94.4% (1038/1100), 已处理: 20,694,252, 发现变化: 41,239, 错误: 0
# Process 1036 completed: 20024 files, 33 results, 0 errors
# 进度: 94.3% (1037/1100), 已处理: 20,714,276, 发现变化: 41,272, 错误: 0
# Process 1030 completed: 20017 files, 45 results, 0 errors
# 进度: 93.7% (1031/1100), 已处理: 20,734,293, 发现变化: 41,317, 错误: 0
# Process 1040 completed: 19789 files, 37 results, 0 errors
# 进度: 94.6% (1041/1100), 已处理: 20,754,082, 发现变化: 41,354, 错误: 0
# Process 1042 completed: 20034 files, 39 results, 0 errors
# 进度: 94.8% (1043/1100), 已处理: 20,774,116, 发现变化: 41,393, 错误: 0
# Process 1043 completed: 19984 files, 41 results, 0 errors
# 进度: 94.9% (1044/1100), 已处理: 20,794,100, 发现变化: 41,434, 错误: 0
# Process 1041 completed: 19889 files, 37 results, 0 errors
# 进度: 94.7% (1042/1100), 已处理: 20,813,989, 发现变化: 41,471, 错误: 0
# Process 1044 completed: 19813 files, 39 results, 0 errors
# 进度: 95.0% (1045/1100), 已处理: 20,833,802, 发现变化: 41,510, 错误: 0
# Process 1046 completed: 19937 files, 33 results, 0 errors
# 进度: 95.2% (1047/1100), 已处理: 20,853,739, 发现变化: 41,543, 错误: 0
# Process 1048 completed: 20026 files, 35 results, 0 errors
# Process 1047 completed: 20030 files, 39 results, 0 errors
# 进度: 95.4% (1049/1100), 已处理: 20,873,765, 发现变化: 41,578, 错误: 0
# 进度: 95.3% (1048/1100), 已处理: 20,893,795, 发现变化: 41,617, 错误: 0
# Process 1045 completed: 19853 files, 39 results, 0 errors
# 进度: 95.1% (1046/1100), 已处理: 20,913,648, 发现变化: 41,656, 错误: 0
# Process 1049 completed: 20047 files, 35 results, 0 errors
# 进度: 95.5% (1050/1100), 已处理: 20,933,695, 发现变化: 41,691, 错误: 0
# Process 1050 completed: 19884 files, 47 results, 0 errors
# 进度: 95.5% (1051/1100), 已处理: 20,953,579, 发现变化: 41,738, 错误: 0
# Process 1051 completed: 19944 files, 49 results, 0 errors
# 进度: 95.6% (1052/1100), 已处理: 20,973,523, 发现变化: 41,787, 错误: 0
# Process 1052 completed: 19864 files, 39 results, 0 errors
# 进度: 95.7% (1053/1100), 已处理: 20,993,387, 发现变化: 41,826, 错误: 0
# Process 1054 completed: 19886 files, 44 results, 0 errors
# 进度: 95.9% (1055/1100), 已处理: 21,013,273, 发现变化: 41,870, 错误: 0
# Process 1053 completed: 19899 files, 43 results, 0 errors
# 进度: 95.8% (1054/1100), 已处理: 21,033,172, 发现变化: 41,913, 错误: 0
# Process 1055 completed: 19805 files, 47 results, 0 errors
# 进度: 96.0% (1056/1100), 已处理: 21,052,977, 发现变化: 41,960, 错误: 0
# Process 1057 completed: 19912 files, 31 results, 0 errors
# 进度: 96.2% (1058/1100), 已处理: 21,072,889, 发现变化: 41,991, 错误: 0
# Process 1058 completed: 19898 files, 31 results, 0 errors
# 进度: 96.3% (1059/1100), 已处理: 21,092,787, 发现变化: 42,022, 错误: 0
# Process 1056 completed: 19883 files, 59 results, 0 errors
# 进度: 96.1% (1057/1100), 已处理: 21,112,670, 发现变化: 42,081, 错误: 0
# Process 1062 completed: 19895 files, 42 results, 0 errors
# 进度: 96.6% (1063/1100), 已处理: 21,132,565, 发现变化: 42,123, 错误: 0
# Process 1063 completed: 20062 files, 41 results, 0 errors
# 进度: 96.7% (1064/1100), 已处理: 21,152,627, 发现变化: 42,164, 错误: 0
# Process 1064 completed: 19892 files, 42 results, 0 errors
# 进度: 96.8% (1065/1100), 已处理: 21,172,519, 发现变化: 42,206, 错误: 0
# Process 1059 completed: 19980 files, 19 results, 0 errors
# 进度: 96.4% (1060/1100), 已处理: 21,192,499, 发现变化: 42,225, 错误: 0
# Process 1065 completed: 19885 files, 30 results, 0 errors
# 进度: 96.9% (1066/1100), 已处理: 21,212,384, 发现变化: 42,255, 错误: 0
# Process 1067 completed: 19962 files, 38 results, 0 errors
# 进度: 97.1% (1068/1100), 已处理: 21,232,346, 发现变化: 42,293, 错误: 0
# Process 1061 completed: 19934 files, 43 results, 0 errors
# 进度: 96.5% (1062/1100), 已处理: 21,252,280, 发现变化: 42,336, 错误: 0
# Process 1060 completed: 19873 files, 44 results, 0 errors
# 进度: 96.5% (1061/1100), 已处理: 21,272,153, 发现变化: 42,380, 错误: 0
# Process 1068 completed: 19823 files, 35 results, 0 errors
# 进度: 97.2% (1069/1100), 已处理: 21,291,976, 发现变化: 42,415, 错误: 0
# Process 1066 completed: 19988 files, 34 results, 0 errors
# 进度: 97.0% (1067/1100), 已处理: 21,311,964, 发现变化: 42,449, 错误: 0
# Process 1069 completed: 20035 files, 23 results, 0 errors
# 进度: 97.3% (1070/1100), 已处理: 21,331,999, 发现变化: 42,472, 错误: 0
# Process 1070 completed: 19965 files, 35 results, 0 errors
# 进度: 97.4% (1071/1100), 已处理: 21,351,964, 发现变化: 42,507, 错误: 0
# Process 1074 completed: 19926 files, 51 results, 0 errors
# 进度: 97.7% (1075/1100), 已处理: 21,371,890, 发现变化: 42,558, 错误: 0
# Process 1075 completed: 19967 files, 51 results, 0 errors
# 进度: 97.8% (1076/1100), 已处理: 21,391,857, 发现变化: 42,609, 错误: 0
# Process 1073 completed: 19893 files, 37 results, 0 errors
# 进度: 97.6% (1074/1100), 已处理: 21,411,750, 发现变化: 42,646, 错误: 0
# Process 1072 completed: 20028 files, 40 results, 0 errors
# 进度: 97.5% (1073/1100), 已处理: 21,431,778, 发现变化: 42,686, 错误: 0
# Process 1076 completed: 19906 files, 46 results, 0 errors
# Process 1079 completed: 19846 files, 46 results, 0 errors
# 进度: 97.9% (1077/1100), 已处理: 21,451,684, 发现变化: 42,732, 错误: 0
# 进度: 98.2% (1080/1100), 已处理: 21,471,530, 发现变化: 42,778, 错误: 0
# Process 1078 completed: 19953 files, 39 results, 0 errors
# Process 1077 completed: 19914 files, 46 results, 0 errors
# 进度: 98.1% (1079/1100), 已处理: 21,491,483, 发现变化: 42,817, 错误: 0
# 进度: 98.0% (1078/1100), 已处理: 21,511,397, 发现变化: 42,863, 错误: 0
# Process 1071 completed: 19975 files, 40 results, 0 errors
# 进度: 97.5% (1072/1100), 已处理: 21,531,372, 发现变化: 42,903, 错误: 0
# Process 1084 completed: 19949 files, 33 results, 0 errors
# 进度: 98.6% (1085/1100), 已处理: 21,551,321, 发现变化: 42,936, 错误: 0
# Process 1082 completed: 19787 files, 31 results, 0 errors
# 进度: 98.5% (1083/1100), 已处理: 21,571,108, 发现变化: 42,967, 错误: 0
# Process 1083 completed: 19938 files, 42 results, 0 errors
# 进度: 98.5% (1084/1100), 已处理: 21,591,046, 发现变化: 43,009, 错误: 0
# Process 1081 completed: 19909 files, 37 results, 0 errors
# 进度: 98.4% (1082/1100), 已处理: 21,610,955, 发现变化: 43,046, 错误: 0
# Process 1085 completed: 20118 files, 38 results, 0 errors
# Process 1080 completed: 20001 files, 42 results, 0 errors
# 进度: 98.7% (1086/1100), 已处理: 21,631,073, 发现变化: 43,084, 错误: 0
# 进度: 98.3% (1081/1100), 已处理: 21,651,074, 发现变化: 43,126, 错误: 0
# Process 1087 completed: 20025 files, 38 results, 0 errors
# 进度: 98.9% (1088/1100), 已处理: 21,671,099, 发现变化: 43,164, 错误: 0
# Process 1086 completed: 20068 files, 36 results, 0 errors
# 进度: 98.8% (1087/1100), 已处理: 21,691,167, 发现变化: 43,200, 错误: 0
# Process 1088 completed: 20035 files, 33 results, 0 errors
# 进度: 99.0% (1089/1100), 已处理: 21,711,202, 发现变化: 43,233, 错误: 0
# Process 1090 completed: 19921 files, 44 results, 0 errors
# 进度: 99.2% (1091/1100), 已处理: 21,731,123, 发现变化: 43,277, 错误: 0
# Process 1091 completed: 19969 files, 27 results, 0 errors
# 进度: 99.3% (1092/1100), 已处理: 21,751,092, 发现变化: 43,304, 错误: 0
# Process 1089 completed: 19944 files, 46 results, 0 errors
# 进度: 99.1% (1090/1100), 已处理: 21,771,036, 发现变化: 43,350, 错误: 0
# Process 1093 completed: 20083 files, 41 results, 0 errors
# 进度: 99.5% (1094/1100), 已处理: 21,791,119, 发现变化: 43,391, 错误: 0
# Process 1092 completed: 20064 files, 34 results, 0 errors
# 进度: 99.4% (1093/1100), 已处理: 21,811,183, 发现变化: 43,425, 错误: 0
# Process 1096 completed: 20026 files, 37 results, 0 errors
# 进度: 99.7% (1097/1100), 已处理: 21,831,209, 发现变化: 43,462, 错误: 0
# Process 1094 completed: 19901 files, 42 results, 0 errors
# 进度: 99.5% (1095/1100), 已处理: 21,851,110, 发现变化: 43,504, 错误: 0
# Process 1095 completed: 19854 files, 39 results, 0 errors
# 进度: 99.6% (1096/1100), 已处理: 21,870,964, 发现变化: 43,543, 错误: 0
# Process 1098 completed: 20166 files, 40 results, 0 errors
# 进度: 99.9% (1099/1100), 已处理: 21,891,130, 发现变化: 43,583, 错误: 0
# Process 1099 completed: 19768 files, 37 results, 0 errors
# 进度: 100.0% (1100/1100), 已处理: 21,910,898, 发现变化: 43,620, 错误: 0
# Process 1097 completed: 19868 files, 31 results, 0 errors
# 进度: 99.8% (1098/1100), 已处理: 21,930,766, 发现变化: 43,651, 错误: 0
